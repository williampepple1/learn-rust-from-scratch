// %% [markdown]
// # 🦀 Rust Interview MCQ — Part 4: Concurrency, Async & Advanced Topics (Q301–Q400)
//
// **500 Multiple-Choice Questions for Rust Interview Preparation**
//
// Each question has 4 options (A–D) with the correct answer and explanation immediately below.
//
// ---

// %% [markdown]
// ### Q301. What does `std::thread::spawn` return?
//
// A) `Thread`
// B) `JoinHandle<T>`
// C) `Result<Thread, JoinError>`
// D) `Option<JoinHandle<T>>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q301. B** — `spawn` returns a `JoinHandle<T>` where `T` is the return type of the closure. Call `join()` on it to block and get the result.
//
// </details>

// %% [markdown]
// ### Q302. Which keyword is required when a closure needs to transfer ownership of captured variables to a spawned thread?
//
// A) `clone`
// B) `move`
// C) `send`
// D) `transfer`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q302. B** — The `move` keyword forces the closure to take ownership of captured variables, which is required for `thread::spawn` since the closure must be `'static`.
//
// </details>

// %% [markdown]
// ### Q303. What happens if you call `join()` on a `JoinHandle` and the thread panicked?
//
// A) The program continues normally
// B) `join()` returns `Ok(())`
// C) `join()` returns `Err(Box<dyn Any + Send>)`
// D) The main thread panics
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q303. C** — If the thread panicked, `join()` returns `Err(Box<dyn Any + Send>)` containing the panic payload. The main thread does not automatically panic.
//
// </details>

// %% [markdown]
// ### Q304. Which function puts the current thread to sleep for a specified duration?
//
// A) `std::thread::sleep()`
// B) `std::thread::yield()`
// C) `std::time::sleep()`
// D) `std::thread::block()`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q304. A** — `std::thread::sleep(duration)` blocks the current thread for the given duration.
//
// </details>

// %% [markdown]
// ### Q305. What does this code do?
// ```rust
// let handle = std::thread::spawn(|| {
//     println!("Hello from thread");
// });
// handle.join().unwrap();
// ```
//
// A) Compile error: closure may outlive the current function
// B) Spawns a thread, prints, and blocks until the thread finishes
// C) Spawns a thread but never waits for it
// D) Runs synchronously in the main thread
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q305. B** — The closure has no captures, so it's `'static`. `spawn` creates a new thread, and `join().unwrap()` blocks until the thread completes.
//
// </details>

// %% [markdown]
// ### Q306. What is `std::thread::current()` used for?
//
// A) Getting the main thread
// B) Getting a handle to the current thread
// C) Switching to another thread
// D) Creating a new thread
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q306. B** — `std::thread::current()` returns a `Thread` handle representing the current thread.
//
// </details>

// %% [markdown]
// ### Q307. Which trait must a type implement to be safely transferred between threads?
//
// A) `Clone`
// B) `Send`
// C) `Sync`
// D) `Copy`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q307. B** — The `Send` trait indicates that a type can be safely transferred across thread boundaries.
//
// </details>

// %% [markdown]
// ### Q308. What does `std::thread::yield_now()` do?
//
// A) Terminates the current thread
// B) Gives a hint to the scheduler to run other threads
// C) Puts the thread to sleep indefinitely
// D) Joins all other threads
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q308. B** — `yield_now()` suggests to the scheduler that other threads should run. It's a hint, not a guarantee.
//
// </details>

// %% [markdown]
// ### Q309. Why does `Rc<T>` NOT implement `Send`?
//
// A) It's too slow
// B) It uses non-atomic reference counting
// C) It's single-threaded by design
// D) Both B and C
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q309. D** — `Rc` uses non-atomic reference counting and is designed for single-threaded use. Sharing it across threads would cause data races.
//
// </details>

// %% [markdown]
// ### Q310. What is the purpose of `thread::scope` (Rust 1.63+)?
//
// A) To limit thread lifetime to a scope
// B) To allow spawning threads that borrow from the parent without `'static`
// C) To automatically join all spawned threads
// D) Both B and C
//
// <details>
// <summary>Show Answer</summary>
//
// **Q310. D** — `thread::scope` creates a scope where spawned threads can borrow from the parent. All threads are automatically joined when the scope ends.
//
// </details>

// %% [markdown]
// ### Q311. What does `Arc` stand for?
//
// A) Atomic Reference Count
// B) Asynchronous Reference Counter
// C) Automatic Resource Control
// D) Atomic Rust Counter
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q311. A** — `Arc` = Atomic Reference Count. It's the thread-safe version of `Rc`.
//
// </details>

// %% [markdown]
// ### Q312. Which type provides exclusive (write) access and shared (read) access with different semantics?
//
// A) `Mutex<T>`
// B) `RwLock<T>`
// C) `AtomicPtr<T>`
// D) `RefCell<T>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q312. B** — `RwLock<T>` allows multiple readers OR one writer. `Mutex` allows only one holder at a time.
//
// </details>

// %% [markdown]
// ### Q313. What happens when a thread holding a `Mutex` lock panics?
//
// A) The mutex is permanently poisoned
// B) The mutex becomes "poisoned"; subsequent `lock()` returns `Err`
// C) The lock is automatically released
// D) Deadlock occurs
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q313. B** — A poisoned mutex means a thread panicked while holding the lock. `lock()` returns `Err(PoisonError)` to prevent using potentially inconsistent data.
//
// </details>

// %% [markdown]
// ### Q314. Which pattern is commonly used for shared mutable state across threads?
//
// A) `Rc<RefCell<T>>`
// B) `Arc<Mutex<T>>`
// C) `Box<Mutex<T>>`
// D) `Mutex<Arc<T>>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q314. B** — `Arc<Mutex<T>>` is the standard pattern: `Arc` for shared ownership across threads, `Mutex` for interior mutability.
//
// </details>

// %% [markdown]
// ### Q315. What does the `Sync` trait indicate?
//
// A) A type can be sent between threads
// B) A type can be shared between threads via references
// C) A type is thread-safe
// D) A type supports atomic operations
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q315. B** — `Sync` means `&T` is `Send` (safe to share references across threads). `Send` is for transferring ownership.
//
// </details>

// %% [markdown]
// ### Q316. Which atomic type would you use for a lock-free counter?
//
// A) `AtomicBool`
// B) `AtomicUsize`
// C) `AtomicPtr`
// D) `Mutex<usize>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q316. B** — `AtomicUsize` is ideal for lock-free counters. `fetch_add` and similar operations are atomic.
//
// </details>

// %% [markdown]
// ### Q317. What is a deadlock?
//
// A) When a thread panics while holding a lock
// B) When two or more threads wait for each other's locks indefinitely
// C) When a mutex is poisoned
// D) When `join()` is never called
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q317. B** — Deadlock occurs when threads are waiting on each other's locks in a cycle, and none can proceed.
//
// </details>

// %% [markdown]
// ### Q318. Does `Arc<T>` allow mutable access to `T`?
//
// A) Yes, always
// B) No, never
// C) Only if `T` implements `Clone`
// D) Only when wrapped with `Mutex` or `RwLock`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q318. D** — `Arc` provides shared ownership. To mutate, you need interior mutability like `Mutex<T>` or `RwLock<T>` inside.
//
// </details>

// %% [markdown]
// ### Q319. What is the difference between `Mutex::lock()` and `Mutex::try_lock()`?
//
// A) `try_lock` is faster
// B) `try_lock` returns immediately; `lock` blocks until available
// C) `try_lock` works only with `Arc`
// D) There is no difference
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q319. B** — `try_lock()` returns `Err` immediately if the lock is held; `lock()` blocks until the lock is available.
//
// </details>

// %% [markdown]
// ### Q320. Which ordering is typically used for "release" semantics in atomics?
//
// A) `Ordering::Relaxed`
// B) `Ordering::Acquire`
// C) `Ordering::Release`
// D) `Ordering::SeqCst`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q320. C** — `Ordering::Release` ensures previous writes are visible to threads that subsequently acquire the same location.
//
// </details>

// %% [markdown]
// ### Q321. What module provides multi-producer, single-consumer channels?
//
// A) `std::sync::mpsc`
// B) `std::channel`
// C) `std::io::channel`
// D) `std::thread::mpsc`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q321. A** — `std::sync::mpsc` provides the channel API.
//
// </details>

// %% [markdown]
// ### Q322. What does `mpsc` stand for?
//
// A) Multi-process single consumer
// B) Multiple producer single consumer
// C) Message passing sync channel
// D) Mutex-protected sync channel
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q322. B** — mpsc = Multiple Producer, Single Consumer. Multiple senders can send to one receiver.
//
// </details>

// %% [markdown]
// ### Q323. What does `channel()` return?
//
// A) `(Sender<T>, Receiver<T>)`
// B) `(Tx<T>, Rx<T>)`
// C) `Channel<T>`
// D) `Result<(Sender, Receiver), Error>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q323. A** — `channel()` returns `(Sender<T>, Receiver<T>)`.
//
// </details>

// %% [markdown]
// ### Q324. What happens when all `Sender`s are dropped and the `Receiver` tries to `recv()`?
//
// A) Panic
// B) Blocks forever
// C) Returns `Err` (channel disconnected)
// D) Returns `Ok(None)`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q324. C** — When all senders are dropped, the channel is "disconnected." `recv()` returns `Err` indicating no more messages will arrive.
//
// </details>

// %% [markdown]
// ### Q325. Can you clone a `Sender`?
//
// A) No
// B) Yes, `Sender` implements `Clone`
// C) Only with `Arc`
// D) Only for `Sync` types
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q325. B** — `Sender` implements `Clone`. Each clone can send to the same receiver, enabling multiple producers.
//
// </details>

// %% [markdown]
// ### Q326. What is the difference between `sync_channel(0)` and `channel()`?
//
// A) `sync_channel(0)` is unbounded
// B) `sync_channel(0)` has zero buffer; `send()` blocks until `recv()`
// C) `channel()` is synchronous
// D) They are identical
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q326. B** — `sync_channel(0)` is a rendezvous channel: no buffer. `send()` blocks until `recv()` takes the value. `channel()` is unbounded.
//
// </details>

// %% [markdown]
// ### Q327. What does `Receiver::try_recv()` return when the channel is empty?
//
// A) `None`
// B) `Err(Empty)`
// C) `Err(TryRecvError::Empty)`
// D) Blocks until a message arrives
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q327. C** — `try_recv()` returns `Err(TryRecvError::Empty)` when no message is available, or `Err(TryRecvError::Disconnected)` when the channel is closed.
//
// </details>

// %% [markdown]
// ### Q328. Which method on `Receiver` allows iterating over messages until the channel is closed?
//
// A) `iter()`
// B) `Receiver` implements `Iterator`
// C) `recv_iter()`
// D) `messages()`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q328. B** — `Receiver` implements `Iterator`, yielding `Result<T, RecvError>`. Iteration ends when the channel is disconnected.
//
// </details>

// %% [markdown]
// ### Q329. In the "shared state vs message passing" design choice, when is message passing preferred?
//
// A) When you need maximum performance
// B) When you want to avoid locks and ownership transfer of data
// C) When you need shared mutable state
// D) When using only a single thread
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q329. B** — Message passing avoids shared mutable state and locks by transferring ownership of messages. "Do not communicate by sharing memory; share memory by communicating."
//
// </details>

// %% [markdown]
// ### Q330. What does `sync_channel(n)` with `n > 0` provide?
//
// A) Unbounded buffering
// B) A bounded buffer of size `n`; `send()` blocks when full
// C) `n` producers
// D) `n` consumers
//
// <details>
// <summary>Show Answer</summary>
//
// **Q330. B** — `sync_channel(n)` creates a bounded channel. When the buffer has `n` messages, `send()` blocks until space is available.
//
// </details>

// %% [markdown]
// ### Q331. Which crate is the most popular async runtime for Rust?
//
// A) `async-std`
// B) `tokio`
// C) `futures`
// D) `smol`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q331. B** — Tokio is the most widely used async runtime in the Rust ecosystem.
//
// </details>

// %% [markdown]
// ### Q332. What does the `Future` trait represent?
//
// A) A completed value
// B) An asynchronous computation that may produce a value
// C) A synchronous blocking operation
// D) A thread handle
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q332. B** — A `Future` represents an asynchronous computation that may eventually produce a value (or error).
//
// </details>

// %% [markdown]
// ### Q333. What is the key method of the `Future` trait?
//
// A) `run()`
// B) `execute()`
// C) `poll()`
// D) `await()`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q333. C** — The `Future` trait has a `poll` method that the runtime calls to make progress. It returns `Poll::Ready` or `Poll::Pending`.
//
// </details>

// %% [markdown]
// ### Q334. What does `.await` do?
//
// A) Blocks the thread until the future completes
// B) Yields control until the future is ready, without blocking the thread
// C) Spawns a new task
// D) Converts a future to a value
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q334. B** — `.await` suspends the async task and yields to the runtime. The thread can run other tasks; it does not block.
//
// </details>

// %% [markdown]
// ### Q335. Where can you use `.await`?
//
// A) Anywhere in Rust code
// B) Only inside `async` functions or blocks
// C) Only in `main`
// D) Only with `tokio::run`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q335. B** — `.await` can only be used inside an `async fn`, `async` block, or `async` closure.
//
// </details>

// %% [markdown]
// ### Q336. What does `async fn foo() -> T` desugar to?
//
// A) `fn foo() -> T`
// B) `fn foo() -> impl Future<Output = T>`
// C) `fn foo() -> Box<dyn Future<Output = T>>`
// D) `fn foo() -> Pin<Box<dyn Future<Output = T>>>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q336. B** — `async fn foo() -> T` becomes a function that returns `impl Future<Output = T>`.
//
// </details>

// %% [markdown]
// ### Q337. Why does the `Future` trait use `Pin`?
//
// A) For performance
// B) To allow self-referential structs in async
// C) To prevent moving futures
// D) Both B and C
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q337. D** — `Pin` ensures the future is not moved after being polled, which is required for self-referential futures (e.g., holding a reference into the future's own data).
//
// </details>

// %% [markdown]
// ### Q338. What does `Poll::Ready(value)` mean?
//
// A) The future will never complete
// B) The future has completed and produced `value`
// C) The future needs to be polled again
// D) The future was cancelled
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q338. B** — `Poll::Ready(value)` means the future has completed and produced the given value.
//
// </details>

// %% [markdown]
// ### Q339. What does `Poll::Pending` mean?
//
// A) The future has completed
// B) The future is not ready; the task will be woken when progress can be made
// C) The future panicked
// D) The future was dropped
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q339. B** — `Poll::Pending` means the future is not ready. The `Waker` in the `Context` will be used to wake the task when it can make progress.
//
// </details>

// %% [markdown]
// ### Q340. How do you run an async block in tokio?
//
// A) `tokio::run(async { ... })`
// B) `tokio::spawn(async { ... })`
// C) `#[tokio::main] async fn main() { ... }` or `tokio::runtime::Runtime::new().unwrap().block_on(async { ... })`
// D) `async { ... }.await`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q340. C** — You need an async runtime. With tokio, use `#[tokio::main]` on `main` or create a `Runtime` and call `block_on`.
//
// </details>

// %% [markdown]
// ### Q341. What does `#[tokio::main]` do?
//
// A) Marks the function as async
// B) Transforms `main` into an async entry point and runs it on the tokio runtime
// C) Enables multi-threading
// D) Compiles the program for tokio
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q341. B** — `#[tokio::main]` converts `fn main()` into an async main that creates and runs the tokio runtime.
//
// </details>

// %% [markdown]
// ### Q342. What is a "task" in async Rust?
//
// A) A thread
// B) A lightweight unit of work scheduled by the runtime
// C) A future that has completed
// D) A mutex
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q342. B** — A task is a lightweight unit of work. Many tasks can run on few threads; the runtime schedules them.
//
// </details>

// %% [markdown]
// ### Q343. What does `tokio::spawn` return?
//
// A) `JoinHandle<T>`
// B) `Task<T>`
// C) `Future<T>`
// D) `Result<T, JoinError>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q343. A** — `tokio::spawn` returns a `JoinHandle<T>`; call `.await` on it to get the result.
//
// </details>

// %% [markdown]
// ### Q344. Can you use `std::thread::sleep` inside an async function?
//
// A) Yes, it's recommended
// B) No, it will cause a panic
// C) It works but blocks the entire runtime thread
// D) Only with `tokio::task::spawn_blocking`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q344. C** — `std::thread::sleep` blocks the OS thread. In a multi-threaded runtime it blocks one worker; in single-threaded it blocks everything.
//
// </details>

// %% [markdown]
// ### Q345. What should you use instead of `std::thread::sleep` in async code?
//
// A) `tokio::time::sleep()`
// B) `std::thread::sleep` is fine
// C) `futures::future::pending()`
// D) `tokio::sync::Notify`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q345. A** — Use `tokio::time::sleep(duration).await` so the runtime can run other tasks during the delay.
//
// </details>

// %% [markdown]
// ### Q346. What does `tokio::join!(a, b)` do?
//
// A) Runs `a` and `b` sequentially
// B) Runs `a` and `b` concurrently and waits for both to complete
// C) Runs `a` then `b` in parallel
// D) Joins two tasks into one
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q346. B** — `tokio::join!(a, b)` runs both futures concurrently and returns when both complete.
//
// </details>

// %% [markdown]
// ### Q347. What does `tokio::select!` do?
//
// A) Selects the first future to complete
// B) Runs all branches in parallel
// C) Matches on future results
// D) Selects the fastest future
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q347. A** — `select!` waits for the first branch to complete and cancels the others (or runs a default/complete branch).
//
// </details>

// %% [markdown]
// ### Q348. What is `tokio::time::timeout` used for?
//
// A) Setting a maximum duration for a future to complete
// B) Delaying execution
// C) Measuring execution time
// D) Cancelling a task
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q348. A** — `timeout(duration, future)` returns `Err(Elapsed)` if the future doesn't complete within the duration.
//
// </details>

// %% [markdown]
// ### Q349. When should you use `spawn_blocking`?
//
// A) For all async operations
// B) For CPU-intensive or blocking I/O that would block the async runtime
// C) Never
// D) Only for file I/O
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q349. B** — Use `spawn_blocking` for blocking operations (CPU work, blocking I/O) so they don't block the async worker threads.
//
// </details>

// %% [markdown]
// ### Q350. What does `futures::stream::Stream` represent?
//
// A) A single async value
// B) An asynchronous sequence of values
// C) A synchronous iterator
// D) A channel
//
// <details>
// <summary>Show Answer</summary>
//
// **Q350. B** — A `Stream` yields a sequence of values asynchronously, like an async version of `Iterator`.
//
// </details>

// %% [markdown]
// ### Q351. What is `tokio::sync::mpsc` used for?
//
// A) Same as `std::sync::mpsc` but faster
// B) Async message passing between tasks
// C) Multi-process communication
// D) Synchronous channels
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q351. B** — `tokio::sync::mpsc` provides async channels; `send()` and `recv()` return futures that can be awaited.
//
// </details>

// %% [markdown]
// ### Q352. In `tokio::select!`, what does `else` do?
//
// A) Handles errors
// B) Runs when all branches are disabled (e.g., all channels closed)
// C) Default branch
// D) Runs after all branches complete
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q352. B** — The `else` branch runs when all `select!` branches are disabled (e.g., all channels closed). It's required if not all branches can always run.
//
// </details>

// %% [markdown]
// ### Q353. What does `futures::future::select` do?
//
// A) Runs two futures in parallel
// B) Returns when the first future completes, cancelling the other
// C) Selects the faster future
// D) Joins two futures
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q353. B** — `select` runs both futures and returns when one completes, dropping the other.
//
// </details>

// %% [markdown]
// ### Q354. What is `async move`?
//
// A) An async closure that takes ownership of captured variables
// B) A keyword that moves a future
// C) Invalid syntax
// D) Same as `move` in sync closures
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q354. A** — `async move { ... }` creates an async block that takes ownership of captured variables, similar to `move` in closures.
//
// </details>

// %% [markdown]
// ### Q355. Why might an async function need to be `Send`?
//
// A) To be called from sync code
// B) So the future can be sent between threads (e.g., with `tokio::spawn`)
// C) For FFI
// D) To use `.await`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q355. B** — `tokio::spawn` requires the future to be `Send` because the runtime may move it between threads. Async functions produce futures that must be `Send` for this.
//
// </details>

// %% [markdown]
// ### Q356. What does `pin!` macro do (from `tokio`)?
//
// A) Pins a value on the stack for use in async
// B) Pins a value to the heap
// C) Prevents a future from being polled
// D) Locks a mutex
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q356. A** — `pin!` pins a value on the stack, producing a `Pin<&mut T>`, which is needed when you need to poll a future that holds references to itself.
//
// </details>

// %% [markdown]
// ### Q357. What is `FuturesUnordered` used for?
//
// A) Running futures in a specific order
// B) Running many futures concurrently, yielding as each completes
// C) Queuing futures
// D) Cancelling futures
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q357. B** — `FuturesUnordered` runs many futures concurrently and yields results as each completes (like a stream of completions).
//
// </details>

// %% [markdown]
// ### Q358. What does `async_trait` crate provide?
//
// A) A way to define async methods in traits
// B) Automatic async conversion
// C) Async trait objects
// D) Both A and C
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q358. D** — `async_trait` allows `async fn` in trait definitions (which Rust doesn't support natively yet) and helps with async trait objects.
//
// </details>

// %% [markdown]
// ### Q359. What is a "runtime" in async Rust?
//
// A) The Rust compiler
// B) The component that drives futures to completion (polls them, schedules tasks)
// C) The operating system
// D) A test framework
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q359. B** — The runtime (e.g., tokio) is responsible for polling futures, waking tasks, and scheduling work on threads.
//
// </details>

// %% [markdown]
// ### Q360. Can you mix different async runtimes (e.g., tokio and async-std) in one program?
//
// A) Yes, easily
// B) Generally no; runtimes have different types and don't interoperate well
// C) Only with special adapters
// D) Only in tests
//
// <details>
// <summary>Show Answer</summary>
//
// **Q360. B** — Mixing runtimes is difficult; they have different executor types, and futures are often runtime-specific. Stick to one runtime per program.
//
// </details>

// %% [markdown]
// ### Q361. What does `tokio::task::yield_now()` do?
//
// A) Yields the current OS thread
// B) Yields the current async task, allowing other tasks to run
// C) Stops the runtime
// D) Cancels the current task
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q361. B** — `yield_now()` yields the current task so the runtime can run other tasks. It doesn't block the thread.
//
// </details>

// %% [markdown]
// ### Q362. What is `LocalSet` in tokio used for?
//
// A) Running tasks on multiple threads
// B) Running `!Send` tasks on a single thread
// C) Local storage
// D) Process-local state
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q362. B** — `LocalSet` runs tasks that are `!Send` (e.g., holding `Rc`) on a single thread, so they don't need to cross thread boundaries.
//
// </details>

// %% [markdown]
// ### Q363. When do you need `unsafe` in Rust?
//
// A) Never; Rust is always safe
// B) When doing operations the compiler cannot verify (raw pointers, FFI, etc.)
// C) For all I/O operations
// D) Only in `no_std` code
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q363. B** — `unsafe` is used when you need to do things the type system can't verify: raw pointers, FFI, implementing unsafe traits, etc.
//
// </details>

// %% [markdown]
// ### Q364. What can you do inside an `unsafe` block that you cannot do in safe Rust?
//
// A) Use `println!`
// B) Dereference raw pointers, call unsafe functions, implement unsafe traits
// C) Use `mut`
// D) Create references
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q364. B** — Inside `unsafe` you can dereference raw pointers, call `unsafe fn`, implement `unsafe trait`, access mutable statics, etc.
//
// </details>

// %% [markdown]
// ### Q365. What are raw pointers `*const T` and `*mut T`?
//
// A) References that can be null
// B) Pointer types with no automatic cleanup; dereferencing requires `unsafe`
// C) Same as `&T` and `&mut T`
// D) Only used for FFI
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q365. B** — Raw pointers have no ownership semantics, can be null, and dereferencing them is `unsafe` because it can cause UB.
//
// </details>

// %% [markdown]
// ### Q366. What does `unsafe fn` mean?
//
// A) The function may panic
// B) The function can only be called from `unsafe` blocks
// C) The function makes safety guarantees that the compiler cannot verify; callers must ensure preconditions
// D) The function is deprecated
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q366. C** — An `unsafe fn` has a contract that callers must uphold. Calling it is `unsafe` because the compiler can't check that.
//
// </details>

// %% [markdown]
// ### Q367. What is an `unsafe trait`?
//
// A) A trait that may panic
// B) A trait whose implementors must uphold invariants the compiler cannot check
// C) A trait that cannot be used in generic code
// D) A trait with unsafe methods
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q367. B** — An `unsafe trait` has invariants that implementors must maintain. Implementing it is `unsafe`.
//
// </details>

// %% [markdown]
// ### Q368. What does `extern "C"` indicate?
//
// A) A C-compatible function (for FFI)
// B) A function written in C
// C) A function that cannot be inlined
// D) A C-style struct
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q368. A** — `extern "C"` defines a function with C calling convention for FFI (calling C from Rust or vice versa).
//
// </details>

// %% [markdown]
// ### Q369. What is `std::ptr::null()`?
//
// A) A null reference
// B) A null raw pointer
// C) Invalid; Rust has no null
// D) A default value for `Option`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q369. B** — `std::ptr::null()` creates a null raw pointer. References in Rust cannot be null; use `Option<&T>` for optional references.
//
// </details>

// %% [markdown]
// ### Q370. When implementing `Send` or `Sync` manually, why is it `unsafe`?
//
// A) Because it's a system trait
// B) Because you are asserting thread-safety invariants the compiler cannot verify
// C) Because it involves raw pointers
// D) It's not unsafe
//
// <details>
// <summary>Show Answer</summary>
//
// **Q370. B** — `Send` and `Sync` are `unsafe trait`s. Implementing them means you guarantee thread-safety, which the compiler cannot verify.
//
// </details>

// %% [markdown]
// ### Q371. What does `#[repr(C)]` do?
//
// A) Makes a struct faster
// B) Ensures the struct has a C-compatible memory layout for FFI
// C) Enables C inheritance
// D) Marks the struct as unsafe
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q371. B** — `#[repr(C)]` gives the struct a predictable layout matching C, so it can be shared with C code via FFI.
//
// </details>

// %% [markdown]
// ### Q372. What is a declarative macro defined with?
//
// A) `macro`
// B) `macro_rules!`
// C) `decl_macro!`
// D) `define_macro!`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q372. B** — Declarative macros are defined with `macro_rules! name { ... }`.
//
// </details>

// %% [markdown]
// ### Q373. What fragment specifier matches an expression?
//
// A) `:stmt`
// B) `:expr`
// C) `:ident`
// D) `:block`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q373. B** — `:expr` matches an expression. Other specifiers: `:ident` (identifier), `:ty` (type), `:stmt` (statement), etc.
//
// </details>

// %% [markdown]
// ### Q374. What are the three kinds of procedural macros?
//
// A) `macro!`, `fn!`, `trait!`
// B) Custom derive, attribute macros, function-like macros
// C) Declarative, procedural, hybrid
// D) `derive`, `attr`, `fn`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q374. B** — Procedural macros: (1) Custom derive, (2) Attribute macros, (3) Function-like macros.
//
// </details>

// %% [markdown]
// ### Q375. What does a custom derive macro do?
//
// A) Derives a trait implementation from the struct's fields
// B) Creates a new struct
// C) Modifies function bodies
// D) Generates tests
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q375. A** — A derive macro (e.g., `#[derive(Debug)]`) generates a trait implementation based on the struct's structure.
//
// </details>

// %% [markdown]
// ### Q376. What does an attribute macro receive as input?
//
// A) The item's name only
// B) The attributes and the annotated item
// C) Only the attributes
// D) A token stream
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q376. D** — Attribute macros receive a `TokenStream` of the attribute arguments and the annotated item. They output a new `TokenStream`.
//
// </details>

// %% [markdown]
// ### Q377. What is macro hygiene?
//
// A) Keeping macros clean
// B) Macros not accidentally capturing or conflicting with identifiers from the call site
// C) Sanitizing macro inputs
// D) Preventing macro expansion
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q377. B** — Hygiene means macros use their own namespaces so they don't accidentally capture or conflict with variables at the call site.
//
// </details>

// %% [markdown]
// ### Q378. Which crate is commonly used for writing procedural macros?
//
// A) `macro`
// B) `syn` and `quote`
// C) `proc_macro` only
// D) `macro_rules`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q378. B** — `syn` parses Rust code into AST; `quote` turns AST back into tokens. Together they're the standard for proc macros.
//
// </details>

// %% [markdown]
// ### Q379. What does `$($x:expr),*` mean in a macro?
//
// A) One expression
// B) Zero or more expressions separated by commas
// C) One or more expressions
// D) A tuple of expressions
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q379. B** — `$($x:expr),*` matches zero or more comma-separated expressions. `*` = zero or more; `+` = one or more.
//
// </details>

// %% [markdown]
// ### Q380. Where must procedural macros be defined?
//
// A) In the same crate as the code that uses them
// B) In a separate crate with `proc-macro = true` in Cargo.toml
// C) In lib.rs only
// D) Anywhere
//
// <details>
// <summary>Show Answer</summary>
//
// **Q380. B** — Proc macros must be in a crate with `[lib] proc-macro = true` in Cargo.toml. They can't be in the same crate as the code that uses them in some configurations.
//
// </details>

// %% [markdown]
// ### Q381. What does `#[derive(Clone)]` generate?
//
// A) A `clone()` method that does a deep copy
// B) A `clone()` method that does a shallow copy (or delegates to field `clone`s)
// C) A `copy()` implementation
// D) A `Clone` trait that must be implemented manually
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q381. B** — `#[derive(Clone)]` generates a `clone()` that clones each field. For `Copy` types it's a shallow copy; for others it depends on their `clone`.
//
// </details>

// %% [markdown]
// ### Q382. How do you run tests in a Rust project?
//
// A) `rustc --test`
// B) `cargo test`
// C) `cargo run --test`
// D) `rust test`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q382. B** — `cargo test` compiles and runs all tests (unit and integration).
//
// </details>

// %% [markdown]
// ### Q383. What attribute marks a function as a test?
//
// A) `#[test_case]`
// B) `#[test]`
// C) `#[bench]`
// D) `#[unit_test]`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q383. B** — `#[test]` marks a function as a test. The function must have signature `fn() -> ()` (or `Result`).
//
// </details>

// %% [markdown]
// ### Q384. What does `#[should_panic]` do?
//
// A) Makes the test panic
// B) The test passes only if it panics
// C) Suppresses panic output
// D) Marks the test as expected to fail
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q384. B** — `#[should_panic]` means the test passes if it panics. If it doesn't panic, the test fails.
//
// </details>

// %% [markdown]
// ### Q385. Where do integration tests go by default?
//
// A) In the same file as the code
// B) In `tests/` directory at the crate root
// C) In `src/tests/`
// D) In `benches/`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q385. B** — Integration tests go in `tests/` at the project root. Each file is compiled as a separate crate.
//
// </details>

// %% [markdown]
// ### Q386. How do you run a specific test by name?
//
// A) `cargo test test_name`
// B) `cargo test -- test_name`
// C) `cargo test -n test_name`
// D) `cargo test --filter test_name`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q386. A** — `cargo test test_name` runs tests whose names contain `test_name`. Use `cargo test -- test_name` for more control.
//
// </details>

// %% [markdown]
// ### Q387. What does `#[ignore]` do on a test?
//
// A) Fails the test
// B) Skips the test unless run with `cargo test -- --ignored`
// C) Hides the test from output
// D) Marks it as flaky
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q387. B** — `#[ignore]` skips the test by default. Run with `cargo test -- --ignored` to run only ignored tests.
//
// </details>

// %% [markdown]
// ### Q388. What is the difference between unit tests and integration tests?
//
// A) Unit tests are faster
// B) Unit tests are in the same file and can test private items; integration tests are in `tests/` and use the crate as an external user
// C) Integration tests run in separate processes
// D) There is no difference
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q388. B** — Unit tests live in the source, often in a `#[cfg(test)]` module, and can access private items. Integration tests are in `tests/` and use the crate's public API.
//
// </details>

// %% [markdown]
// ### Q389. What does `assert_eq!(a, b)` do on failure?
//
// A) Panics with a message showing `a` and `b`
// B) Returns `Err`
// C) Prints a warning
// D) Continues execution
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q389. A** — `assert_eq!` panics on failure, printing the values of both arguments (they must implement `Debug`).
//
// </details>

// %% [markdown]
// ### Q390. How do you test private functions?
//
// A) You cannot
// B) Use `pub(crate)` or put tests in the same module
// C) Use `#[test]` on the function
// D) Use `cargo test --private`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q390. B** — Put tests in the same module (e.g., `#[cfg(test)] mod tests`) to access private items, or use `pub(crate)` for limited visibility.
//
// </details>

// %% [markdown]
// ### Q391. What does `#[should_panic(expected = "message")]` do?
//
// A) The test must panic with a message containing "message"
// B) The test prints "message" on panic
// C) The test expects the string "message" as input
// D) Invalid attribute
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q391. A** — `expected = "message"` means the panic message must contain that substring. The test fails if it panics with a different message or doesn't panic.
//
// </details>

// %% [markdown]
// ### Q392. How can a test return a `Result`?
//
// A) Tests cannot return `Result`
// B) Use `#[test] fn foo() -> Result<(), E> { ... }` and `?` operator
// C) Use `assert!(result.is_ok())`
// D) Wrap in `Ok(())`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q392. B** — Since Rust 1.34, tests can return `Result<(), E>`. Returning `Err` fails the test. The `?` operator works for propagating errors.
//
// </details>

// %% [markdown]
// ### Q393. What does `cargo test --no-run` do?
//
// A) Runs tests without output
// B) Compiles tests but does not run them
// C) Skips tests
// D) Runs tests in release mode
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q393. B** — `cargo test --no-run` compiles the test binary but does not execute it.
//
// </details>

// %% [markdown]
// ### Q394. What is `#[cfg(test)]` used for?
//
// A) Marking test functions
// B) Including code only when compiling tests
// C) Enabling test mode
// D) Skipping tests in CI
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q394. B** — `#[cfg(test)]` includes the module or item only when `cargo test` is run. Used for test helpers and test-only code.
//
// </details>

// %% [markdown]
// ### Q395. What does `doc(test)` do?
//
// A) Documents tests
// B) Ensures doc comments compile as tests (doctests)
// C) Marks documentation as tested
// D) Generates test docs
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q395. B** — `doc(test)` (in `#![doc(test(...))]`) configures how doctests are run. Doctests are code blocks in doc comments that get compiled and run as tests.
//
// </details>

// %% [markdown]
// ### Q396. Which trait is automatically implemented for types that implement `Send + Sync`?
//
// A) `Send` and `Sync` are independent
// B) `Sync` implies `Send` for references
// C) `&T` is `Send` if `T: Sync`
// D) Both B and C
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q396. C** — `T: Sync` means `&T: Send`. So sharing `&T` across threads is safe when `T` is `Sync`. `Send` and `Sync` are separate traits.
//
// </details>

// %% [markdown]
// ### Q397. What does `std::mem::forget` do?
//
// A) Frees memory
// B) Prevents a value's destructor from running (safe but can leak)
// C) Zeros memory
// D) Drops a value
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q397. B** — `std::mem::forget` takes ownership and never runs the destructor. It's safe but can cause leaks (e.g., of memory or other resources).
//
// </details>

// %% [markdown]
// ### Q398. What is `Box::leak` used for?
//
// A) Causing a memory leak for testing
// B) Converting `Box<T>` to `&'static T` (leaks the allocation)
// C) Releasing memory
// D) Detecting leaks
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q398. B** — `Box::leak` consumes the `Box` and returns `&'static T`. The allocation is never freed, so it's a deliberate leak for static-like data.
//
// </details>

// %% [markdown]
// ### Q399. What does `std::hint::spin_loop` do?
//
// A) Busy-waits indefinitely
// B) Gives a hint to the CPU that we're in a spin-wait (can improve power/performance)
// C) Yields to the scheduler
// D) Sleeps
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q399. B** — `spin_loop` emits a hint (e.g., `pause` on x86) that can reduce power and improve performance in spin-wait loops.
//
// </details>

// %% [markdown]
// ### Q400. Which macro is used for compile-time assertion?
//
// A) `assert!`
// B) `debug_assert!`
// C) `static_assert!`
// D) Rust uses `const_assert!` or `const` with `assert!` in const context
//
// <details>
// <summary>Show Answer</summary>
//
// **Q400. D** — Rust doesn't have `static_assert!`. Use `const _: () = assert!(condition);` in a const context, or the `static_assertions` crate's `const_assert!`.
//
// </details>
