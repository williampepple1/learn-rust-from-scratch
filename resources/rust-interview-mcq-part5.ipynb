// %% [markdown]
// # 🦀 Rust Interview MCQ — Part 5: Ecosystem, Web, Systems & Mixed (Q401–Q500)
//
// **500 Multiple-Choice Questions for Rust Interview Preparation**
//
// Each question has 4 options (A–D) with the correct answer and explanation immediately below.
//
// ---

// %% [markdown]
// ### Q401. In `Cargo.toml`, what does `[dependencies]` with `serde = { version = "1.0", features = ["derive"] }` mean?
//
// A) serde is optional and only compiled when requested
// B) serde version 1.0 is required with the "derive" feature enabled
// C) serde has two separate dependencies: 1.0 and derive
// D) The derive feature overrides version 1.0
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q401. B** — The inline table syntax specifies version 1.0 and enables the "derive" feature, which provides `#[derive(Serialize, Deserialize)]`.
//
// </details>

// %% [markdown]
// ### Q402. What does `cargo publish --dry-run` do?
//
// A) Publishes to a test registry only
// B) Validates the package without uploading
// C) Publishes with a temporary version
// D) Skips documentation generation
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q402. B** — `--dry-run` checks the package (validates Cargo.toml, builds, etc.) without actually uploading to the registry.
//
// </details>

// %% [markdown]
// ### Q403. In a Cargo workspace, how do you add a member crate?
//
// ```toml
// [workspace]
// members = ["crate-a", "crate-b"]
// ```
//
// A) The members must be in subdirectories with the same names
// B) The members can be anywhere; paths are relative to the workspace root
// C) Each member needs its own `[workspace]` section
// D) Workspace members cannot have their own Cargo.toml
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q403. A** — Workspace members are typically subdirectories; each must have a `Cargo.toml` and the path is relative to the workspace root.
//
// </details>

// %% [markdown]
// ### Q404. Semantic versioning in Rust: a crate goes from `1.2.3` to `1.3.0`. What changed?
//
// A) Patch: bug fixes only
// B) Minor: new backward-compatible functionality
// C) Major: breaking changes
// D) Pre-release version
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q404. B** — In semver, MAJOR.MINOR.PATCH: 1.3.0 indicates a minor version bump (new backward-compatible features).
//
// </details>

// %% [markdown]
// ### Q405. What does `cargo tree` show?
//
// A) The directory structure of the project
// B) The dependency graph of all crates
// C) The AST of the main binary
// D) Test execution order
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q405. B** — `cargo tree` displays the dependency graph showing all crates and their versions.
//
// </details>

// %% [markdown]
// ### Q406. In Cargo.toml, `optional = true` on a dependency means:
//
// A) The dependency is never compiled
// B) The dependency is only compiled when a feature enables it
// C) The dependency version is flexible
// D) The dependency is for development only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q406. B** — Optional dependencies are only compiled when a feature that lists them is enabled.
//
// </details>

// %% [markdown]
// ### Q407. What is the purpose of `[patch]` in Cargo.toml?
//
// A) To patch source code before compilation
// B) To override a dependency with a local or git version
// C) To apply security patches automatically
// D) To patch the Rust compiler
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q407. B** — `[patch]` overrides a dependency, e.g. to use a local path or a git branch for testing fixes.
//
// </details>

// %% [markdown]
// ### Q408. Which Cargo command builds in release mode with optimizations?
//
// A) `cargo build --optimize`
// B) `cargo build --release`
// C) `cargo build -O`
// D) `cargo release`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q408. B** — `cargo build --release` uses the release profile with optimizations enabled.
//
// </details>

// %% [markdown]
// ### Q409. What does `cargo doc --open` do?
//
// A) Opens the project in an editor
// B) Builds documentation and opens it in a browser
// C) Opens crates.io in a browser
// D) Generates and opens a dependency report
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q409. B** — Builds the documentation for the crate and its dependencies, then opens it in the default browser.
//
// </details>

// %% [markdown]
// ### Q410. To publish a crate to crates.io, you need:
//
// A) A GitHub account only
// B) A crates.io account and `cargo login` with an API token
// C) To run `cargo publish` without authentication
// D) A verified email and paid subscription
//
// <details>
// <summary>Show Answer</summary>
//
// **Q410. B** — You need a crates.io account, generate an API token, and run `cargo login <token>` before publishing.
//
// </details>

// %% [markdown]
// ### Q411. What does `pub(crate)` mean?
//
// A) Public to the entire crate
// B) Public only to the current module
// C) Public to the parent module
// D) Deprecated; use `pub` instead
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q411. A** — `pub(crate)` makes an item visible to the entire crate but not outside it.
//
// </details>

// %% [markdown]
// ### Q412. In `mod foo { pub fn bar() {} }`, where is `bar` visible?
//
// A) Only inside `foo`
// B) Anywhere the `foo` module is visible
// C) Only in the parent of `foo`
// D) Nowhere; it's private
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q412. B** — `pub fn` is visible wherever the `foo` module is accessible.
//
// </details>

// %% [markdown]
// ### Q413. What does `use crate::utils::helper;` do?
//
// A) Imports the `crate` module
// B) Imports `helper` from the `utils` module (crate root relative)
// C) Imports from an external crate named `utils`
// D) Creates a new module `utils::helper`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q413. B** — `crate::` is the crate root; this imports `helper` from `utils`.
//
// </details>

// %% [markdown]
// ### Q414. `pub use self::inner::Item;` is an example of:
//
// A) Re-export
// B) Circular import
// C) Private use
// D) Module alias
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q414. A** — Re-exporting makes `Item` available to users of the current module as if it were defined there.
//
// </details>

// %% [markdown]
// ### Q415. What does `super::` refer to?
//
// A) The crate root
// B) The parent module
// C) A module named "super"
// D) The standard library
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q415. B** — `super` refers to the parent module (one level up in the hierarchy).
//
// </details>

// %% [markdown]
// ### Q416. For `src/lib.rs` with `mod foo;`, where does Rust look for the `foo` module?
//
// A) `src/foo.rs` or `src/foo/mod.rs`
// B) `foo.rs` in the project root
// C) `src/foo/mod.rs` only
// D) `lib/foo.rs`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q416. A** — Rust looks for `src/foo.rs` or `src/foo/mod.rs` for `mod foo;`.
//
// </details>

// %% [markdown]
// ### Q417. What is the default visibility of items in a module?
//
// A) `pub`
// B) `pub(crate)`
// C) Private (visible only within the module and its children)
// D) `pub(super)`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q417. C** — Items are private by default; they're visible only within the module and its submodules.
//
// </details>

// %% [markdown]
// ### Q418. `use std::collections::{HashMap, HashSet};` does what?
//
// A) Imports only HashMap
// B) Imports HashMap and HashSet from std::collections
// C) Imports the collections module
// D) Imports HashMap and re-exports HashSet
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q418. B** — The brace syntax imports multiple items from the same path.
//
// </details>

// %% [markdown]
// ### Q419. In a binary crate, what is the default entry point?
//
// A) `src/main.rs` with `fn main()`
// B) `src/lib.rs` with `fn main()`
// C) `main.rs` in project root
// D) Any file with `#![main]` attribute
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q419. A** — Binary crates use `src/main.rs` and `fn main()` as the entry point.
//
// </details>

// %% [markdown]
// ### Q420. What does `#[path = "custom/path.rs"] mod foo;` do?
//
// A) Changes the module's logical path
// B) Specifies a custom file path for the module
// C) Imports from an external path
// D) Sets the module's visibility path
//
// <details>
// <summary>Show Answer</summary>
//
// **Q420. B** — The `#[path]` attribute overrides the default file location for the module.
//
// </details>

// %% [markdown]
// ### Q421. `HashMap<K, V>` vs `BTreeMap<K, V>`: when to use BTreeMap?
//
// A) When you need faster random access
// B) When you need keys in sorted order or range queries
// C) When K doesn't implement Hash
// D) BTreeMap is always slower; avoid it
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q421. B** — BTreeMap keeps keys sorted and supports range queries; HashMap is faster for simple lookups.
//
// </details>

// %% [markdown]
// ### Q422. What does `map.entry(key).or_insert(value)` do?
//
// A) Inserts value and panics if key exists
// B) Returns the value for key, or inserts value if absent
// C) Replaces the value if key exists
// D) Removes the key and returns the old value
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q422. B** — The Entry API: `or_insert` inserts the value only if the key is absent, then returns a mutable reference.
//
// </details>

// %% [markdown]
// ### Q423. `VecDeque` is useful when:
//
// A) You need a sorted vector
// B) You need efficient push/pop from both ends
// C) You need key-value storage
// D) You need a heap structure
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q423. B** — VecDeque is a double-ended queue with O(1) push/pop at both ends.
//
// </details>

// %% [markdown]
// ### Q424. `BinaryHeap<T>` returns elements in what order?
//
// A) Insertion order
// B) Sorted order (ascending)
// C) Max-heap order (largest first, by Ord)
// D) Random order
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q424. C** — BinaryHeap is a max-heap; `pop()` returns the largest element (by Ord).
//
// </details>

// %% [markdown]
// ### Q425. What does `HashSet::difference(&other)` return?
//
// A) Elements in self but not in other
// B) Elements in both sets
// C) Elements in either set
// D) A new HashSet with the difference
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q425. A** — `difference` yields elements in self that are not in other.
//
// </details>

// %% [markdown]
// ### Q426. For `let mut v: Vec<i32> = vec![1, 2, 3]; v.reserve(10);`, what happens?
//
// A) v grows to length 10
// B) Capacity increases by at least 10
// C) v is truncated to 10 elements
// D) Nothing; reserve is a no-op for Vec
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q426. B** — `reserve` ensures capacity for at least `len + 10` more elements without reallocating.
//
// </details>

// %% [markdown]
// ### Q427. `BTreeSet` requires its elements to implement:
//
// A) `Hash + Eq`
// B) `Ord`
// C) `Copy`
// D) `Default`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q427. B** — BTreeSet requires Ord for ordering; HashSet requires Hash + Eq.
//
// </details>

// %% [markdown]
// ### Q428. What does `vec.retain(|x| *x > 0)` do?
//
// A) Returns a new Vec with filtered elements
// B) Keeps only elements for which the predicate is true (in-place)
// C) Removes the first matching element
// D) Sorts the vector
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q428. B** — `retain` keeps elements in-place where the predicate returns true.
//
// </details>

// %% [markdown]
// ### Q429. `HashMap::get(&key)` returns:
//
// A) `Option<&V>`
// B) `Option<V>`
// C) `&V` (panics if absent)
// D) `Result<V, NotFound>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q429. A** — `get` returns `Option<&V>`; None if the key is absent.
//
// </details>

// %% [markdown]
// ### Q430. To use a custom type as HashMap key, it must implement:
//
// A) `Eq + Hash`
// B) `Ord`
// C) `Clone + Copy`
// D) `Serialize + Deserialize`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q430. A** — HashMap keys need Eq and Hash; BTreeMap keys need Ord.
//
// </details>

// %% [markdown]
// ### Q431. What does `iter.zip(other_iter)` produce?
//
// A) A concatenation of both iterators
// B) An iterator of pairs (a, b) from both
// C) An iterator that alternates elements
// D) The Cartesian product
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q431. B** — zip pairs elements from two iterators; stops when the shorter one ends.
//
// </details>

// %% [markdown]
// ### Q432. `flat_map` is equivalent to:
//
// A) `map` then `flatten`
// B) `filter` then `map`
// C) `map` then `filter`
// D) `chain` of two iterators
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q432. A** — flat_map(f) is equivalent to map(f).flatten(); it maps each element to an iterator and flattens.
//
// </details>

// %% [markdown]
// ### Q433. What does `fold(init, |acc, x| ...)` do?
//
// A) Reduces to a single value by repeatedly applying a function
// B) Folds the iterator in half
// C) Applies a function to each element
// D) Collects into a Vec
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q433. A** — fold accumulates: starts with init, applies the closure to (acc, x) for each x, returns final acc.
//
// </details>

// %% [markdown]
// ### Q434. `scan(init, |state, x| ...)` differs from `fold` in that:
//
// A) scan is lazy, fold is eager
// B) scan yields intermediate results; fold yields only the final value
// C) scan requires Copy
// D) There is no difference
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q434. B** — scan yields each intermediate state as an Option; fold only returns the final accumulator.
//
// </details>

// %% [markdown]
// ### Q435. `iter.chain(other)` produces:
//
// A) Pairs of elements
// B) Elements from iter, then elements from other
// C) Only elements in both
// D) Interleaved elements
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q435. B** — chain concatenates: first all elements from iter, then all from other.
//
// </details>

// %% [markdown]
// ### Q436. `peekable()` allows you to:
//
// A) Look at the next element without consuming it
// B) Skip elements
// C) Reverse the iterator
// D) Clone the iterator
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q436. A** — peekable() adds peek() to look at the next element without advancing.
//
// </details>

// %% [markdown]
// ### Q437. `slice.windows(3)` on `[1,2,3,4,5]` yields:
//
// A) `[1], [2], [3], [4], [5]`
// B) `[1,2,3], [2,3,4], [3,4,5]`
// C) `[1,2,3], [4,5]`
// D) `[1,2,3,4,5]`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q437. B** — windows(n) yields overlapping slices of size n: [1,2,3], [2,3,4], [3,4,5].
//
// </details>

// %% [markdown]
// ### Q438. `enumerate()` on an iterator produces:
//
// A) (index, value) pairs
// B) (value, index) pairs
// C) Only indices
// D) A counted iterator
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q438. A** — enumerate() yields (0, first), (1, second), etc.
//
// </details>

// %% [markdown]
// ### Q439. `iter.rev()` requires the iterator to implement:
//
// A) `Clone`
// B) `DoubleEndedIterator`
// C) `ExactSizeIterator`
// D) `FusedIterator`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q439. B** — rev() requires DoubleEndedIterator to iterate from the back.
//
// </details>

// %% [markdown]
// ### Q440. What does `try_fold` return?
//
// A) `Result<Acc, E>` — can short-circuit on Err
// B) Same as fold
// C) `Option<Acc>`
// D) `(Acc, bool)` where bool indicates early exit
//
// <details>
// <summary>Show Answer</summary>
//
// **Q440. A** — try_fold short-circuits on Err (or other Try types); used by ? in iterator chains.
//
// </details>

// %% [markdown]
// ### Q441. `std::fs::read_to_string(path)` returns:
//
// A) `String`
// B) `Result<String, std::io::Error>`
// C) `Vec<u8>`
// D) `Option<String>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q441. B** — read_to_string returns Result<String, io::Error>; it can fail for I/O or UTF-8 errors.
//
// </details>

// %% [markdown]
// ### Q442. Why use `BufReader` when reading a file?
//
// A) To compress the file
// B) To buffer reads and reduce syscalls
// C) To read in reverse
// D) To enable random access
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q442. B** — BufReader buffers reads to reduce the number of system calls for better performance.
//
// </details>

// %% [markdown]
// ### Q443. `std::env::args()` returns:
//
// A) `Vec<String>`
// B) `Args` (iterator of String)
// C) `Option<String>`
// D) `&[String]`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q443. B** — args() returns Args, an iterator over the program arguments (including program name).
//
// </details>

// %% [markdown]
// ### Q444. With clap, `#[arg(short, long)]` on a field means:
//
// A) The argument is required
// B) The argument can be passed as `-s` or `--long-name`
// C) The argument is short and long
// D) The argument has a default value
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q444. B** — short enables -s, long enables --long-name for the argument.
//
// </details>

// %% [markdown]
// ### Q445. `OpenOptions::new().append(true).open(path)` opens the file for:
//
// A) Reading only
// B) Writing, truncating existing content
// C) Appending to the end
// D) Read and write
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q445. C** — append(true) opens for appending; writes go to the end without truncating.
//
// </details>

// %% [markdown]
// ### Q446. `std::io::stdin().lock()` returns:
//
// A) A locked handle to stdin
// B) A MutexGuard
// C) A static reference
// D) An error if stdin is not available
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q446. A** — lock() returns StdinLock, a locked handle that implements Read for efficient line-by-line reading.
//
// </details>

// %% [markdown]
// ### Q447. `fs::metadata(path)` gives you:
//
// A) File contents
// B) File metadata (size, permissions, etc.) without following symlinks
// C) Only file size
// D) Symlink target
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q447. B** — metadata returns Metadata (size, permissions, etc.); use symlink_metadata to avoid following symlinks.
//
// </details>

// %% [markdown]
// ### Q448. `Read` trait's `read_to_string(&mut self, buf: &mut String)` does what?
//
// A) Replaces buf with file contents
// B) Appends read bytes (as UTF-8) to buf
// C) Reads exactly buf.len() bytes
// D) Reads until newline
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q448. B** — read_to_string appends all read bytes (interpreted as UTF-8) to the String.
//
// </details>

// %% [markdown]
// ### Q449. `std::env::var("KEY")` returns:
//
// A) `String`
// B) `Result<String, VarError>`
// C) `Option<String>`
// D) `&'static str`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q449. B** — var returns Result<String, VarError>; Err if the variable is unset or not valid UTF-8.
//
// </details>

// %% [markdown]
// ### Q450. `fs::create_dir_all(path)`:
//
// A) Creates only the final directory
// B) Creates the directory and all parent directories
// C) Creates all directories in path as siblings
// D) Fails if any parent doesn't exist
//
// <details>
// <summary>Show Answer</summary>
//
// **Q450. B** — create_dir_all creates all directories in the path, like mkdir -p.
//
// </details>

// %% [markdown]
// ### Q451. To derive `Serialize` and `Deserialize`, you need:
//
// A) `#[derive(Serialize, Deserialize)]` with serde and the "derive" feature
// B) Only `#[derive(Serialize)]`
// C) Manual impl of both traits
// D) The serde_json crate only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q451. A** — You need serde with the "derive" feature: serde = { version = "1.0", features = ["derive"] }.
//
// </details>

// %% [markdown]
// ### Q452. `#[serde(rename = "snake_case")]` does what?
//
// A) Renames the struct
// B) Serializes the field with snake_case name
// C) Converts values to snake_case
// D) Applies to enum variants only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q452. B** — rename changes the key used in the serialized format (e.g. "myField" -> "my_field").
//
// </details>

// %% [markdown]
// ### Q453. `serde_json::from_str::<T>(s)` returns:
//
// A) `T`
// B) `Result<T, serde_json::Error>`
// C) `Option<T>`
// D) `String`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q453. B** — from_str returns Result<T, Error>; it can fail on invalid JSON or type mismatch.
//
// </details>

// %% [markdown]
// ### Q454. `#[serde(skip)]` on a field means:
//
// A) Skip during serialization only
// B) Skip during deserialization only
// C) Skip during both (field not in JSON)
// D) Use default value when missing
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q454. C** — skip means the field is omitted from serialization and deserialization.
//
// </details>

// %% [markdown]
// ### Q455. `#[serde(default)]` on a field:
//
// A) Uses Default::default() when the field is missing during deserialization
// B) Makes the field optional
// C) Uses empty string for strings
// D) Skips the field
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q455. A** — default uses Default::default() when the key is absent during deserialization.
//
// </details>

// %% [markdown]
// ### Q456. `toml::to_string(&value)` serializes to:
//
// A) JSON
// B) TOML format
// C) YAML
// D) Binary
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q456. B** — toml::to_string produces TOML format; toml::from_str parses it.
//
// </details>

// %% [markdown]
// ### Q457. For `#[serde(flatten)]`, what happens?
//
// A) The field is serialized as a nested object
// B) The field's contents are flattened into the parent
// C) The field is ignored
// D) The field is serialized as an array
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q457. B** — flatten merges the field's keys into the parent object (useful for embedding structs).
//
// </details>

// %% [markdown]
// ### Q458. `serde_json::Value` represents:
//
// A) Any valid JSON value
// B) Only JSON objects
// C) Only JSON strings
// D) A parsed JSON document
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q458. A** — Value is an enum (Null, Bool, Number, String, Array, Object) representing any JSON value.
//
// </details>

// %% [markdown]
// ### Q459. `#[serde(serialize_with = "...")]` allows:
//
// A) Custom serialization logic for that field
// B) Only built-in formats
// C) Skipping serialization
// D) Renaming the field
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q459. A** — serialize_with lets you specify a custom function for serializing that field.
//
// </details>

// %% [markdown]
// ### Q460. To deserialize `"true"` (string) into `bool`, you might use:
//
// A) `#[serde(deserialize_with = "...")]` with a custom function
// B) `#[serde(from = "String")]`
// C) `TryFrom` implementation
// D) All of the above can work
//
// <details>
// <summary>Show Answer</summary>
//
// **Q460. D** — All can work: deserialize_with, From/TryFrom, or custom logic.
//
// </details>

// %% [markdown]
// ### Q461. In Axum, `Router::new().route("/", get(handler))` does what?
//
// A) Registers a GET handler for the root path
// B) Registers a POST handler
// C) Creates a redirect
// D) Serves static files
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q461. A** — route("/", get(handler)) registers a GET handler for "/".
//
// </details>

// %% [markdown]
// ### Q462. `reqwest::get(url).await` returns:
//
// A) `String`
// B) `Result<Response, Error>`
// C) `Response` directly
// D) `Option<Response>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q462. B** — reqwest is async; get returns a Future that resolves to Result<Response, Error>.
//
// </details>

// %% [markdown]
// ### Q463. In Axum, an extractor like `Json<T>` in a handler:
//
// A) Automatically deserializes the request body into T
// B) Serializes the response
// C) Validates headers only
// D) Extracts query parameters
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q463. A** — Json<T> extracts the body, parses JSON, and deserializes into T.
//
// </details>

// %% [markdown]
// ### Q464. Axum middleware is typically added via:
//
// A) `router.layer(middleware)`
// B) `router.middleware(middleware)`
// C) `app.use(middleware)`
// D) In the handler signature
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q464. A** — layer() adds middleware (tower::Layer) to the router.
//
// </details>

// %% [markdown]
// ### Q465. `axum::extract::Path(params)` extracts:
//
// A) Query string parameters
// B) Path parameters (e.g. /users/:id)
// C) Request headers
// D) Form data
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q465. B** — Path extracts dynamic path segments, e.g. "/users/:id" -> Path((id,)).
//
// </details>

// %% [markdown]
// ### Q466. For a JSON API, `axum::Json` requires the type to implement:
//
// A) `Serialize` for responses, `Deserialize` for request bodies
// B) `Clone`
// C) `Send + Sync`
// D) `Default`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q466. A** — Responses need Serialize; request bodies need Deserialize (both for JSON).
//
// </details>

// %% [markdown]
// ### Q467. `reqwest::Client::new()` should typically be:
//
// A) Created per request
// B) Reused (e.g. once per app) for connection pooling
// C) Created in each handler
// D) A global static
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q467. B** — Reusing Client enables connection pooling and better performance.
//
// </details>

// %% [markdown]
// ### Q468. In Actix-web, `web::Json<T>` for a handler parameter:
//
// A) Extracts and deserializes JSON body into T
// B) Returns JSON
// C) Validates JSON schema
// D) Parses query params as JSON
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q468. A** — web::Json<T> extracts and deserializes the request body.
//
// </details>

// %% [markdown]
// ### Q469. Axum's `State<S>` extractor:
//
// A) Extracts application state shared across handlers
// B) Extracts HTTP state headers
// C) Returns the server state
// D) Is for session state only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q469. A** — State<S> gives access to shared state passed to Router::with_state.
//
// </details>

// %% [markdown]
// ### Q470. To return a 404 in Axum, you typically:
//
// A) `return (StatusCode::NOT_FOUND, "Not found")`
// B) panic!
// C) `Err(StatusCode::NOT_FOUND)`
// D) Use `axum::response::NotFound`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q470. A** — Return a tuple (StatusCode, impl IntoResponse) or use StatusCode::NOT_FOUND.into_response().
//
// </details>

// %% [markdown]
// ### Q471. `rusqlite::Connection::open(path)` returns:
//
// A) `Connection`
// B) `Result<Connection, rusqlite::Error>`
// C) `Option<Connection>`
// D) A file handle
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q471. B** — Connection::open returns Result<Connection, Error>; it can fail if the file can't be opened.
//
// </details>

// %% [markdown]
// ### Q472. `tokio::net::TcpListener::bind(addr).await` returns:
//
// A) `TcpStream`
// B) `Result<TcpListener, std::io::Error>`
// C) `TcpListener` directly
// D) `Option<TcpListener>`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q472. B** — bind returns Result<TcpListener, io::Error>; use .await in async context.
//
// </details>

// %% [markdown]
// ### Q473. To accept incoming TCP connections, you call:
//
// A) `listener.accept().await`
// B) `listener.recv().await`
// C) `listener.connect().await`
// D) `listener.listen().await`
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q473. A** — accept() yields (TcpStream, SocketAddr) for each incoming connection.
//
// </details>

// %% [markdown]
// ### Q474. `TcpStream::connect(addr).await`:
//
// A) Binds to the address
// B) Initiates a connection to the remote address
// C) Listens on the address
// D) Closes the stream
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q474. B** — connect() initiates an outbound TCP connection to the given address.
//
// </details>

// %% [markdown]
// ### Q475. With rusqlite, `conn.execute("INSERT INTO t (a) VALUES (?1)", [value])`:
//
// A) Uses ?1 as a named parameter
// B) Binds value to the first placeholder
// C) Executes without parameters
// D) Uses value as table name
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q475. B** — ?1, ?2, etc. are positional parameters; the array binds values in order.
//
// </details>

// %% [markdown]
// ### Q476. `tokio::io::AsyncReadExt::read_to_string` is used to:
//
// A) Read bytes into a String
// B) Read a file synchronously
// C) Parse JSON
// D) Read headers only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q476. A** — read_to_string reads all bytes and interprets them as UTF-8 into a String.
//
// </details>

// %% [markdown]
// ### Q477. For a simple request-response TCP protocol, you typically:
//
// A) Send raw bytes with no framing
// B) Use a framing strategy (length-prefix, delimiters, etc.)
// C) Use HTTP only
// D) Use UDP
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q477. B** — You need framing (e.g. length-prefix or newline-delimited) to know message boundaries.
//
// </details>

// %% [markdown]
// ### Q478. `rusqlite::params!` macro:
//
// A) Creates a params array for execute/query
// B) Defines table parameters
// C) Validates SQL
// D) Escapes strings
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q478. A** — params! creates a value suitable for execute/query parameter binding.
//
// </details>

// %% [markdown]
// ### Q479. `TcpStream` implements:
//
// A) `AsyncRead` and `AsyncWrite`
// B) `Read` and `Write` only
// C) `Stream` only
// D) `Future` only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q479. A** — TcpStream implements AsyncRead and AsyncWrite for async I/O.
//
// </details>

// %% [markdown]
// ### Q480. To run SQL with rusqlite and iterate rows:
//
// A) `conn.prepare("SELECT ...")?.query_map([], |row| ...)`
// B) `conn.query("SELECT ...")`
// C) `conn.execute("SELECT ...")`
// D) `conn.fetch("SELECT ...")`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q480. A** — prepare() + query_map() lets you execute and map each row with a closure.
//
// </details>

// %% [markdown]
// ### Q481. `cargo bench` runs benchmarks if you have:
//
// A) A `[[bench]]` section in Cargo.toml
// B) Any test functions
// C) A bench.rs file
// D) The criterion crate only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q481. A** — [[bench]] defines benchmark targets; cargo bench runs them (or use criterion in tests).
//
// </details>

// %% [markdown]
// ### Q482. `const fn` can be evaluated:
//
// A) Only at runtime
// B) At compile time (in const contexts)
// C) Never; it's deprecated
// D) Only in tests
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q482. B** — const fn can be evaluated at compile time in const contexts (const, static, array lengths).
//
// </details>

// %% [markdown]
// ### Q483. LTO (Link Time Optimization) in Cargo.toml:
//
// A) Optimizes across crate boundaries
// B) Only optimizes within a single file
// C) Is enabled by default in debug
// D) Reduces binary size only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q483. A** — LTO performs optimizations across compilation units (crate boundaries).
//
// </details>

// %% [markdown]
// ### Q484. `#[inline(always)]` suggests:
//
// A) The compiler should never inline
// B) The compiler should always inline (strong hint)
// C) Inline assembly
// D) Inline documentation
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q484. B** — #[inline(always)] strongly suggests inlining; #[inline] is a hint.
//
// </details>

// %% [markdown]
// ### Q485. SIMD in Rust is typically used via:
//
// A) `std::simd` (portable SIMD) or `core::arch`
// B) `simd` crate only
// C) Inline assembly only
// D) LLVM automatically; no explicit API
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q485. A** — std::simd (nightly) and core::arch for target-specific intrinsics.
//
// </details>

// %% [markdown]
// ### Q486. `profile.release` in Cargo.toml can set:
//
// A) `opt-level = 3`, `lto = true`, `codegen-units = 1`
// B) Only opt-level
// C) Only for dev profile
// D) Nothing; profiles are fixed
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q486. A** — [profile.release] can customize opt-level, lto, codegen-units, etc.
//
// </details>

// %% [markdown]
// ### Q487. `codegen-units = 1` in release profile:
//
// A) Enables better optimizations (slower compile)
// B) Speeds up compilation
// C) Reduces binary size only
// D) Is the default
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q487. A** — codegen-units=1 improves optimization but slows compilation (default is 16).
//
// </details>

// %% [markdown]
// ### Q488. For profiling Rust programs, common tools include:
//
// A) perf, flamegraph, cargo-flamegraph
// B) Only gdb
// C) Only println!
// D) valgrind only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q488. A** — perf, flamegraph, cargo-flamegraph, and others are commonly used.
//
// </details>

// %% [markdown]
// ### Q489. `#[cold]` on a function hints:
//
// A) The function is rarely called (optimize for size)
// B) The function is hot (optimize for speed)
// C) The function uses cold storage
// D) The function is deprecated
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q489. A** — #[cold] hints the function is unlikely; compiler may optimize for size.
//
// </details>

// %% [markdown]
// ### Q490. `std::hint::black_box(x)` is used to:
//
// A) Prevent the compiler from optimizing away x in benchmarks
// B) Convert x to black color
// C) Mark x as unused
// D) Serialize x
//
// <details>
// <summary>Show Answer</summary>
//
// **Q490. A** — black_box prevents optimization away of values in benchmarks for accurate timing.
//
// </details>

// %% [markdown]
// ### Q491. `#![no_std]` means:
//
// A) The crate does not use the standard library
// B) The crate has no main
// C) The crate is std-only
// D) Disables core library
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q491. A** — no_std omits the standard library; you use core (and optionally alloc) for embedded/WASM.
//
// </details>

// %% [markdown]
// ### Q492. For WebAssembly (WASM) targets, you typically use:
//
// A) `wasm-pack` and `wasm-bindgen`
// B) Only rustc
// C) Only cargo
// D) A separate WASM compiler
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q492. A** — wasm-pack and wasm-bindgen are the standard tools for Rust-to-WASM with JS interop.
//
// </details>

// %% [markdown]
// ### Q493. `extern "C"` in Rust is used for:
//
// A) Defining C-callable functions (FFI)
// B) Importing C code
// C) Both declaring external C functions and defining Rust functions callable from C
// D) Only for unsafe blocks
//
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q493. C** — extern "C" declares C ABI; used for both calling C from Rust and exposing Rust to C.
//
// </details>

// %% [markdown]
// ### Q494. `PhantomData<T>` is used when:
//
// A) You need to store a T
// B) You want to express a type relationship without owning T
// C) T is a phantom type
// D) For zero-sized types only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q494. B** — PhantomData<T> is zero-sized; it tells the compiler about type relationships (e.g. variance, Send) without storing T.
//
// </details>

// %% [markdown]
// ### Q495. The builder pattern in Rust is idiomatic when:
//
// A) You have many optional parameters
// B) You need inheritance
// C) You want to avoid structs
// D) For single-argument constructors
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q495. A** — Builder pattern is idiomatic for configurable structs with many optional fields.
//
// </details>

// %% [markdown]
// ### Q496. `impl Trait` in return position means:
//
// A) Return a concrete type that implements Trait (opaque)
// B) Return the Trait object
// C) Return any type
// D) Return a generic
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q496. A** — impl Trait in return position returns an opaque type implementing Trait (like a type alias).
//
// </details>

// %% [markdown]
// ### Q497. `?` operator can be used in functions that return:
//
// A) `Result<T, E>` or `Option<T>` (or types that implement Try)
// B) Only Result
// C) Any type
// D) Only in main
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q497. A** — ? works with Result, Option, and any type implementing the Try trait.
//
// </details>

// %% [markdown]
// ### Q498. `Arc<Mutex<T>>` is used when:
//
// A) Sharing mutable state across threads
// B) Single-threaded only
// C) Immutable shared state
// D) For Send types only
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q498. A** — Arc enables shared ownership across threads; Mutex provides interior mutability for safe mutation.
//
// </details>

// %% [markdown]
// ### Q499. In idiomatic Rust, error handling prefers:
//
// A) Result and ? over unwrap/expect in library code
// B) panic! everywhere
// C) Option only
// D) Exceptions
//
//
// <details>
// <summary>Show Answer</summary>
//
// **Q499. A** — Idiomatic Rust uses Result and ? for recoverable errors; panic for unrecoverable cases.
//
// </details>

// %% [markdown]
// ### Q500. (Capstone) A production Rust web service uses: Axum for HTTP, tokio for async, serde for JSON, and a shared `Arc<DbPool>` for database connections. Which concept best ties these together?
//
// A) The service combines async I/O, type-safe extractors, serialization, and thread-safe shared state — showcasing Rust's strengths: zero-cost abstractions, fearless concurrency, and strong typing across the stack
// B) Only async/await
// C) Only the type system
// D) Only memory safety
//
// <details>
// <summary>Show Answer</summary>
//
// **Q500. A** — The capstone ties together async I/O, type-safe APIs, serialization, and shared state — demonstrating Rust's ecosystem and design philosophy.
//
// </details>

// %% [markdown]
// ---
//
// ## 🎉 Congratulations!
//
// You've completed all **500 Rust interview questions**!
//
// ### Score Guide
// - **400-500 correct**: Expert — you're ready for senior Rust positions
// - **300-399 correct**: Advanced — strong foundation, review weak areas
// - **200-299 correct**: Intermediate — good progress, keep practicing
// - **100-199 correct**: Beginner — review the fundamentals
// - **0-99 correct**: Just starting — work through the learning materials first
//
// **Good luck with your Rust interviews!** 🦀
