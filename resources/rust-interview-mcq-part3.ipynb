// %% [markdown]
// # 🦀 Rust Interview MCQ — Part 3: Traits, Generics & Error Handling (Q201–Q300)
//
// **500 Multiple-Choice Questions for Rust Interview Preparation**
//
// Each question has 4 options (A–D) with the correct answer and explanation immediately below.
//
// ---

// %% [markdown]
// ### Q201. Which keyword is used to define a trait in Rust?
// - A) `interface`
// - B) `trait`
// - C) `protocol`
// - D) `abstract`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q201. B)** `trait`. Traits define shared behavior, similar to interfaces in other languages.
//
// </details>

// %% [markdown]
// ### Q202. What does the `impl` keyword do when used with a trait?
// - A) Declares a new trait
// - B) Implements trait methods for a type
// - C) Imports a trait from another crate
// - D) Defines a trait bound
//
// <details>
// <summary>Show Answer</summary>
//
// **Q202. B)** Implements trait methods for a type. `impl Trait for Type` provides the implementation.
//
// </details>

// %% [markdown]
// ### Q203. Which of the following is valid trait definition syntax?
// - A) `trait Foo { fn bar(); }`
// - B) `trait Foo { fn bar() -> Self; }`
// - C) Both A and B
// - D) Neither—traits cannot have methods
//
// <details>
// <summary>Show Answer</summary>
//
// **Q203. C)** Both A and B. Traits can have methods with or without return types (including `Self`).
//
// </details>

// %% [markdown]
// ### Q204. What is a default method in a trait?
// - A) A method that must be overridden by implementors
// - B) A method with a body that implementors can optionally override
// - C) A method that only works with default type parameters
// - D) A deprecated method
//
// <details>
// <summary>Show Answer</summary>
//
// **Q204. B)** A method with a body that implementors can optionally override. Default methods have `{ }` with implementation.
//
// </details>

// %% [markdown]
// ### Q205. How do you implement multiple traits for the same type?
// - A) `impl Trait1, Trait2 for Type { }`
// - B) Use separate `impl Trait1 for Type` and `impl Trait2 for Type` blocks
// - C) `impl Trait1 + Trait2 for Type { }`
// - D) Traits cannot be combined for one type
//
// <details>
// <summary>Show Answer</summary>
//
// **Q205. B)** Use separate `impl Trait1 for Type` and `impl Trait2 for Type` blocks. Each trait gets its own impl block.
//
// </details>

// %% [markdown]
// ### Q206. What does the orphan rule restrict?
// - A) You cannot implement a trait for a type unless either the trait or the type is defined in your crate
// - B) You cannot have orphan types in Rust
// - C) You cannot implement traits for generic types
// - D) You cannot implement traits from stdlib
//
// <details>
// <summary>Show Answer</summary>
//
// **Q206. A)** You cannot implement a trait for a type unless either the trait or the type is defined in your crate. This prevents conflicting implementations.
//
// </details>

// %% [markdown]
// ### Q207. What does trait inheritance (supertrait) syntax look like?
// - A) `trait Child : Parent { }`
// - B) `trait Child extends Parent { }`
// - C) `trait Child : Parent + Other { }`
// - D) Both A and C
//
// <details>
// <summary>Show Answer</summary>
//
// **Q207. D)** Both A and C. `trait Child : Parent` and `trait Child : Parent + Other` are valid supertrait syntax.
//
// </details>

// %% [markdown]
// ### Q208. In `impl Trait for Type`, what does `Self` refer to?
// - A) The trait being implemented
// - B) The type being implemented for
// - C) The current module
// - D) The parent trait
//
// <details>
// <summary>Show Answer</summary>
//
// **Q208. B)** The type being implemented for. `Self` is an alias for the implementing type.
//
// </details>

// %% [markdown]
// ### Q209. Can a trait have associated constants?
// - A) No, only methods
// - B) Yes, with `const NAME: Type`
// - C) Only in nightly Rust
// - D) Yes, but they must be overridden
//
// <details>
// <summary>Show Answer</summary>
//
// **Q209. B)** Yes, with `const NAME: Type`. Traits can have associated constants, types, and methods.
//
// </details>

// %% [markdown]
// ### Q210. What does `impl Trait` as a return type mean?
// - A) Returns a concrete type that implements the trait (opaque type)
// - B) Returns the trait itself
// - C) Returns a generic type
// - D) Returns a trait object
//
// <details>
// <summary>Show Answer</summary>
//
// **Q210. A)** Returns a concrete type that implements the trait (opaque type). The caller knows it implements the trait but not the concrete type.
//
// </details>

// %% [markdown]
// ### Q211. Which trait is required for `println!("{}", x)` to work?
// - A) `Debug`
// - B) `Display`
// - C) `ToString`
// - D) `Print`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q211. B)** `Display`. The `{}` format specifier uses `Display`; `{:?}` uses `Debug`.
//
// </details>

// %% [markdown]
// ### Q212. What does `#[derive(Debug)]` provide?
// - A) Human-readable output for `{:?}` and `{:#?}`
// - B) Compile-time debugging symbols
// - C) Runtime debug assertions
// - D) Stack trace on panic
//
// <details>
// <summary>Show Answer</summary>
//
// **Q212. A)** Human-readable output for `{:?}` and `{:#?}`. `Debug` is used for debugging output.
//
// </details>

// %% [markdown]
// ### Q213. What is the difference between `Clone` and `Copy`?
// - A) `Copy` is a superset of `Clone`
// - B) `Copy` implies trivial bitwise copy; `Clone` can have custom logic
// - C) `Clone` is for references, `Copy` is for values
// - D) They are identical
//
// <details>
// <summary>Show Answer</summary>
//
// **Q213. B)** `Copy` implies trivial bitwise copy (no custom logic); `Clone` can have custom clone logic. `Copy` types implicitly implement `Clone`.
//
// </details>

// %% [markdown]
// ### Q214. Why can't `String` implement `Copy`?
// - A) It's in the standard library
// - B) It contains heap-allocated data; copying would be expensive and ambiguous
// - C) It implements `Clone` instead
// - D) `Copy` is only for primitive types
//
// <details>
// <summary>Show Answer</summary>
//
// **Q214. B)** It contains heap-allocated data; copying would be expensive and ambiguous (would it clone the buffer or share it?).
//
// </details>

// %% [markdown]
// ### Q215. What does `PartialEq` require that `Eq` adds?
// - A) `Eq` adds reflexivity: `a == a` for all `a`
// - B) `Eq` adds commutativity
// - C) `Eq` adds transitivity
// - D) `Eq` is a marker with no extra requirements
//
// <details>
// <summary>Show Answer</summary>
//
// **Q215. A)** `Eq` adds reflexivity: `a == a` for all `a`. `PartialEq` allows `NaN != NaN`; `Eq` does not.
//
// </details>

// %% [markdown]
// ### Q216. When would you use `Hash`?
// - A) For types used as keys in `HashMap` or in `HashSet`
// - B) For cryptographic hashing
// - C) For checksums
// - D) For serialization
//
// <details>
// <summary>Show Answer</summary>
//
// **Q216. A)** For types used as keys in `HashMap` or in `HashSet`. Types with `Hash` can be hashed consistently.
//
// </details>

// %% [markdown]
// ### Q217. What does `Default` provide?
// - A) A way to create a default instance with `Default::default()` or `Type::default()`
// - B) Default method implementations in traits
// - C) Default function parameters
// - D) Fallback values for Option
//
// <details>
// <summary>Show Answer</summary>
//
// **Q217. A)** A way to create a default instance with `Default::default()` or `Type::default()`.
//
// </details>

// %% [markdown]
// ### Q218. If you implement `From<T> for U`, what do you get for free?
// - A) `Into<U>` for `T`
// - B) `TryFrom` for `U`
// - C) `AsRef<U>` for `T`
// - D) Nothing—you must implement both
//
// <details>
// <summary>Show Answer</summary>
//
// **Q218. A)** `Into<U>` for `T`. Implementing `From` automatically provides the blanket `Into` implementation.
//
// </details>

// %% [markdown]
// ### Q219. What does the `Iterator` trait's `Item` represent?
// - A) The number of items
// - B) The type of each yielded element
// - C) The index type
// - D) The iterator's state
//
// <details>
// <summary>Show Answer</summary>
//
// **Q219. B)** The type of each yielded element. `Item` is an associated type of the `Iterator` trait.
//
// </details>

// %% [markdown]
// ### Q220. Which method is required when implementing `Iterator`?
// - A) `next()`
// - B) `iter()`
// - C) `into_iter()`
// - D) `collect()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q220. A)** `next()`. The `Iterator` trait only requires implementing `next()`; other methods have default implementations.
//
// </details>

// %% [markdown]
// ### Q221. What does this generic function signature mean: `fn foo<T>(x: T) -> T`?
// - A) `T` must be `Copy`
// - B) `foo` works with any type `T`, and returns a value of the same type
// - C) `T` must be `Clone`
// - D) `T` is a trait
//
// <details>
// <summary>Show Answer</summary>
//
// **Q221. B)** `foo` works with any type `T`, and returns a value of the same type. No trait bounds means minimal requirements.
//
// </details>

// %% [markdown]
// ### Q222. How do you constrain a generic `T` to types that implement `Display`?
// - A) `fn foo<T: Display>(x: T)`
// - B) `fn foo<T where T: Display>(x: T)`
// - C) Both A and B
// - D) `fn foo<T impl Display>(x: T)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q222. C)** Both A and B. `T: Display` and `where T: Display` are valid trait bound syntaxes.
//
// </details>

// %% [markdown]
// ### Q223. What is a `where` clause used for?
// - A) To specify the crate where a type comes from
// - B) To add trait bounds when the signature would be too long
// - C) To define local variables
// - D) To specify module paths
//
// <details>
// <summary>Show Answer</summary>
//
// **Q223. B)** To add trait bounds when the signature would be too long. `where` clauses improve readability.
//
// </details>

// %% [markdown]
// ### Q224. Can a struct have generic type parameters?
// - A) No, only functions
// - B) Yes, e.g. `struct Foo<T> { x: T }`
// - C) Only with `impl` blocks
// - D) Yes, but only one parameter
//
// <details>
// <summary>Show Answer</summary>
//
// **Q224. B)** Yes, e.g. `struct Foo<T> { x: T }`. Structs, enums, and functions can all be generic.
//
// </details>

// %% [markdown]
// ### Q225. What does `impl<T> Foo<T>` mean?
// - A) `Foo` implements `T`
// - B) Implementation for `Foo` for any type `T`
// - C) `T` implements `Foo`
// - D) Generic implementation block for `Foo`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q225. D)** Generic implementation block for `Foo`. `impl<T> Foo<T>` provides methods for `Foo` with any `T`.
//
// </details>

// %% [markdown]
// ### Q226. What is `impl Trait` in argument position (e.g. `fn foo(x: impl Display)`)?
// - A) Accepts a trait object
// - B) Accepts any type that implements the trait (syntactic sugar for a generic)
// - C) Accepts only `Display` type
// - D) Invalid syntax
//
// <details>
// <summary>Show Answer</summary>
//
// **Q226. B)** Accepts any type that implements the trait. It's syntactic sugar for a generic with a trait bound.
//
// </details>

// %% [markdown]
// ### Q227. What is the difference between `fn f<T: Display>(x: T)` and `fn f(x: impl Display)`?
// - A) No difference; they are equivalent
// - B) `impl Display` cannot be used as return type in the same function
// - C) With `T`, you can use `T` in multiple parameters and enforce same type
// - D) Both B and C
//
// <details>
// <summary>Show Answer</summary>
//
// **Q227. C)** With `T`, you can use `T` in multiple parameters and enforce the same type (e.g. `fn f(a: T, b: T)`). With `impl Display`, each parameter could be a different type.
//
// </details>

// %% [markdown]
// ### Q228. Can enums have generic parameters?
// - A) No
// - B) Yes, e.g. `enum Result<T, E> { Ok(T), Err(E) }`
// - C) Only in nightly
// - D) Only for `Option` and `Result`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q228. B)** Yes, e.g. `enum Result<T, E> { Ok(T), Err(E) }`. Enums commonly use generics.
//
// </details>

// %% [markdown]
// ### Q229. What does `T: Clone + Display` mean?
// - A) `T` implements both `Clone` and `Display`
// - B) `T` implements `Clone` or `Display`
// - C) `T` is a tuple of `(Clone, Display)`
// - D) Invalid syntax
//
// <details>
// <summary>Show Answer</summary>
//
// **Q229. A)** `T` implements both `Clone` and `Display`. The `+` combines trait bounds.
//
// </details>

// %% [markdown]
// ### Q230. In `fn foo<T, U>(t: T, u: U) where T: Display, U: Debug`, what are the bounds?
// - A) `T` and `U` must both implement `Display` and `Debug`
// - B) `T` must implement `Display`, `U` must implement `Debug`
// - C) At least one of `T` or `U` must implement both
// - D) Invalid—cannot have multiple generics with different bounds
//
// <details>
// <summary>Show Answer</summary>
//
// **Q230. B)** `T` must implement `Display`, `U` must implement `Debug`. Each generic has its own bounds.
//
// </details>

// %% [markdown]
// ### Q231. What is an associated type in a trait?
// - A) A type that is associated with a module
// - B) A type specified by the implementor instead of the caller (e.g. `Iterator::Item`)
// - C) A type parameter of the trait
// - D) A type alias
//
// <details>
// <summary>Show Answer</summary>
//
// **Q231. B)** A type specified by the implementor instead of the caller. `Iterator::Item` is chosen per type, not per call.
//
// </details>

// %% [markdown]
// ### Q232. Why use associated types instead of generic traits? `trait Iter<T> { fn next(&mut self) -> Option<T>; }` vs `trait Iterator { type Item; fn next(&mut self) -> Option<Self::Item>; }`
// - A) Associated types are faster
// - B) With generics, a type could implement `Iter<i32>` and `Iter<String>`; with associated types, one `Item` per impl
// - C) Associated types are required by the compiler
// - D) No practical difference
//
// <details>
// <summary>Show Answer</summary>
//
// **Q232. B)** With generics, a type could implement `Iter<i32>` and `Iter<String>`; with associated types, there is one `Item` per impl, simplifying usage.
//
// </details>

// %% [markdown]
// ### Q233. Which traits allow overloading the `+` operator?
// - A) `Add`
// - B) `AddAssign`
// - C) `std::ops::Add`
// - D) Both A and C (they are the same)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q233. D)** Both A and C. `Add` is in `std::ops::Add`; they refer to the same trait.
//
// </details>

// %% [markdown]
// ### Q234. What does `Deref` provide?
// - A) Deep copy semantics
// - B) Custom dereference behavior (e.g. `*x` for smart pointers)
// - C) Reference conversion
// - D) Destructuring
//
// <details>
// <summary>Show Answer</summary>
//
// **Q234. B)** Custom dereference behavior. Smart pointers like `Box<T>` implement `Deref` so `*boxed` gives `T`.
//
// </details>

// %% [markdown]
// ### Q235. What is deref coercion?
// - A) Converting `&T` to `&U` when `T: Deref<Target = U>`
// - B) Converting `T` to `U`
// - C) Converting `Box<T>` to `T`
// - D) A compiler bug
//
// <details>
// <summary>Show Answer</summary>
//
// **Q235. A)** Converting `&T` to `&U` when `T: Deref<Target = U>`. E.g. `&String` coerces to `&str`.
//
// </details>

// %% [markdown]
// ### Q236. What is a trait object (e.g. `dyn Trait`)?
// - A) A generic type
// - B) A value that can hold any type implementing the trait, using dynamic dispatch
// - C) A trait definition
// - D) An enum
//
// <details>
// <summary>Show Answer</summary>
//
// **Q236. B)** A value that can hold any type implementing the trait, using dynamic dispatch (vtable).
//
// </details>

// %% [markdown]
// ### Q237. What does "object safety" mean for traits?
// - A) The trait is safe to use
// - B) The trait can be used as a trait object (`dyn Trait`); it must not have methods that return `Self` or have generic methods
// - C) The trait has no unsafe code
// - D) The trait is thread-safe
//
// <details>
// <summary>Show Answer</summary>
//
// **Q237. B)** The trait can be used as a trait object; it must not have methods that return `Self` or have generic methods.
//
// </details>

// %% [markdown]
// ### Q238. Why can't `Clone` be used as `dyn Clone` easily?
// - A) It's not in std
// - B) `clone()` returns `Self`, which is not object-safe
// - C) It requires `Copy`
// - D) It has generic methods
//
// <details>
// <summary>Show Answer</summary>
//
// **Q238. B)** `clone()` returns `Self`, which is not object-safe. The compiler cannot know the size of `Self` at compile time for `dyn Clone`.
//
// </details>

// %% [markdown]
// ### Q239. What does `DerefMut` add over `Deref`?
// - A) Nothing—they are the same
// - B) Mutable dereference: `*x` when `x` is `&mut T`
// - C) Multiple dereference levels
// - D) Dereference for references only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q239. B)** Mutable dereference. `DerefMut` is used when you need `*x = value` through a smart pointer.
//
// </details>

// %% [markdown]
// ### Q240. Which syntax creates a trait object?
// - A) `Box<dyn Display>`
// - B) `&dyn Display`
// - C) Both A and B
// - D) `impl Display`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q240. C)** Both A and B. Trait objects can be behind `Box`, `&`, `&mut`, etc.
//
// </details>

// %% [markdown]
// ### Q241. What does `Result<T, E>` represent?
// - A) A value that might be absent
// - B) A computation that can succeed with `T` or fail with `E`
// - C) A tuple of two values
// - D) An error only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q241. B)** A computation that can succeed with `T` or fail with `E`. `Ok(T)` or `Err(E)`.
//
// </details>

// %% [markdown]
// ### Q242. What does `Option<T>` represent?
// - A) A required value of type `T`
// - B) An optional value: `Some(T)` or `None`
// - C) A default value
// - D) A result type
//
// <details>
// <summary>Show Answer</summary>
//
// **Q242. B)** An optional value: `Some(T)` or `None`. Used when a value might be absent.
//
// </details>

// %% [markdown]
// ### Q243. What does the `?` operator do?
// - A) Returns the value if `Ok`, or propagates the error to the caller
// - B) Unwraps the value, panicking on error
// - C) Converts `Option` to `Result`
// - D) Checks for null
//
// <details>
// <summary>Show Answer</summary>
//
// **Q243. A)** Returns the value if `Ok`, or propagates the error to the caller. Requires the function to return `Result` or `Option`.
//
// </details>

// %% [markdown]
// ### Q244. What is the difference between `unwrap()` and `expect(msg)`?
// - A) No difference
// - B) `expect` lets you provide a custom panic message
// - C) `unwrap` is for `Option`, `expect` is for `Result`
// - D) `expect` never panics
//
// <details>
// <summary>Show Answer</summary>
//
// **Q244. B)** `expect` lets you provide a custom panic message. Both panic on `None`/`Err`.
//
// </details>

// %% [markdown]
// ### Q245. What does `result.map(|x| x + 1)` do?
// - A) Adds 1 to the error
// - B) If `Ok(v)`, produces `Ok(v + 1)`; if `Err`, passes through
// - C) Unwraps and adds 1
// - D) Panics on `Err`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q245. B)** If `Ok(v)`, produces `Ok(v + 1)`; if `Err`, passes through unchanged.
//
// </details>

// %% [markdown]
// ### Q246. What does `result.and_then(|x| Ok(x + 1))` do?
// - A) Same as `map`
// - B) Chains computations that return `Result`; flattens nested `Result`s
// - C) Only works with `Option`
// - D) Runs in a separate thread
//
// <details>
// <summary>Show Answer</summary>
//
// **Q246. B)** Chains computations that return `Result`; flattens nested `Result`s. The closure returns `Result`, not a raw value.
//
// </details>

// %% [markdown]
// ### Q247. When should you use `unwrap()` in production code?
// - A) Always—it's the idiomatic way
// - B) Rarely; prefer `?` or proper error handling
// - C) Only for `Option`
// - D) Never
//
// <details>
// <summary>Show Answer</summary>
//
// **Q247. B)** Rarely; prefer `?` or proper error handling. `unwrap` is for prototypes or when you're certain.
//
// </details>

// %% [markdown]
// ### Q248. What does `option.unwrap_or(default)` do?
// - A) Unwraps or panics with `default` message
// - B) Returns the value if `Some`, otherwise returns `default`
// - C) Swaps `Some` and `None`
// - D) Converts to `Result`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q248. B)** Returns the value if `Some`, otherwise returns `default`. Provides a fallback without panicking.
//
// </details>

// %% [markdown]
// ### Q249. What does `result.map_err(|e| MyError::from(e))` do?
// - A) Maps the success value
// - B) Maps the error value, converting it to another error type
// - C) Ignores the error
// - D) Panics on error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q249. B)** Maps the error value, converting it to another error type. Useful for error conversion chains.
//
// </details>

// %% [markdown]
// ### Q250. Can the `?` operator be used in `main()`?
// - A) Yes, always
// - B) No, never
// - C) Yes, if `main()` returns `Result<(), E>` where `E` implements `Debug` (or use `Box<dyn Error>`)
// - D) Only in test functions
//
// <details>
// <summary>Show Answer</summary>
//
// **Q250. C)** Yes, if `main()` returns `Result<(), E>` (Rust 1.26+). The error type must implement `Termination` (e.g. `Debug`, `Display`, `Box<dyn Error>`).
//
// </details>

// %% [markdown]
// ### Q251. What does `thiserror` typically provide?
// - A) Runtime error handling
// - B) Derive macro for custom error types with `#[derive(thiserror::Error)]`
// - C) Global error handler
// - D) Error logging
//
// <details>
// <summary>Show Answer</summary>
//
// **Q251. B)** Derive macro for custom error types with `#[derive(thiserror::Error)]`. Reduces boilerplate for error types.
//
// </details>

// %% [markdown]
// ### Q252. What does `anyhow` typically provide?
// - A) Strongly typed errors
// - B) `anyhow::Result<T>` for application-level code where you don't care about the exact error type
// - C) Compile-time error checking
// - D) Error serialization
//
// <details>
// <summary>Show Answer</summary>
//
// **Q252. B)** `anyhow::Result<T>` for application-level code where you don't care about the exact error type. Good for binaries.
//
// </details>

// %% [markdown]
// ### Q253. If you implement `From<OtherError> for MyError`, what does that enable?
// - A) Converting `OtherError` to `MyError` with `?` operator automatically
// - B) Cloning errors
// - C) Comparing errors
// - D) Logging errors
//
// <details>
// <summary>Show Answer</summary>
//
// **Q253. A)** Converting `OtherError` to `MyError` with `?` operator automatically. The `?` operator uses `From` for conversion.
//
// </details>

// %% [markdown]
// ### Q254. What is an error chain?
// - A) A linked list of errors
// - B) A sequence of errors caused by each other (e.g. via `source()`)
// - C) A chain of `Result` types
// - D) A macro for error handling
//
// <details>
// <summary>Show Answer</summary>
//
// **Q254. B)** A sequence of errors caused by each other. The `Error::source()` method traverses the chain.
//
// </details>

// %% [markdown]
// ### Q255. When should you use `panic!` vs returning `Result`?
// - A) Always use `panic!`
// - B) Use `panic!` for unrecoverable bugs; use `Result` for expected failures
// - C) Always use `Result`
// - D) Use `panic!` in libraries, `Result` in applications
//
// <details>
// <summary>Show Answer</summary>
//
// **Q255. B)** Use `panic!` for unrecoverable bugs (programmer errors); use `Result` for expected failures (user input, I/O).
//
// </details>

// %% [markdown]
// ### Q256. What does `#[derive(Debug)]` on an error type enable?
// - A) Pretty printing for `{:?}`
// - B) The `Error` trait
// - C) `Display` implementation
// - D) Serialization
//
// <details>
// <summary>Show Answer</summary>
//
// **Q256. A)** Pretty printing for `{:?}`. The `Error` trait requires `Debug`; `thiserror` derives it.
//
// </details>

// %% [markdown]
// ### Q257. What is the `std::error::Error` trait's `source()` method for?
// - A) Getting the error message
// - B) Getting the underlying cause of the error (error chain)
// - C) Getting the file and line number
// - D) Getting the error type name
//
// <details>
// <summary>Show Answer</summary>
//
// **Q257. B)** Getting the underlying cause of the error. Enables error chaining and root cause analysis.
//
// </details>

// %% [markdown]
// ### Q258. In `thiserror`, what does `#[from]` on a field do?
// - A) Imports the type
// - B) Generates `From` implementation for that error type
// - C) Marks the field as the source
// - D) Converts from reference
//
// <details>
// <summary>Show Answer</summary>
//
// **Q258. B)** Generates `From` implementation for that error type. Allows `?` to convert that error into your type.
//
// </details>

// %% [markdown]
// ### Q259. When would you use `anyhow::Context`?
// - A) For adding context messages when propagating errors: `.context("failed to read config")`
// - B) For error types
// - C) For threading
// - D) For async
//
// <details>
// <summary>Show Answer</summary>
//
// **Q259. A)** For adding context messages when propagating errors. E.g. `read_file().context("failed to read config")`.
//
// </details>

// %% [markdown]
// ### Q260. What does `Box<dyn std::error::Error>` represent?
// - A) A specific error type
// - B) Any type implementing `Error`, useful as a generic error type
// - C) A boxed panic
// - D) A deprecated type
//
// <details>
// <summary>Show Answer</summary>
//
// **Q260. B)** Any type implementing `Error`, useful as a generic error type when you need to return various errors.
//
// </details>

// %% [markdown]
// ### Q261. What are the three closure traits in Rust?
// - A) `Fn`, `FnMut`, `FnOnce`
// - B) `Closure`, `Lambda`, `Function`
// - C) `Call`, `CallMut`, `CallOnce`
// - D) `fn`, `fn mut`, `fn once`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q261. A)** `Fn`, `FnMut`, `FnOnce`. These are the three closure traits, from most to least restrictive.
//
// </details>

// %% [markdown]
// ### Q262. What does `FnOnce` mean?
// - A) The closure can only be called once
// - B) The closure takes ownership of captured values; it can be called at most once
// - C) The closure runs once at compile time
// - D) The closure is single-threaded
//
// <details>
// <summary>Show Answer</summary>
//
// **Q262. B)** The closure takes ownership of captured values; it can be called at most once. Used when the closure moves out of captures.
//
// </details>

// %% [markdown]
// ### Q263. What does `FnMut` mean?
// - A) The closure can mutate its environment
// - B) The closure takes `&mut self`; it can mutate captured values
// - C) The closure returns a mutable reference
// - D) The closure is mutable
//
// <details>
// <summary>Show Answer</summary>
//
// **Q263. B)** The closure takes `&mut self`; it can mutate captured values. Can be called multiple times.
//
// </details>

// %% [markdown]
// ### Q264. What does `Fn` mean?
// - A) The closure is a function
// - B) The closure takes `&self`; it can be called multiple times without mutating captures
// - C) The closure takes `self`
// - D) The closure is the same as `fn`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q264. B)** The closure takes `&self`; it can be called multiple times without mutating captures. Most flexible for callers.
//
// </details>

// %% [markdown]
// ### Q265. What is the relationship between `Fn`, `FnMut`, and `FnOnce`?
// - A) They are unrelated
// - B) `Fn` is a subtrait of `FnMut`, which is a subtrait of `FnOnce`
// - C) `FnOnce` is a subtrait of `FnMut`, which is a subtrait of `Fn`
// - D) Only `Fn` and `FnMut` are related
//
// <details>
// <summary>Show Answer</summary>
//
// **Q265. B)** `Fn` is a subtrait of `FnMut`, which is a subtrait of `FnOnce`. So `Fn` can be used where `FnMut` or `FnOnce` is expected.
//
// </details>

// %% [markdown]
// ### Q266. What does `iter.map(|x| x + 1)` return?
// - A) A `Vec`
// - B) A new iterator that yields transformed values (lazy)
// - C) The original iterator
// - D) `Option<i32>`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q266. B)** A new iterator that yields transformed values. Iterators are lazy; no work until consumed.
//
// </details>

// %% [markdown]
// ### Q267. What does `iter.filter(|x| x > 0)` do?
// - A) Filters in place
// - B) Returns an iterator that yields only elements satisfying the predicate
// - C) Returns a `Vec`
// - D) Consumes the iterator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q267. B)** Returns an iterator that yields only elements satisfying the predicate. Lazy adapter.
//
// </details>

// %% [markdown]
// ### Q268. What is an iterator consumer?
// - A) A function that creates iterators
// - B) A method that consumes the iterator and produces a value (e.g. `collect`, `sum`, `count`)
// - C) A closure that consumes values
// - D) A trait
//
// <details>
// <summary>Show Answer</summary>
//
// **Q268. B)** A method that consumes the iterator and produces a value. Examples: `collect`, `sum`, `count`, `find`.
//
// </details>

// %% [markdown]
// ### Q269. What does `vec.into_iter().collect::<Vec<_>>()` do?
// - A) Nothing—invalid
// - B) Consumes the vector and collects into a new `Vec` (essentially a copy for `Vec<T>` where `T: Copy`)
// - C) Clones the vector
// - D) Moves the vector
//
// <details>
// <summary>Show Answer</summary>
//
// **Q269. B)** Consumes the vector and collects into a new `Vec`. For `Vec<T>` with `T: Copy`, this is like cloning; otherwise it moves elements.
//
// </details>

// %% [markdown]
// ### Q270. What does `iter.fold(0, |acc, x| acc + x)` do?
// - A) Folds the iterator into an `Option`
// - B) Reduces the iterator to a single value using the closure (like `sum`)
// - C) Unfolds values
// - D) Filters by accumulator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q270. B)** Reduces the iterator to a single value using the closure. `fold(init, |acc, x| ...)` accumulates into `acc`.
//
// </details>

// %% [markdown]
// ### Q271. What does `(0..10)` create?
// - A) A `Vec` of 0 to 9
// - B) A range iterator from 0 to 9 (exclusive)
// - C) A range from 0 to 10 inclusive
// - D) A slice
//
// <details>
// <summary>Show Answer</summary>
//
// **Q271. B)** A range iterator from 0 to 9 (exclusive). `0..10` is `Range`; `0..=10` is inclusive.
//
// </details>

// %% [markdown]
// ### Q272. What is the difference between `iter()` and `into_iter()`?
// - A) No difference
// - B) `iter()` borrows, yields `&T`; `into_iter()` consumes, yields `T`
// - C) `iter()` consumes, `into_iter()` borrows
// - D) `iter()` is for arrays only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q272. B)** `iter()` borrows, yields `&T`; `into_iter()` consumes the collection, yields `T`.
//
// </details>

// %% [markdown]
// ### Q273. What does `iter.enumerate()` yield?
// - A) Just the values
// - B) Pairs `(index, value)`
// - C) Indexes only
// - D) References
//
// <details>
// <summary>Show Answer</summary>
//
// **Q273. B)** Pairs `(index, value)`. Useful for loops with index: `for (i, x) in items.enumerate()`.
//
// </details>

// %% [markdown]
// ### Q274. What does `iter.chain(other)` do?
// - A) Chains two iterators into one that yields from both in sequence
// - B) Links two iterators
// - C) Zips two iterators
// - D) Merges sorted iterators
//
// <details>
// <summary>Show Answer</summary>
//
// **Q274. A)** Chains two iterators into one that yields from both in sequence. First all from `iter`, then all from `other`.
//
// </details>

// %% [markdown]
// ### Q275. What does `iter.zip(other)` yield?
// - A) Pairs `(a, b)` from both iterators
// - B) A single iterator
// - C) Tuples of length 3
// - D) Chained values
//
// <details>
// <summary>Show Answer</summary>
//
// **Q275. A)** Pairs `(a, b)` from both iterators. Stops when the shorter iterator ends.
//
// </details>

// %% [markdown]
// ### Q276. What does `Option<T>` implement `IntoIterator` for?
// - A) It doesn't
// - B) It yields 0 or 1 element—useful for `iter.flat_map(|x| x.into_iter())`
// - C) It yields infinite elements
// - D) Only for `Option<&T>`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q276. B)** It yields 0 or 1 element. `None` yields nothing; `Some(x)` yields `x`. Useful with `flat_map`.
//
// </details>

// %% [markdown]
// ### Q277. What does `iter.take(n)` do?
// - A) Takes ownership
// - B) Yields at most `n` elements
// - C) Skips `n` elements
// - D) Takes the nth element
//
// <details>
// <summary>Show Answer</summary>
//
// **Q277. B)** Yields at most `n` elements. Limits the iterator length.
//
// </details>

// %% [markdown]
// ### Q278. What does `iter.skip(n)` do?
// - A) Skips the first `n` elements, yields the rest
// - B) Skips all elements
// - C) Skips errors
// - D) Skips duplicates
//
// <details>
// <summary>Show Answer</summary>
//
// **Q278. A)** Skips the first `n` elements, yields the rest. Opposite of `take`.
//
// </details>

// %% [markdown]
// ### Q279. What does `iter.find(|x| x > 5)` return?
// - A) All elements > 5
// - B) `Option<&T>`—the first element satisfying the predicate, or `None`
// - C) `bool`
// - D) `Result<T, E>`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q279. B)** `Option<&T>`—the first element satisfying the predicate, or `None`. Consumes the iterator.
//
// </details>

// %% [markdown]
// ### Q280. What does `iter.any(|x| x > 5)` return?
// - A) All elements > 5
// - B) `Option<bool>`
// - C) `bool`—true if any element satisfies the predicate
// - D) The first matching element
//
// <details>
// <summary>Show Answer</summary>
//
// **Q280. C)** `bool`—true if any element satisfies the predicate. Short-circuits on first match.
//
// </details>

// %% [markdown]
// ### Q281. What does `iter.all(|x| x > 0)` return?
// - A) All elements > 0
// - B) `bool`—true if every element satisfies the predicate
// - C) `Option<bool>`
// - D) The count of matching elements
//
// <details>
// <summary>Show Answer</summary>
//
// **Q281. B)** `bool`—true if every element satisfies the predicate. Short-circuits on first false.
//
// </details>

// %% [markdown]
// ### Q282. What does `vec.iter().cloned()` yield?
// - A) References `&T`
// - B) Cloned values `T` (requires `T: Clone`)
// - C) Copied values (requires `T: Copy`)
// - D) Moved values
//
// <details>
// <summary>Show Answer</summary>
//
// **Q282. B)** Cloned values `T`. For `Iterator<Item = &T>`, produces `T` by cloning. Requires `T: Clone`.
//
// </details>

// %% [markdown]
// ### Q283. What does `iter.rev()` require?
// - A) `T: Clone`
// - B) The iterator must be `DoubleEndedIterator`
// - C) `T: Copy`
// - D) Nothing special
//
// <details>
// <summary>Show Answer</summary>
//
// **Q283. B)** The iterator must be `DoubleEndedIterator`. `rev()` iterates from the end.
//
// </details>

// %% [markdown]
// ### Q284. What does `iter.peekable()` provide?
// - A) A way to peek at the next element without consuming it
// - B) A sorted iterator
// - C) A cached iterator
// - D) A parallel iterator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q284. A)** A way to peek at the next element without consuming it. `peek()` returns `Option<&Item>`.
//
// </details>

// %% [markdown]
// ### Q285. What does `iter.collect::<Vec<_>>()` do?
// - A) Collects into a `Vec`; the type must be specified or inferrable
// - B) Collects into a `HashMap`
// - C) Collects into a `String`
// - D) Collects into any collection—no type needed
//
// <details>
// <summary>Show Answer</summary>
//
// **Q285. A)** Collects into a `Vec`; the type must be specified or inferrable. `collect` can produce various types.
//
// </details>

// %% [markdown]
// ### Q286. What does `iter.partition(|x| x > 5)` return?
// - A) `Vec<T>`
// - B) `(Vec<T>, Vec<T>)`—two collections split by the predicate
// - C) `Option<(Vec<T>, Vec<T>)>`
// - D) `bool`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q286. B)** `(Vec<T>, Vec<T>)`—two collections split by the predicate. First for true, second for false.
//
// </details>

// %% [markdown]
// ### Q287. What does `iter.flatten()` do when `Item` is `IntoIterator`?
// - A) Flattens one level of nesting: `[[1,2],[3]]` → `[1,2,3]`
// - B) Flattens all levels
// - C) Flattens only `Option`
// - D) Invalid—`flatten` is for `Option` only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q287. A)** Flattens one level of nesting. For `Iterator<Item = I>` where `I: IntoIterator`, yields the inner items.
//
// </details>

// %% [markdown]
// ### Q288. What does `iter.flat_map(|x| x.into_iter())` do?
// - A) Maps then flattens one level
// - B) Same as `map`
// - C) Flattens all levels
// - D) Invalid
//
// <details>
// <summary>Show Answer</summary>
//
// **Q288. A)** Maps then flattens one level. Equivalent to `map(...).flatten()`.
//
// </details>

// %% [markdown]
// ### Q289. What does `iter.copied()` require?
// - A) `T: Clone`
// - B) `T: Copy` (for `Iterator<Item = &T>`)
// - C) `T: Default`
// - D) Nothing
//
// <details>
// <summary>Show Answer</summary>
//
// **Q289. B)** `T: Copy`. For `Iterator<Item = &T>`, produces `T` by copying. More efficient than `cloned` when `T: Copy`.
//
// </details>

// %% [markdown]
// ### Q290. What does `iter.nth(3)` return?
// - A) The first 3 elements
// - B) `Option<Self::Item>`—the element at index 3 (0-based), consuming up to it
// - C) The 3rd element from the end
// - D) A sub-iterator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q290. B)** `Option<Self::Item>`—the element at index 3 (0-based). Consumes and discards elements 0..3, returns the 4th.
//
// </details>

// %% [markdown]
// ### Q291. What does `move` in a closure do? `let f = move || x;`
// - A) Moves the closure
// - B) Moves captured variables into the closure (takes ownership)
// - C) Moves the return value
// - D) Enables mutation
//
// <details>
// <summary>Show Answer</summary>
//
// **Q291. B)** Moves captured variables into the closure. The closure takes ownership of `x`; useful for spawning threads.
//
// </details>

// %% [markdown]
// ### Q292. When does a closure implement `Fn` vs `FnMut` vs `FnOnce`?
// - A) Always `Fn`
// - B) Depends on what it captures and how: immutable borrows → `Fn`; mutable borrows → `FnMut`; ownership → `FnOnce`
// - C) Depends on the return type
// - D) Always `FnOnce`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q292. B)** Depends on what it captures: immutable borrows → `Fn`; mutable borrows → `FnMut`; ownership/moves → `FnOnce`.
//
// </details>

// %% [markdown]
// ### Q293. What does `|x, y| x + y` capture?
// - A) Nothing—it's a pure function of its arguments
// - B) Everything in scope
// - C) Only `x` and `y`
// - D) The environment
//
// <details>
// <summary>Show Answer</summary>
//
// **Q293. A)** Nothing—it only uses its parameters. Closures capture from the environment only when they use outer variables.
//
// </details>

// %% [markdown]
// ### Q294. What does `iter.collect::<HashMap<_, _>>()` require?
// - A) `Item` must be `(K, V)`
// - B) `Item` must be `K`
// - C) `Item` must implement `Hash`
// - D) `Item` must be `String`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q294. A)** `Item` must be `(K, V)`. `HashMap` implements `FromIterator<(K, V)>`.
//
// </details>

// %% [markdown]
// ### Q295. What does `iter.collect::<String>()` require for `Iterator<Item = char>`?
// - A) `Item` must be `&str`
// - B) `Item` must be `char` or `&str` (via `FromIterator`)
// - C) `Item` must be `String`
// - D) Invalid—cannot collect to `String`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q295. B)** `Item` must be `char` or `&str`. `String` implements `FromIterator<char>` and `FromIterator<&str>`.
//
// </details>

// %% [markdown]
// ### Q296. What does `iter.sum()` return?
// - A) `Option<Item>`
// - B) The sum type (e.g. `i32` for `Iterator<Item = i32>`)
// - C) `Result<Item, Error>`
// - D) The iterator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q296. B)** The sum type. For `Iterator<Item = i32>`, returns `i32`. Requires `Item: Sum` (e.g. numbers).
//
// </details>

// %% [markdown]
// ### Q297. What does `iter.count()` return?
// - A) `Option<usize>`
// - B) `usize`—the number of elements
// - C) `u32`
// - D) The last element
//
// <details>
// <summary>Show Answer</summary>
//
// **Q297. B)** `usize`—the number of elements. Consumes the iterator.
//
// </details>

// %% [markdown]
// ### Q298. What does `iter.last()` return?
// - A) `Option<Self::Item>`—the last element
// - B) The first element
// - C) `Vec<Self::Item>`
// - D) Consumes nothing
//
// <details>
// <summary>Show Answer</summary>
//
// **Q298. A)** `Option<Self::Item>`—the last element. Consumes the entire iterator.
//
// </details>

// %% [markdown]
// ### Q299. What does `iter.max()` require (for `Iterator<Item = T>`)?
// - A) `Item: Ord`
// - B) `Item: PartialOrd`
// - C) `Item: Copy`
// - D) Nothing
//
// <details>
// <summary>Show Answer</summary>
//
// **Q299. A)** `Item: Ord`. `Iterator::max()` requires `Item: Ord` for total ordering.
//
// </details>

// %% [markdown]
// ### Q300. What does `iter.min_by_key(|x| x.len())` return?
// - A) The minimum key
// - B) `Option<Self::Item>`—the element with the minimum key (by the closure)
// - C) The key of the minimum
// - D) A sorted iterator
//
// <details>
// <summary>Show Answer</summary>
//
// **Q300. B)** `Option<Self::Item>`—the element with the minimum key. The closure extracts a comparable key from each element.
//
// </details>
