// %% [markdown]
// # 🦀 Rust Exercises — Part 1: Basics (E1–E50)

// %% [markdown]
// ### Exercise 1: Declare an Immutable Variable
//
// Declare an immutable variable `name` with the value `"Rust"`.

// %%
let name = "Rust";
// YOUR CODE HERE
name

// %%
let result = name;
assert_eq!(result, "Rust");
println!("✅ Exercise 1 passed!");

// %% [markdown]
// ### Exercise 2: Declare a Mutable Variable
//
// Declare a mutable variable `count` initialized to 0, then add 5 to it.

// %%
let mut count = 0;
// YOUR CODE HERE
count

// %%
assert_eq!(count, 5);
println!("✅ Exercise 2 passed!");

// %% [markdown]
// ### Exercise 3: Variable Shadowing
//
// Use shadowing: declare `x = 5`, then shadow it with `x * 2`, then shadow again with `x + 10`.

// %%
let x = 5;
let x = x * 2;
let x = x + 10;
// YOUR CODE HERE
x

// %%
assert_eq!(x, 20);
println!("✅ Exercise 3 passed!");

// %% [markdown]
// ### Exercise 4: Type Annotation
//
// Declare `temperature` as `f64` with value 36.5 using an explicit type annotation.

// %%
let temperature: f64 = 36.5;
// YOUR CODE HERE
temperature

// %%
assert_eq!(temperature, 36.5);
assert_eq!(std::mem::size_of::<f64>(), 8);
println!("✅ Exercise 4 passed!");

// %% [markdown]
// ### Exercise 5: Add Two Numbers
//
// Write a function `add` that takes two `i32` parameters and returns their sum.

// %%
fn add(a: i32, b: i32) -> i32 {
    // YOUR CODE HERE
}
add(2, 3)

// %%
assert_eq!(add(2, 3), 5);
assert_eq!(add(-1, 1), 0);
assert_eq!(add(100, 200), 300);
println!("✅ Exercise 5 passed!");

// %% [markdown]
// ### Exercise 6: Constants
//
// Define a constant `MAX_SCORE` of type `u32` with value 100.

// %%
const MAX_SCORE: u32 = 100;
// YOUR CODE HERE
MAX_SCORE

// %%
assert_eq!(MAX_SCORE, 100);
println!("✅ Exercise 6 passed!");

// %% [markdown]
// ### Exercise 7: Multiple Variables
//
// Declare `width` and `height` as `u32` with values 1920 and 1080.

// %%
let width: u32 = 1920;
let height: u32 = 1080;
// YOUR CODE HERE
(width, height)

// %%
assert_eq!(width, 1920);
assert_eq!(height, 1080);
println!("✅ Exercise 7 passed!");

// %% [markdown]
// ### Exercise 8: Destructuring Assignment
//
// Use a tuple `(1, 2, 3)` and destructure into variables `a`, `b`, `c`.

// %%
let (a, b, c) = (1, 2, 3);
// YOUR CODE HERE
(a, b, c)

// %%
assert_eq!(a, 1);
assert_eq!(b, 2);
assert_eq!(c, 3);
println!("✅ Exercise 8 passed!");

// %% [markdown]
// ### Exercise 9: Underscore Prefix
//
// Declare `_unused` with value 42 (prefix with underscore to suppress unused warning).

// %%
let _unused = 42;
// YOUR CODE HERE
_unused

// %%
assert_eq!(_unused, 42);
println!("✅ Exercise 9 passed!");

// %% [markdown]
// ### Exercise 10: Type Inference
//
// Let Rust infer the type: assign `items` the result of `vec![1, 2, 3]`.

// %%
let items = vec![1, 2, 3];
// YOUR CODE HERE
items.len()

// %%
assert_eq!(items.len(), 3);
assert_eq!(items[0], 1);
println!("✅ Exercise 10 passed!");

// %% [markdown]
// ### Exercise 11: Integer Types
//
// Create `small: i8` = -128 and `big: u64` = 1_000_000.

// %%
let small: i8 = -128;
let big: u64 = 1_000_000;
// YOUR CODE HERE
(small, big)

// %%
assert_eq!(small, -128);
assert_eq!(big, 1_000_000);
println!("✅ Exercise 11 passed!");

// %% [markdown]
// ### Exercise 12: Float Types
//
// Create `pi: f32` ≈ 3.14 and `e: f64` ≈ 2.718.

// %%
let pi: f32 = 3.14;
let e: f64 = 2.718;
// YOUR CODE HERE
(pi, e)

// %%
assert!((pi - 3.14).abs() < 0.01);
assert!((e - 2.718).abs() < 0.001);
println!("✅ Exercise 12 passed!");

// %% [markdown]
// ### Exercise 13: Boolean Logic
//
// Write `is_valid(age: u8)` returning true if age is 18-120 inclusive.

// %%
fn is_valid(age: u8) -> bool {
    // YOUR CODE HERE
}
is_valid(25)

// %%
assert!(is_valid(18));
assert!(is_valid(120));
assert!(!is_valid(17));
assert!(!is_valid(121));
println!("✅ Exercise 13 passed!");

// %% [markdown]
// ### Exercise 14: Character Type
//
// Create `letter` as char = 'A' and `emoji` as char = '🦀'.

// %%
let letter: char = 'A';
let emoji: char = '🦀';
// YOUR CODE HERE
(letter, emoji)

// %%
assert_eq!(letter, 'A');
assert_eq!(emoji, '🦀');
println!("✅ Exercise 14 passed!");

// %% [markdown]
// ### Exercise 15: String Literal
//
// Create `greeting` as &str with "Hello, Rust!".

// %%
let greeting: &str = "Hello, Rust!";
// YOUR CODE HERE
greeting

// %%
assert_eq!(greeting, "Hello, Rust!");
println!("✅ Exercise 15 passed!");

// %% [markdown]
// ### Exercise 16: Numeric Operations
//
// Write `multiply(a: i32, b: i32)` returning a * b.

// %%
fn multiply(a: i32, b: i32) -> i32 {
    // YOUR CODE HERE
}
multiply(6, 7)

// %%
assert_eq!(multiply(6, 7), 42);
assert_eq!(multiply(-3, 4), -12);
println!("✅ Exercise 16 passed!");

// %% [markdown]
// ### Exercise 17: Integer Division
//
// Compute `quotient` = 17 / 5 and `remainder` = 17 % 5.

// %%
let quotient = 17 / 5;
let remainder = 17 % 5;
// YOUR CODE HERE
(quotient, remainder)

// %%
assert_eq!(quotient, 3);
assert_eq!(remainder, 2);
println!("✅ Exercise 17 passed!");

// %% [markdown]
// ### Exercise 18: Boolean AND/OR
//
// Write `both_true(a: bool, b: bool)` returning a && b.

// %%
fn both_true(a: bool, b: bool) -> bool {
    // YOUR CODE HERE
}
both_true(true, true)

// %%
assert!(both_true(true, true));
assert!(!both_true(true, false));
assert!(!both_true(false, true));
println!("✅ Exercise 18 passed!");

// %% [markdown]
// ### Exercise 19: Numeric Comparison
//
// Write `max_of_two(a: i32, b: i32)` returning the larger value.

// %%
fn max_of_two(a: i32, b: i32) -> i32 {
    // YOUR CODE HERE
}
max_of_two(10, 20)

// %%
assert_eq!(max_of_two(10, 20), 20);
assert_eq!(max_of_two(-5, -10), -5);
assert_eq!(max_of_two(7, 7), 7);
println!("✅ Exercise 19 passed!");

// %% [markdown]
// ### Exercise 20: Type Conversion
//
// Convert `x: i32 = 42` to `y: f64` using `as`.

// %%
let x: i32 = 42;
let y: f64 = x as f64;
// YOUR CODE HERE
y

// %%
assert_eq!(y, 42.0);
println!("✅ Exercise 20 passed!");

// %% [markdown]
// ### Exercise 21: Function with No Return
//
// Write `greet()` that prints "Hello!" and returns unit `()`.

// %%
fn greet() -> () {
    println!("Hello!");
    // YOUR CODE HERE
}
greet()

// %%
let _ = greet();
println!("✅ Exercise 21 passed!");

// %% [markdown]
// ### Exercise 22: Function with Single Parameter
//
// Write `double(n: i32)` returning n * 2.

// %%
fn double(n: i32) -> i32 {
    // YOUR CODE HERE
}
double(21)

// %%
assert_eq!(double(21), 42);
assert_eq!(double(0), 0);
println!("✅ Exercise 22 passed!");

// %% [markdown]
// ### Exercise 23: Expression vs Statement
//
// Write `square(x: i32)` using an expression (no semicolon) to return x * x.

// %%
fn square(x: i32) -> i32 {
    // YOUR CODE HERE
}
square(5)

// %%
assert_eq!(square(5), 25);
assert_eq!(square(-3), 9);
println!("✅ Exercise 23 passed!");

// %% [markdown]
// ### Exercise 24: Early Return
//
// Write `abs(n: i32)` returning n if n >= 0, else -n.

// %%
fn abs(n: i32) -> i32 {
    // YOUR CODE HERE
}
abs(-42)

// %%
assert_eq!(abs(-42), 42);
assert_eq!(abs(42), 42);
assert_eq!(abs(0), 0);
println!("✅ Exercise 24 passed!");

// %% [markdown]
// ### Exercise 25: Multiple Parameters
//
// Write `rectangle_area(width: u32, height: u32)` returning width * height.

// %%
fn rectangle_area(width: u32, height: u32) -> u32 {
    // YOUR CODE HERE
}
rectangle_area(5, 4)

// %%
assert_eq!(rectangle_area(5, 4), 20);
assert_eq!(rectangle_area(10, 10), 100);
println!("✅ Exercise 25 passed!");

// %% [markdown]
// ### Exercise 26: Return Tuple
//
// Write `div_mod(a: i32, b: i32)` returning (a/b, a%b). Assume b != 0.

// %%
fn div_mod(a: i32, b: i32) -> (i32, i32) {
    // YOUR CODE HERE
}
div_mod(17, 5)

// %%
assert_eq!(div_mod(17, 5), (3, 2));
assert_eq!(div_mod(10, 2), (5, 0));
println!("✅ Exercise 26 passed!");

// %% [markdown]
// ### Exercise 27: Default Return
//
// Write `is_even(n: i32)` returning true if n % 2 == 0.

// %%
fn is_even(n: i32) -> bool {
    // YOUR CODE HERE
}
is_even(4)

// %%
assert!(is_even(4));
assert!(!is_even(5));
assert!(is_even(0));
println!("✅ Exercise 27 passed!");

// %% [markdown]
// ### Exercise 28: Function Call
//
// Write `apply_twice(f: fn(i32)->i32, x: i32)` returning f(f(x)).

// %%
fn apply_twice(f: fn(i32) -> i32, x: i32) -> i32 {
    // YOUR CODE HERE
}
fn add_one(n: i32) -> i32 { n + 1 }
apply_twice(add_one, 0)

// %%
fn add_one(n: i32) -> i32 { n + 1 }
assert_eq!(apply_twice(add_one, 0), 2);
assert_eq!(apply_twice(|x| x * 2, 3), 12);
println!("✅ Exercise 28 passed!");

// %% [markdown]
// ### Exercise 29: Scope
//
// Inside a block `{ let x = 10; x * 2 }`, return the expression value.

// %%
let result = { let x = 10; x * 2 };
// YOUR CODE HERE
result

// %%
assert_eq!(result, 20);
println!("✅ Exercise 29 passed!");

// %% [markdown]
// ### Exercise 30: Closure-like Logic
//
// Write `make_adder(n: i32)` returning a closure that adds n. Use a regular fn: `fn add_n(x: i32, n: i32) -> i32`.

// %%
fn add_n(x: i32, n: i32) -> i32 {
    // YOUR CODE HERE
}
add_n(5, 10)

// %%
assert_eq!(add_n(5, 10), 15);
assert_eq!(add_n(0, 7), 7);
println!("✅ Exercise 30 passed!");

// %% [markdown]
// ### Exercise 31: If Expression
//
// Write `sign(n: i32)` returning "positive", "negative", or "zero".

// %%
fn sign(n: i32) -> &'static str {
    // YOUR CODE HERE
}
sign(5)

// %%
assert_eq!(sign(5), "positive");
assert_eq!(sign(-3), "negative");
assert_eq!(sign(0), "zero");
println!("✅ Exercise 31 passed!");

// %% [markdown]
// ### Exercise 32: If-Else
//
// Write `min(a: i32, b: i32)` returning the smaller value.

// %%
fn min(a: i32, b: i32) -> i32 {
    // YOUR CODE HERE
}
min(3, 7)

// %%
assert_eq!(min(3, 7), 3);
assert_eq!(min(10, 2), 2);
assert_eq!(min(5, 5), 5);
println!("✅ Exercise 32 passed!");

// %% [markdown]
// ### Exercise 33: Match on Integer
//
// Write `describe_number(n: i32)` using match: 0=>"zero", 1=>"one", _=>"many".

// %%
fn describe_number(n: i32) -> &'static str {
    // YOUR CODE HERE
}
describe_number(1)

// %%
assert_eq!(describe_number(0), "zero");
assert_eq!(describe_number(1), "one");
assert_eq!(describe_number(5), "many");
println!("✅ Exercise 33 passed!");

// %% [markdown]
// ### Exercise 34: Match Ranges
//
// Write `grade(score: u8)` using match: 90..=100=>"A", 80..=89=>"B", _=>"F".

// %%
fn grade(score: u8) -> &'static str {
    // YOUR CODE HERE
}
grade(95)

// %%
assert_eq!(grade(95), "A");
assert_eq!(grade(85), "B");
assert_eq!(grade(50), "F");
println!("✅ Exercise 34 passed!");

// %% [markdown]
// ### Exercise 35: Loop Basics
//
// Use `loop` to accumulate sum of 1..=5, break when sum >= 10. Hint: use `if sum >= 10 { break; }`.

// %%
let mut sum = 0;
let mut i = 1;
loop {
    sum += i;
    // YOUR CODE HERE - break when sum >= 10
    i += 1;
}
sum

// %%
assert_eq!(sum, 10);
println!("✅ Exercise 35 passed!");

// %% [markdown]
// ### Exercise 36: While Loop
//
// Use `while` to count down from 5 to 1, store count in `countdown`.

// %%
let mut n = 5;
let mut countdown = vec![];
while n >= 1 {
    countdown.push(n);
    n -= 1;
}
// YOUR CODE HERE
countdown

// %%
assert_eq!(countdown, vec![5, 4, 3, 2, 1]);
println!("✅ Exercise 36 passed!");

// %% [markdown]
// ### Exercise 37: For Loop
//
// Use `for` to sum elements of `arr = [1, 2, 3, 4, 5]`. Hint: add each element to sum.

// %%
let arr = [1, 2, 3, 4, 5];
let mut sum = 0;
for x in arr {
    // YOUR CODE HERE
}
sum

// %%
assert_eq!(sum, 15);
println!("✅ Exercise 37 passed!");

// %% [markdown]
// ### Exercise 38: Loop with Break Value
//
// Use `loop { break value; }` to produce 42.

// %%
let result = loop {
    // YOUR CODE HERE
};
result

// %%
assert_eq!(result, 42);
println!("✅ Exercise 38 passed!");

// %% [markdown]
// ### Exercise 39: Match Multiple
//
// Write `operation(op: char, a: i32, b: i32)` matching '+', '-', '*', '/'.

// %%
fn operation(op: char, a: i32, b: i32) -> i32 {
    // YOUR CODE HERE
}
operation('+', 3, 4)

// %%
assert_eq!(operation('+', 3, 4), 7);
assert_eq!(operation('-', 10, 3), 7);
assert_eq!(operation('*', 6, 7), 42);
println!("✅ Exercise 39 passed!");

// %% [markdown]
// ### Exercise 40: Nested If
//
// Write `leap_year(year: u32)` returning true if divisible by 4 (and special cases for 100, 400).

// %%
fn leap_year(year: u32) -> bool {
    // YOUR CODE HERE
}
leap_year(2024)

// %%
assert!(leap_year(2024));
assert!(leap_year(2000));
assert!(!leap_year(1900));
assert!(!leap_year(2023));
println!("✅ Exercise 40 passed!");

// %% [markdown]
// ### Exercise 41: Array Creation
//
// Create `nums: [i32; 5]` with values 10, 20, 30, 40, 50.

// %%
let nums: [i32; 5] = [10, 20, 30, 40, 50];
// YOUR CODE HERE
nums[0]

// %%
assert_eq!(nums[0], 10);
assert_eq!(nums[4], 50);
assert_eq!(nums.len(), 5);
println!("✅ Exercise 41 passed!");

// %% [markdown]
// ### Exercise 42: Array Repeat
//
// Create `zeros: [i32; 10]` where all elements are 0.

// %%
let zeros: [i32; 10] = [0; 10];
// YOUR CODE HERE
zeros

// %%
assert!(zeros.iter().all(|&x| x == 0));
assert_eq!(zeros.len(), 10);
println!("✅ Exercise 42 passed!");

// %% [markdown]
// ### Exercise 43: Tuple Creation
//
// Create `point: (f64, f64)` = (3.0, 4.0).

// %%
let point: (f64, f64) = (3.0, 4.0);
// YOUR CODE HERE
point.0

// %%
assert_eq!(point.0, 3.0);
assert_eq!(point.1, 4.0);
println!("✅ Exercise 43 passed!");

// %% [markdown]
// ### Exercise 44: Vector Creation
//
// Create `v: Vec<i32>` with elements 1, 2, 3 using `vec![]`.

// %%
let v: Vec<i32> = vec![1, 2, 3];
// YOUR CODE HERE
v

// %%
assert_eq!(v, vec![1, 2, 3]);
println!("✅ Exercise 44 passed!");

// %% [markdown]
// ### Exercise 45: Vector Push
//
// Create empty Vec, push 1, 2, 3, then return its length.

// %%
let mut v: Vec<i32> = Vec::new();
v.push(1);
v.push(2);
v.push(3);
// YOUR CODE HERE
v.len()

// %%
assert_eq!(v.len(), 3);
assert_eq!(v[0], 1);
println!("✅ Exercise 45 passed!");

// %% [markdown]
// ### Exercise 46: Array Iteration
//
// Sum all elements of `[1, 2, 3, 4, 5]` using a for loop.

// %%
let arr = [1, 2, 3, 4, 5];
let mut sum = 0;
for &x in &arr {
    sum += x;
}
// YOUR CODE HERE
sum

// %%
assert_eq!(sum, 15);
println!("✅ Exercise 46 passed!");

// %% [markdown]
// ### Exercise 47: Tuple Destructuring in Match
//
// Write `first((a, _): (i32, i32))` returning a.

// %%
fn first((a, _): (i32, i32)) -> i32 {
    // YOUR CODE HERE
}
first((10, 20))

// %%
assert_eq!(first((10, 20)), 10);
assert_eq!(first((1, 2)), 1);
println!("✅ Exercise 47 passed!");

// %% [markdown]
// ### Exercise 48: Vector Pop
//
// Create vec![1, 2, 3], pop once, assert popped value is 3 and len is 2.

// %%
let mut v = vec![1, 2, 3];
let popped = v.pop();
// YOUR CODE HERE
(popped, v.len())

// %%
assert_eq!(popped, Some(3));
assert_eq!(v.len(), 2);
println!("✅ Exercise 48 passed!");

// %% [markdown]
// ### Exercise 49: Array Index
//
// Write `get_third(arr: &[i32])` returning arr[2] or 0 if len < 3.

// %%
fn get_third(arr: &[i32]) -> i32 {
    // YOUR CODE HERE
}
get_third(&[1, 2, 3, 4])

// %%
assert_eq!(get_third(&[1, 2, 3, 4]), 3);
assert_eq!(get_third(&[1, 2]), 0);
println!("✅ Exercise 49 passed!");

// %% [markdown]
// ### Exercise 50: Mixed Tuple
//
// Create `data: (i32, bool, &str)` = (42, true, "hello").

// %%
let data: (i32, bool, &str) = (42, true, "hello");
// YOUR CODE HERE
data

// %%
assert_eq!(data.0, 42);
assert!(data.1);
assert_eq!(data.2, "hello");
println!("✅ Exercise 50 passed!");
