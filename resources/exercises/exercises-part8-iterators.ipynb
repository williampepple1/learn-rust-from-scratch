// %% [markdown]
// # 🦀 Rust Exercises — Part 8: Iterators (E351–E400)

// %% [markdown]
// ### Exercise 351: Create Iterator from Slice
//
// Create an iterator from the slice `[1, 2, 3]` using `.iter()` and collect into a `Vec`. Store the result in `v`.

// %%
let v: Vec<&i32> = [1, 2, 3].iter().collect();
// YOUR CODE HERE
v

// %%
assert_eq!(v, vec![&1, &2, &3]);
println!("✅ Exercise 351 passed!");

// %% [markdown]
// ### Exercise 352: into_iter() Ownership
//
// Use `.into_iter()` on `vec![10, 20, 30]` and collect into a new `Vec<i32>`. Store in `result`.

// %%
let result: Vec<i32> = vec![10, 20, 30].into_iter().collect();
// YOUR CODE HERE
result

// %%
assert_eq!(result, vec![10, 20, 30]);
println!("✅ Exercise 352 passed!");

// %% [markdown]
// ### Exercise 353: next() Method
//
// Create an iterator from `[1, 2, 3]` and call `.next()` three times. Store the three `Option` values in `a`, `b`, `c`.

// %%
let mut iter = [1, 2, 3].into_iter();
let a = iter.next();
let b = iter.next();
let c = iter.next();
// YOUR CODE HERE
(a, b, c)

// %%
assert_eq!(a, Some(1));
assert_eq!(b, Some(2));
assert_eq!(c, Some(3));
assert_eq!(iter.next(), None);
println!("✅ Exercise 353 passed!");

// %% [markdown]
// ### Exercise 354: Implement Iterator for Counter
//
// Define a struct `Counter` with field `count: u32`. Implement `Iterator` for `Counter` that yields 0, 1, 2 and then `None`.

// %%
struct Counter { count: u32 }
impl Iterator for Counter {
    type Item = u32;
    fn next(&mut self) -> Option<u32> {
        // YOUR CODE HERE
    }
}
let nums: Vec<u32> = Counter { count: 0 }.take(3).collect();

// %%
assert_eq!(nums, vec![0, 1, 2]);
let c2: Vec<u32> = Counter { count: 0 }.take(5).collect();
assert_eq!(c2, vec![0, 1, 2, 3, 4]);
println!("✅ Exercise 354 passed!");

// %% [markdown]
// ### Exercise 355: Iterator type Item
//
// Implement `Iterator` for a struct `Ones` that always yields `Some(1)`. Use `type Item = i32`.

// %%
struct Ones;
impl Iterator for Ones {
    type Item = i32;
    fn next(&mut self) -> Option<i32> {
        // YOUR CODE HERE
    }
}
let first_three: Vec<i32> = Ones.take(3).collect();

// %%
assert_eq!(first_three, vec![1, 1, 1]);
println!("✅ Exercise 355 passed!");

// %% [markdown]
// ### Exercise 356: Bounded Counter Iterator
//
// Implement `Iterator` for `RangeToN { n: u32, current: u32 }` that yields values from `current` up to (but not including) `n`.

// %%
struct RangeToN { n: u32, current: u32 }
impl Iterator for RangeToN {
    type Item = u32;
    fn next(&mut self) -> Option<u32> {
        // YOUR CODE HERE
    }
}
let r: Vec<u32> = RangeToN { n: 5, current: 1 }.collect();

// %%
assert_eq!(r, vec![1, 2, 3, 4]);
assert_eq!(RangeToN { n: 3, current: 0 }.collect::<Vec<_>>(), vec![0, 1, 2]);
println!("✅ Exercise 356 passed!");

// %% [markdown]
// ### Exercise 357: Iterator that Returns None
//
// Implement `Iterator` for `Empty<T>` that always returns `None`. Use `type Item = T`.

// %%
struct Empty<T>(std::marker::PhantomData<T>);
impl<T> Iterator for Empty<T> {
    type Item = T;
    fn next(&mut self) -> Option<T> {
        // YOUR CODE HERE
    }
}
let v: Vec<i32> = Empty(std::marker::PhantomData).collect();

// %%
assert!(v.is_empty());
println!("✅ Exercise 357 passed!");

// %% [markdown]
// ### Exercise 358: Custom Repeat Iterator
//
// Implement `Iterator` for `Repeat<T: Copy>` with field `value: T`. It yields `value` forever.

// %%
struct Repeat<T: Copy> { value: T }
impl<T: Copy> Iterator for Repeat<T> {
    type Item = T;
    fn next(&mut self) -> Option<T> {
        // YOUR CODE HERE
    }
}
let five: Vec<i32> = Repeat { value: 7 }.take(5).collect();

// %%
assert_eq!(five, vec![7, 7, 7, 7, 7]);
println!("✅ Exercise 358 passed!");

// %% [markdown]
// ### Exercise 359: Array into_iter
//
// Use `into_iter()` on array `[1, 2, 3]` and `collect` into `Vec<i32>`. Store in `v`.

// %%
// Use into_iter on array to consume and collect
let a = [1, 2, 3];
let v: Vec<i32> = a.into_iter().collect();
// YOUR CODE HERE
v

// %%
assert_eq!(v, vec![1, 2, 3]);
println!("✅ Exercise 359 passed!");

// %% [markdown]
// ### Exercise 360: Iterator from Vec
//
// Create an iterator from `vec!["a", "b", "c"]` using `into_iter()`, then collect into `Vec<&str>`. Store in `letters`.

// %%
let letters: Vec<&str> = vec!["a", "b", "c"].into_iter().collect();
// YOUR CODE HERE
letters

// %%
assert_eq!(letters, vec!["a", "b", "c"]);
println!("✅ Exercise 360 passed!");

// %% [markdown]
// ### Exercise 361: map Adapter
//
// Use `map` to double each element of `[1, 2, 3, 4, 5]`. Collect into `Vec<i32>` and store in `doubled`.

// %%
let doubled: Vec<i32> = [1, 2, 3, 4, 5].into_iter().map(|x| x * 2).collect();
// YOUR CODE HERE
doubled

// %%
assert_eq!(doubled, vec![2, 4, 6, 8, 10]);
println!("✅ Exercise 361 passed!");

// %% [markdown]
// ### Exercise 362: filter Adapter
//
// Use `filter` to keep only even numbers from `[1, 2, 3, 4, 5, 6]`. Collect into `Vec` and store in `evens`.

// %%
let evens: Vec<i32> = [1, 2, 3, 4, 5, 6].into_iter().filter(|x| *x % 2 == 0).collect();
// YOUR CODE HERE
evens

// %%
assert_eq!(evens, vec![2, 4, 6]);
println!("✅ Exercise 362 passed!");

// %% [markdown]
// ### Exercise 363: take Adapter
//
// Use `take(3)` on the iterator from `[10, 20, 30, 40, 50]` and collect. Store in `first_three`.

// %%
let first_three: Vec<i32> = [10, 20, 30, 40, 50].into_iter().take(3).collect();
// YOUR CODE HERE
first_three

// %%
assert_eq!(first_three, vec![10, 20, 30]);
println!("✅ Exercise 363 passed!");

// %% [markdown]
// ### Exercise 364: skip Adapter
//
// Use `skip(2)` on `[1, 2, 3, 4, 5]` and collect. Store in `skipped`.

// %%
let skipped: Vec<i32> = [1, 2, 3, 4, 5].into_iter().skip(2).collect();
// YOUR CODE HERE
skipped

// %%
assert_eq!(skipped, vec![3, 4, 5]);
println!("✅ Exercise 364 passed!");

// %% [markdown]
// ### Exercise 365: enumerate Adapter
//
// Use `enumerate` on `["a", "b", "c"]` and collect into `Vec<(usize, &str)>`. Store in `indexed`.

// %%
let indexed: Vec<(usize, &str)> = ["a", "b", "c"].into_iter().enumerate().collect();
// YOUR CODE HERE
indexed

// %%
assert_eq!(indexed, vec![(0, "a"), (1, "b"), (2, "c")]);
println!("✅ Exercise 365 passed!");

// %% [markdown]
// ### Exercise 366: map and filter Chain
//
// From `[1, 2, 3, 4, 5, 6]`, filter evens then map to double. Collect into `result`.

// %%
let result: Vec<i32> = [1, 2, 3, 4, 5, 6].into_iter()
    .filter(|x| *x % 2 == 0)
    .map(|x| x * 2)
    .collect();
// YOUR CODE HERE
result

// %%
assert_eq!(result, vec![4, 8, 12]);
println!("✅ Exercise 366 passed!");

// %% [markdown]
// ### Exercise 367: take_while
//
// Use `take_while` to take elements from `[2, 4, 6, 7, 8]` while they are even. Collect into `taken`.

// %%
let taken: Vec<i32> = [2, 4, 6, 7, 8].into_iter().take_while(|x| *x % 2 == 0).collect();
// YOUR CODE HERE
taken

// %%
assert_eq!(taken, vec![2, 4, 6]);
println!("✅ Exercise 367 passed!");

// %% [markdown]
// ### Exercise 368: skip_while
//
// Use `skip_while` to skip elements from `[1, 2, 3, 4, 5]` while they are less than 3. Collect into `skipped`.

// %%
let skipped: Vec<i32> = [1, 2, 3, 4, 5].into_iter().skip_while(|x| *x < 3).collect();
// YOUR CODE HERE
skipped

// %%
assert_eq!(skipped, vec![3, 4, 5]);
println!("✅ Exercise 368 passed!");

// %% [markdown]
// ### Exercise 369: map to String
//
// Use `map` to convert `[1, 2, 3]` to `Vec<String>` with format `"Item {n}"`. Store in `strings`.

// %%
let strings: Vec<String> = [1, 2, 3].into_iter().map(|n| format!("Item {}", n)).collect();
// YOUR CODE HERE
strings

// %%
assert_eq!(strings, vec!["Item 1", "Item 2", "Item 3"]);
println!("✅ Exercise 369 passed!");

// %% [markdown]
// ### Exercise 370: filter_map
//
// Use `filter_map` on `[Some(1), None, Some(2), None, Some(3)]` to unwrap `Some` values. Collect into `nums`.

// %%
let nums: Vec<i32> = [Some(1), None, Some(2), None, Some(3)].into_iter()
    .filter_map(|x| x)
    .collect();
// YOUR CODE HERE
nums

// %%
assert_eq!(nums, vec![1, 2, 3]);
println!("✅ Exercise 370 passed!");

// %% [markdown]
// ### Exercise 371: zip Two Iterators
//
// Use `zip` to combine `[1, 2, 3]` and `["a", "b", "c"]` into pairs. Collect into `pairs`.

// %%
let pairs: Vec<(i32, &str)> = [1, 2, 3].into_iter().zip(["a", "b", "c"]).collect();
// YOUR CODE HERE
pairs

// %%
assert_eq!(pairs, vec![(1, "a"), (2, "b"), (3, "c")]);
println!("✅ Exercise 371 passed!");

// %% [markdown]
// ### Exercise 372: chain Two Iterators
//
// Use `chain` to combine `[1, 2]` and `[3, 4]` into one iterator. Collect into `chained`.

// %%
let chained: Vec<i32> = [1, 2].into_iter().chain([3, 4]).collect();
// YOUR CODE HERE
chained

// %%
assert_eq!(chained, vec![1, 2, 3, 4]);
println!("✅ Exercise 372 passed!");

// %% [markdown]
// ### Exercise 373: flat_map
//
// Use `flat_map` on `[[1, 2], [3, 4], [5]]` to flatten into a single `Vec<i32>`. Store in `flat`.

// %%
let nested: Vec<Vec<i32>> = vec![vec![1, 2], vec![3, 4], vec![5]];
let flat: Vec<i32> = nested.into_iter().flat_map(|v| v).collect();
// YOUR CODE HERE
flat

// %%
assert_eq!(flat, vec![1, 2, 3, 4, 5]);
println!("✅ Exercise 373 passed!");

// %% [markdown]
// ### Exercise 374: filter_map with Option
//
// Use `filter_map` on `[1, -2, 3, -4, 5]` to keep only positive numbers (return `Some(x)` if `x > 0` else `None`). Store in `positives`.

// %%
let positives: Vec<i32> = [1, -2, 3, -4, 5].into_iter()
    .filter_map(|x| if x > 0 { Some(x) } else { None })
    .collect();
// YOUR CODE HERE
positives

// %%
assert_eq!(positives, vec![1, 3, 5]);
println!("✅ Exercise 374 passed!");

// %% [markdown]
// ### Exercise 375: zip with enumerate
//
// Use `enumerate` then `map` to create `Vec<(usize, i32)>` from `[10, 20, 30]` where the index is doubled. Store in `result`.

// %%
let result: Vec<(usize, i32)> = [10, 20, 30].into_iter().enumerate().map(|(i, v)| (i * 2, v)).collect();
// YOUR CODE HERE
result

// %%
assert_eq!(result, vec![(0, 10), (2, 20), (4, 30)]);
println!("✅ Exercise 375 passed!");

// %% [markdown]
// ### Exercise 376: chain Three Ranges
//
// Chain `0..2`, `5..7`, and `10..12` into one iterator. Collect into `ranges`.

// %%
let ranges: Vec<i32> = (0..2).map(|x| x as i32)
    .chain((5..7).map(|x| x as i32))
    .chain((10..12).map(|x| x as i32))
    .collect();
// YOUR CODE HERE
ranges

// %%
assert_eq!(ranges, vec![0, 1, 5, 6, 10, 11]);
println!("✅ Exercise 376 passed!");

// %% [markdown]
// ### Exercise 377: flat_map Expand
//
// Use `flat_map` on `[1, 2, 3]` to produce `[1, 1, 2, 2, 3, 3]` (each element repeated twice).

// %%
let expanded: Vec<i32> = [1, 2, 3].into_iter().flat_map(|x| [x, x]).collect();
// YOUR CODE HERE
expanded

// %%
assert_eq!(expanded, vec![1, 1, 2, 2, 3, 3]);
println!("✅ Exercise 377 passed!");

// %% [markdown]
// ### Exercise 378: zip Different Lengths
//
// Zip `[1, 2, 3, 4]` with `["a", "b"]`. The result length is the shorter. Collect into `short_zip`.

// %%
let short_zip: Vec<(i32, &str)> = [1, 2, 3, 4].into_iter().zip(["a", "b"]).collect();
// YOUR CODE HERE
short_zip

// %%
assert_eq!(short_zip, vec![(1, "a"), (2, "b")]);
println!("✅ Exercise 378 passed!");

// %% [markdown]
// ### Exercise 379: Inspect Adapter
//
// Use `inspect` to print each element while iterating over `[1, 2, 3]`, then collect. The result should still be `[1, 2, 3]`.

// %%
let inspected: Vec<i32> = [1, 2, 3].into_iter().inspect(|x| println!("  saw {}", x)).collect();
// YOUR CODE HERE
inspected

// %%
assert_eq!(inspected, vec![1, 2, 3]);
println!("✅ Exercise 379 passed!");

// %% [markdown]
// ### Exercise 380: rev Iterator
//
// Use `rev()` on `[1, 2, 3]` (requires `DoubleEndedIterator`). Collect into `reversed`.

// %%
let reversed: Vec<i32> = [1, 2, 3].into_iter().rev().collect();
// YOUR CODE HERE
reversed

// %%
assert_eq!(reversed, vec![3, 2, 1]);
println!("✅ Exercise 380 passed!");

// %% [markdown]
// ### Exercise 381: collect into Vec
//
// Use `collect` to turn `(0..5)` into `Vec<i32>`. Store in `collected`.

// %%
let collected: Vec<i32> = (0..5).map(|x| x as i32).collect();
// YOUR CODE HERE
collected

// %%
assert_eq!(collected, vec![0, 1, 2, 3, 4]);
println!("✅ Exercise 381 passed!");

// %% [markdown]
// ### Exercise 382: fold Sum
//
// Use `fold` to compute the sum of `[1, 2, 3, 4, 5]`. Start with 0. Store in `total`.

// %%
let total: i32 = [1, 2, 3, 4, 5].into_iter().fold(0, |acc, x| acc + x);
// YOUR CODE HERE
total

// %%
assert_eq!(total, 15);
println!("✅ Exercise 382 passed!");

// %% [markdown]
// ### Exercise 383: sum() Method
//
// Use the `sum()` method on `[10, 20, 30]` to get the total. Store in `s`.

// %%
let s: i32 = [10, 20, 30].into_iter().sum();
// YOUR CODE HERE
s

// %%
assert_eq!(s, 60);
println!("✅ Exercise 383 passed!");

// %% [markdown]
// ### Exercise 384: any() Method
//
// Use `any()` to check if `[1, 2, 3, 4, 5]` contains any element greater than 4. Store in `has_large`.

// %%
let has_large: bool = [1, 2, 3, 4, 5].into_iter().any(|x| x > 4);
// YOUR CODE HERE
has_large

// %%
assert!(has_large);
assert!(![1, 2, 3].into_iter().any(|x| x > 5));
println!("✅ Exercise 384 passed!");

// %% [markdown]
// ### Exercise 385: all() Method
//
// Use `all()` to check if all elements in `[2, 4, 6, 8]` are even. Store in `all_even`.

// %%
let all_even: bool = [2, 4, 6, 8].into_iter().all(|x| x % 2 == 0);
// YOUR CODE HERE
all_even

// %%
assert!(all_even);
assert!(![2, 3, 4].into_iter().all(|x| x % 2 == 0));
println!("✅ Exercise 385 passed!");

// %% [markdown]
// ### Exercise 386: find() Method
//
// Use `find()` to get the first element in `[10, 20, 30, 40]` that is greater than 25. Store in `found`.

// %%
let found: Option<i32> = [10, 20, 30, 40].into_iter().find(|x| *x > 25);
// YOUR CODE HERE
found

// %%
assert_eq!(found, Some(30));
println!("✅ Exercise 386 passed!");

// %% [markdown]
// ### Exercise 387: count() Method
//
// Use `count()` on the iterator from `[1, 2, 3, 4, 5]` to get the number of elements. Store in `cnt`.

// %%
let cnt: usize = [1, 2, 3, 4, 5].into_iter().count();
// YOUR CODE HERE
cnt

// %%
assert_eq!(cnt, 5);
println!("✅ Exercise 387 passed!");

// %% [markdown]
// ### Exercise 388: fold Product
//
// Use `fold` to compute the product of `[1, 2, 3, 4]`. Start with 1. Store in `product`.

// %%
let product: i32 = [1, 2, 3, 4].into_iter().fold(1, |acc, x| acc * x);
// YOUR CODE HERE
product

// %%
assert_eq!(product, 24);
println!("✅ Exercise 388 passed!");

// %% [markdown]
// ### Exercise 389: max() and min()
//
// Use `max()` and `min()` on `[3, 1, 4, 1, 5]`. Store in `mx` and `mn`.

// %%
let nums = [3, 1, 4, 1, 5];
let mx = nums.iter().max();
let mn = nums.iter().min();
// YOUR CODE HERE
(mx, mn)

// %%
assert_eq!(mx, Some(&5));
assert_eq!(mn, Some(&1));
println!("✅ Exercise 389 passed!");

// %% [markdown]
// ### Exercise 390: nth() Method
//
// Use `nth(2)` on `[10, 20, 30, 40]` to get the third element (0-indexed). Store in `third`.

// %%
let third: Option<i32> = [10, 20, 30, 40].into_iter().nth(2);
// YOUR CODE HERE
third

// %%
assert_eq!(third, Some(30));
println!("✅ Exercise 390 passed!");

// %% [markdown]
// ### Exercise 391: Custom Iterator - StepBy
//
// Implement `Iterator` for `StepBy<I>` that wraps an iterator and yields every nth item. For simplicity, implement for a fixed step of 2.

// %%
// Use the standard step_by: (0..10).step_by(2)
let stepped: Vec<i32> = (0..10).step_by(2).map(|x| x as i32).collect();
// YOUR CODE HERE
stepped

// %%
assert_eq!(stepped, vec![0, 2, 4, 6, 8]);
println!("✅ Exercise 391 passed!");

// %% [markdown]
// ### Exercise 392: Peekable Iterator
//
// Use `peekable()` and `peek()` to look at the next element without consuming it. Create iterator from `[1, 2, 3]`, peek (should be 1), then next (should be 1).

// %%
let mut iter = [1, 2, 3].into_iter().peekable();
let peeked = *iter.peek().unwrap();
let first = iter.next().unwrap();
// YOUR CODE HERE
(peeked, first)

// %%
assert_eq!(peeked, 1);
assert_eq!(first, 1);
println!("✅ Exercise 392 passed!");

// %% [markdown]
// ### Exercise 393: partition()
//
// Use `partition()` on `[1, 2, 3, 4, 5, 6]` to split into (evens, odds). Store in `(evens, odds)`.

// %%
let (evens, odds): (Vec<i32>, Vec<i32>) = [1, 2, 3, 4, 5, 6].into_iter().partition(|x| *x % 2 == 0);
// YOUR CODE HERE
(evens, odds)

// %%
assert_eq!(evens, vec![2, 4, 6]);
assert_eq!(odds, vec![1, 3, 5]);
println!("✅ Exercise 393 passed!");

// %% [markdown]
// ### Exercise 394: last() Method
//
// Use `last()` on `[1, 2, 3, 4, 5]` to get the final element. Store in `last_elem`.

// %%
let last_elem: Option<i32> = [1, 2, 3, 4, 5].into_iter().last();
// YOUR CODE HERE
last_elem

// %%
assert_eq!(last_elem, Some(5));
println!("✅ Exercise 394 passed!");

// %% [markdown]
// ### Exercise 395: reduce()
//
// Use `reduce()` on `[1, 2, 3, 4]` to compute the product. `reduce` takes a closure `|a, b| a * b`. Store in `prod`.

// %%
let prod: Option<i32> = [1, 2, 3, 4].into_iter().reduce(|a, b| a * b);
// YOUR CODE HERE
prod

// %%
assert_eq!(prod, Some(24));
assert_eq!([1i32].into_iter().reduce(|a, b| a + b), Some(1));
println!("✅ Exercise 395 passed!");

// %% [markdown]
// ### Exercise 396: try_fold
//
// Use `try_fold` (or `fold`) to sum `[1, 2, 3, 4, 5]` and return `Result<i32, ()>`. For this exercise, always return `Ok(sum)`.

// %%
let sum_result: Result<i32, ()> = [1, 2, 3, 4, 5].into_iter().try_fold(0, |acc, x| Ok(acc + x));
// YOUR CODE HERE
sum_result

// %%
assert_eq!(sum_result, Ok(15));
println!("✅ Exercise 396 passed!");

// %% [markdown]
// ### Exercise 397: Iterator of Iterators - flatten
//
// Use `flatten()` on `[[1, 2], [3], [4, 5]]` to get a flat iterator. Collect into `flat`.

// %%
let nested = vec![vec![1, 2], vec![3], vec![4, 5]];
let flat: Vec<i32> = nested.into_iter().flatten().collect();
// YOUR CODE HERE
flat

// %%
assert_eq!(flat, vec![1, 2, 3, 4, 5]);
println!("✅ Exercise 397 passed!");

// %% [markdown]
// ### Exercise 398: cycle() Infinite Iterator
//
// Use `cycle()` on `[1, 2, 3]` and `take(7)` to get `[1, 2, 3, 1, 2, 3, 1]`. Store in `cycled`.

// %%
let cycled: Vec<i32> = [1, 2, 3].into_iter().cycle().take(7).collect();
// YOUR CODE HERE
cycled

// %%
assert_eq!(cycled, vec![1, 2, 3, 1, 2, 3, 1]);
println!("✅ Exercise 398 passed!");

// %% [markdown]
// ### Exercise 399: Iterator Adapter Chain
//
// From `[5, 2, 8, 1, 9, 3]`: filter to keep only values > 3, then sort (collect and sort). Store in `filtered_sorted`.

// %%
let mut filtered_sorted: Vec<i32> = [5, 2, 8, 1, 9, 3].into_iter().filter(|x| *x > 3).collect();
filtered_sorted.sort();
// YOUR CODE HERE
filtered_sorted

// %%
assert_eq!(filtered_sorted, vec![5, 8, 9]);
println!("✅ Exercise 399 passed!");

// %% [markdown]
// ### Exercise 400: Custom Iterator - Fibonacci
//
// Implement `Iterator` for `Fibonacci` that yields the Fibonacci sequence: 0, 1, 1, 2, 3, 5, 8, ... Take first 7 and collect.

// %%
struct Fibonacci { a: u64, b: u64 }
impl Iterator for Fibonacci {
    type Item = u64;
    fn next(&mut self) -> Option<u64> {
        // YOUR CODE HERE
    }
}
let fib: Vec<u64> = Fibonacci { a: 0, b: 1 }.take(7).collect();

// %%
assert_eq!(fib, vec![0, 1, 1, 2, 3, 5, 8]);
println!("✅ Exercise 400 passed!");
