// %% [markdown]
// # 🦀 Rust Exercises — Part 9: Modules & Testing (E401–E450)

// %% [markdown]
// ### Exercise 401: Define a Module
//
// Define a module `math` with a function `add(a: i32, b: i32) -> i32` that returns `a + b`.

// %%
mod math {
    pub fn add(a: i32, b: i32) -> i32 {
        // YOUR CODE HERE
    }
}
let result = math::add(2, 3);

// %%
assert_eq!(result, 5);
assert_eq!(math::add(0, 0), 0);
assert_eq!(math::add(-1, 1), 0);
println!("✅ Exercise 401 passed!");

// %% [markdown]
// ### Exercise 402: pub Function
//
// Define module `utils` with a **public** function `greet() -> String` that returns `"Hello!"`. Call it from outside the module.

// %%
mod utils {
    pub fn greet() -> String {
        // YOUR CODE HERE
    }
}
let msg = utils::greet();

// %%
assert_eq!(msg, "Hello!");
println!("✅ Exercise 402 passed!");

// %% [markdown]
// ### Exercise 403: use Declaration
//
// Define module `calc` with `pub fn double(x: i32) -> i32`. Use `use calc::double` and call `double(21)`.

// %%
mod calc {
    pub fn double(x: i32) -> i32 { x * 2 }
}
use calc::double;
// YOUR CODE HERE
let result = double(21);

// %%
assert_eq!(result, 42);
assert_eq!(double(0), 0);
println!("✅ Exercise 403 passed!");

// %% [markdown]
// ### Exercise 404: Module with Struct
//
// Define module `shapes` with a public struct `Point { pub x: i32, pub y: i32 }`. Create `Point { x: 1, y: 2 }` from outside.

// %%
mod shapes {
    pub struct Point { pub x: i32, pub y: i32 }
}
// YOUR CODE HERE
let p = shapes::Point { x: 1, y: 2 };

// %%
assert_eq!(p.x, 1);
assert_eq!(p.y, 2);
println!("✅ Exercise 404 passed!");

// %% [markdown]
// ### Exercise 405: Nested Module
//
// Define `outer` containing nested module `inner` with `pub fn value() -> i32 { 42 }`. Call `outer::inner::value()`.

// %%
mod outer {
    pub mod inner {
        pub fn value() -> i32 { 42 }
    }
}
// YOUR CODE HERE
let v = outer::inner::value();

// %%
assert_eq!(v, 42);
println!("✅ Exercise 405 passed!");

// %% [markdown]
// ### Exercise 406: use with Alias
//
// Define `mod foo { pub fn bar() -> i32 { 1 } }`. Use `use foo::bar as baz` and call `baz()`.

// %%
mod foo { pub fn bar() -> i32 { 1 } }
use foo::bar as baz;
// YOUR CODE HERE
let r = baz();

// %%
assert_eq!(r, 1);
println!("✅ Exercise 406 passed!");

// %% [markdown]
// ### Exercise 407: pub(crate) Visibility
//
// Define module `internal` with `pub(crate) fn secret() -> &'static str { "visible" }`. Call it from the crate root.

// %%
mod internal {
    pub(crate) fn secret() -> &'static str { "visible" }
}
// YOUR CODE HERE
let s = internal::secret();

// %%
assert_eq!(s, "visible");
println!("✅ Exercise 407 passed!");

// %% [markdown]
// ### Exercise 408: use with Glob
//
// Define `mod items { pub fn a() -> i32 { 1 } pub fn b() -> i32 { 2 } }`. Use `use items::*` and call both `a()` and `b()`.

// %%
mod items {
    pub fn a() -> i32 { 1 }
    pub fn b() -> i32 { 2 }
}
use items::*;
// YOUR CODE HERE
let sum = a() + b();

// %%
assert_eq!(sum, 3);
assert_eq!(a(), 1);
assert_eq!(b(), 2);
println!("✅ Exercise 408 passed!");

// %% [markdown]
// ### Exercise 409: mod with Block
//
// Define `mod config` inline (block form) with `pub const MAX: i32 = 100`. Access `config::MAX`.

// %%
mod config {
    pub const MAX: i32 = 100;
}
// YOUR CODE HERE
let max_val = config::MAX;

// %%
assert_eq!(max_val, 100);
println!("✅ Exercise 409 passed!");

// %% [markdown]
// ### Exercise 410: Module with impl
//
// Define `mod counter` with a public struct `Counter` and `impl Counter { pub fn new() -> Self }` and `pub fn get(&self) -> i32`. Create and use it.

// %%
mod counter {
    pub struct Counter { value: i32 }
    impl Counter {
        pub fn new() -> Self { Counter { value: 0 } }
        pub fn get(&self) -> i32 { self.value }
    }
}
// YOUR CODE HERE
let c = counter::Counter::new();

// %%
assert_eq!(c.get(), 0);
println!("✅ Exercise 410 passed!");

// %% [markdown]
// ### Exercise 411: crate:: Path
//
// Define a top-level function `root_fn() -> i32 { 10 }`. In a module `sub`, define a function that calls the crate root function using `crate::root_fn()`.

// %%
fn root_fn() -> i32 { 10 }
mod sub {
    pub fn call_root() -> i32 {
        crate::root_fn()
    }
}
// YOUR CODE HERE
let r = sub::call_root();

// %%
assert_eq!(r, 10);
println!("✅ Exercise 411 passed!");

// %% [markdown]
// ### Exercise 412: super:: Path
//
// Define `mod parent { pub fn value() -> i32 { 5 } pub mod child { pub fn get_parent() -> i32 { super::value() } } }`. Call `parent::child::get_parent()`.

// %%
mod parent {
    pub fn value() -> i32 { 5 }
    pub mod child {
        pub fn get_parent() -> i32 { super::value() }
    }
}
// YOUR CODE HERE
let v = parent::child::get_parent();

// %%
assert_eq!(v, 5);
println!("✅ Exercise 412 passed!");

// %% [markdown]
// ### Exercise 413: self:: Path
//
// In module `m`, use `self::helper()` to call a private function `fn helper() -> i32 { 7 }`. Expose via `pub fn public_api() -> i32 { self::helper() }`.

// %%
mod m {
    fn helper() -> i32 { 7 }
    pub fn public_api() -> i32 { self::helper() }
}
// YOUR CODE HERE
let r = m::public_api();

// %%
assert_eq!(r, 7);
println!("✅ Exercise 413 passed!");

// %% [markdown]
// ### Exercise 414: Private by Default
//
// Define `mod hidden { fn secret() -> i32 { 42 } }`. Verify that `hidden::secret()` is NOT accessible from outside (we'll test via a public wrapper). Add `pub fn get_secret() -> i32 { secret() }`.

// %%
mod hidden {
    fn secret() -> i32 { 42 }
    pub fn get_secret() -> i32 { secret() }
}
// YOUR CODE HERE - use get_secret, not secret
let v = hidden::get_secret();

// %%
assert_eq!(v, 42);
println!("✅ Exercise 414 passed!");

// %% [markdown]
// ### Exercise 415: Struct Field Visibility
//
// Define `mod data` with `pub struct Record { pub id: i32, name: String }`. Create a `Record` - you can set `id` but not `name` from outside. Add a constructor `pub fn new(id: i32, name: String) -> Self`.

// %%
mod data {
    pub struct Record { pub id: i32, pub(crate) name: String }
    impl Record {
        pub fn new(id: i32, name: String) -> Self { Record { id, name } }
    }
}
// YOUR CODE HERE
let r = data::Record::new(1, String::from("Alice"));

// %%
assert_eq!(r.id, 1);
println!("✅ Exercise 415 passed!");

// %% [markdown]
// ### Exercise 416: use with Nested Path
//
// Define `mod a { pub mod b { pub fn f() -> i32 { 1 } } }`. Use `use a::b::f` and call `f()`.

// %%
mod a { pub mod b { pub fn f() -> i32 { 1 } } }
use a::b::f;
// YOUR CODE HERE
let r = f();

// %%
assert_eq!(r, 1);
println!("✅ Exercise 416 passed!");

// %% [markdown]
// ### Exercise 417: Re-export
//
// Define `mod inner { pub fn foo() -> i32 { 2 } }` and `mod outer { pub use crate::inner::foo; }`. Call `outer::foo()`.

// %%
mod inner { pub fn foo() -> i32 { 2 } }
mod outer { pub use crate::inner::foo; }
// YOUR CODE HERE
let r = outer::foo();

// %%
assert_eq!(r, 2);
println!("✅ Exercise 417 passed!");

// %% [markdown]
// ### Exercise 418: Multiple use
//
// Define `mod lib { pub fn a() -> i32 { 1 } pub fn b() -> i32 { 2 } }`. Use `use lib::{a, b}` and call both.

// %%
mod lib {
    pub fn a() -> i32 { 1 }
    pub fn b() -> i32 { 2 }
}
use lib::{a, b};
// YOUR CODE HERE
let sum = a() + b();

// %%
assert_eq!(sum, 3);
println!("✅ Exercise 418 passed!");

// %% [markdown]
// ### Exercise 419: Enum Variant Visibility
//
// Define `mod kinds { pub enum Kind { A, B } }`. Create `Kind::A` and `Kind::B` from outside.

// %%
mod kinds {
    pub enum Kind { A, B }
}
// YOUR CODE HERE
let a = kinds::Kind::A;
let b = kinds::Kind::B;

// %%
use kinds::Kind;
match a { Kind::A => assert!(true), _ => panic!() };
match b { Kind::B => assert!(true), _ => panic!() };
println!("✅ Exercise 419 passed!");

// %% [markdown]
// ### Exercise 420: Full Path
//
// Use the full path `crate::module::item` to call a function. Define `mod module { pub fn item() -> i32 { 3 } }` and call via `crate::module::item()`.

// %%
mod module { pub fn item() -> i32 { 3 } }
// YOUR CODE HERE
let r = crate::module::item();

// %%
assert_eq!(r, 3);
println!("✅ Exercise 420 passed!");

// %% [markdown]
// ### Exercise 421: Basic #[test] Function
//
// Write a function `add(a: i32, b: i32) -> i32` and a `#[test]` function that asserts `add(2, 3) == 5`. Run the assertions in the test cell.

// %%
fn add(a: i32, b: i32) -> i32 { a + b }
#[cfg(test)]
mod tests {
    use super::*;
    #[test]
    fn test_add() {
        assert_eq!(add(2, 3), 5);
    }
}
// In notebook we run assertions directly:
let _ = add(0, 0);

// %%
assert_eq!(add(2, 3), 5);
assert_eq!(add(0, 0), 0);
assert_eq!(add(-1, 1), 0);
println!("✅ Exercise 421 passed!");

// %% [markdown]
// ### Exercise 422: assert! Macro
//
// Write a function `is_positive(n: i32) -> bool` and use `assert!` in the test cell to verify it.

// %%
fn is_positive(n: i32) -> bool {
    // YOUR CODE HERE
}
is_positive(1)

// %%
assert!(is_positive(1));
assert!(is_positive(100));
assert!(!is_positive(0));
assert!(!is_positive(-5));
println!("✅ Exercise 422 passed!");

// %% [markdown]
// ### Exercise 423: assert_eq! and assert_ne!
//
// Write `double(x: i32) -> i32` and test with both `assert_eq!` and `assert_ne!`.

// %%
fn double(x: i32) -> i32 {
    // YOUR CODE HERE
}
double(5)

// %%
assert_eq!(double(5), 10);
assert_eq!(double(0), 0);
assert_ne!(double(3), 5);
println!("✅ Exercise 423 passed!");

// %% [markdown]
// ### Exercise 424: assert with Message
//
// Write `max(a: i32, b: i32) -> i32` and use `assert!(max(3, 5) == 5, "max should return larger value")`.

// %%
fn max(a: i32, b: i32) -> i32 {
    if a >= b { a } else { b }
}
// YOUR CODE HERE
max(3, 5)

// %%
assert!(max(3, 5) == 5, "max should return larger value");
assert_eq!(max(10, 10), 10);
println!("✅ Exercise 424 passed!");

// %% [markdown]
// ### Exercise 425: Test String Function
//
// Write `greet(name: &str) -> String` returning `format!("Hello, {}!", name)`. Test with `assert_eq!`.

// %%
fn greet(name: &str) -> String {
    // YOUR CODE HERE
}
greet("Rust")

// %%
assert_eq!(greet("Rust"), "Hello, Rust!");
assert_eq!(greet("World"), "Hello, World!");
println!("✅ Exercise 425 passed!");

// %% [markdown]
// ### Exercise 426: Test Option Return
//
// Write `first_char(s: &str) -> Option<char>` that returns the first character. Test `Some` and `None` cases.

// %%
fn first_char(s: &str) -> Option<char> {
    // YOUR CODE HERE
}
first_char("hi")

// %%
assert_eq!(first_char("hi"), Some('h'));
assert_eq!(first_char("x"), Some('x'));
assert_eq!(first_char(""), None);
println!("✅ Exercise 426 passed!");

// %% [markdown]
// ### Exercise 427: Test Vec
//
// Write `reverse(v: Vec<i32>) -> Vec<i32>` that reverses the vector. Test with `assert_eq!`.

// %%
fn reverse(v: Vec<i32>) -> Vec<i32> {
    let mut out: Vec<i32> = v.into_iter().collect();
    out.reverse();
    out
}
// YOUR CODE HERE - or implement reverse manually
reverse(vec![1, 2, 3])

// %%
assert_eq!(reverse(vec![1, 2, 3]), vec![3, 2, 1]);
assert_eq!(reverse(vec![1]), vec![1]);
println!("✅ Exercise 427 passed!");

// %% [markdown]
// ### Exercise 428: Multiple Assertions
//
// Write `clamp(n: i32, lo: i32, hi: i32) -> i32` and add at least 3 test assertions.

// %%
fn clamp(n: i32, lo: i32, hi: i32) -> i32 {
    // YOUR CODE HERE
}
clamp(5, 0, 10)

// %%
assert_eq!(clamp(5, 0, 10), 5);
assert_eq!(clamp(-5, 0, 10), 0);
assert_eq!(clamp(15, 0, 10), 10);
assert_eq!(clamp(0, 0, 10), 0);
println!("✅ Exercise 428 passed!");

// %% [markdown]
// ### Exercise 429: Test with Different Types
//
// Write a generic `identity<T>(x: T) -> T` and test with `i32`, `&str`, and `bool`.

// %%
fn identity<T>(x: T) -> T {
    // YOUR CODE HERE
}
identity(42)

// %%
assert_eq!(identity(42), 42);
assert_eq!(identity("hi"), "hi");
assert_eq!(identity(true), true);
println!("✅ Exercise 429 passed!");

// %% [markdown]
// ### Exercise 430: Debug Format in Assert
//
// Use `assert_eq!` with a struct that implements `Debug`. Define a simple struct and test it.

// %%
#[derive(Debug, PartialEq)]
struct Point { x: i32, y: i32 }
fn make_origin() -> Point { Point { x: 0, y: 0 } }
// YOUR CODE HERE
make_origin()

// %%
assert_eq!(make_origin(), Point { x: 0, y: 0 });
assert_eq!(Point { x: 1, y: 2 }, Point { x: 1, y: 2 });
println!("✅ Exercise 430 passed!");

// %% [markdown]
// ### Exercise 431: #[should_panic]
//
// Write `panic_if_negative(n: i32)` that panics if `n < 0`. In the test cell, verify it panics for -1 and does not panic for 0.

// %%
fn panic_if_negative(n: i32) {
    // YOUR CODE HERE
}
panic_if_negative(0)

// %%
panic_if_negative(0);
panic_if_negative(1);
let did_panic = std::panic::catch_unwind(|| panic_if_negative(-1)).is_err();
assert!(did_panic, "panic_if_negative(-1) should panic");
println!("✅ Exercise 431 passed!");

// %% [markdown]
// ### Exercise 432: Result in Tests
//
// Write `parse_positive(s: &str) -> Result<i32, String>` that returns `Ok(n)` if the string parses to a positive i32, else `Err`. Test both cases.

// %%
fn parse_positive(s: &str) -> Result<i32, String> {
    // YOUR CODE HERE
}
parse_positive("42")

// %%
assert_eq!(parse_positive("42"), Ok(42));
assert!(parse_positive("-1").is_err());
assert!(parse_positive("abc").is_err());
println!("✅ Exercise 432 passed!");

// %% [markdown]
// ### Exercise 433: Test Module Organization
//
// Put tests in a `#[cfg(test)] mod tests` block. Define `fn mul(a: i32, b: i32) -> i32` and test it from the tests module.

// %%
fn mul(a: i32, b: i32) -> i32 { a * b }
#[cfg(test)]
mod tests {
    use super::*;
    #[test]
    fn test_mul() { assert_eq!(mul(2, 3), 6); }
}
// Run assertions directly:
mul(2, 3)

// %%
assert_eq!(mul(2, 3), 6);
assert_eq!(mul(0, 100), 0);
assert_eq!(mul(-2, 3), -6);
println!("✅ Exercise 433 passed!");

// %% [markdown]
// ### Exercise 434: Integration-Style Test
//
// Write `concat(a: &str, b: &str) -> String` and test the full flow with multiple inputs.

// %%
fn concat(a: &str, b: &str) -> String {
    // YOUR CODE HERE
}
concat("Hello", " World")

// %%
assert_eq!(concat("Hello", " World"), "Hello World");
assert_eq!(concat("", "x"), "x");
assert_eq!(concat("a", "b"), "ab");
println!("✅ Exercise 434 passed!");

// %% [markdown]
// ### Exercise 435: Test with Setup
//
// Write a function that uses a "setup" value. E.g. `fn add_offset(x: i32, offset: i32) -> i32`. Test with offset=10.

// %%
fn add_offset(x: i32, offset: i32) -> i32 {
    // YOUR CODE HERE
}
add_offset(5, 10)

// %%
let offset = 10;
assert_eq!(add_offset(5, offset), 15);
assert_eq!(add_offset(0, offset), 10);
println!("✅ Exercise 435 passed!");

// %% [markdown]
// ### Exercise 436: Test Edge Cases
//
// Write `div(a: i32, b: i32) -> Option<i32>` that returns `Some(a/b)` if `b != 0` else `None`. Test edge cases: b=0, a=0, negative.

// %%
fn div(a: i32, b: i32) -> Option<i32> {
    // YOUR CODE HERE
}
div(10, 2)

// %%
assert_eq!(div(10, 2), Some(5));
assert_eq!(div(10, 0), None);
assert_eq!(div(0, 5), Some(0));
assert_eq!(div(-10, 2), Some(-5));
println!("✅ Exercise 436 passed!");

// %% [markdown]
// ### Exercise 437: Test with assert!(predicate)
//
// Write `is_even(n: i32) -> bool` and test using `assert!(is_even(4))` and `assert!(!is_even(5))`.

// %%
fn is_even(n: i32) -> bool {
    // YOUR CODE HERE
}
is_even(4)

// %%
assert!(is_even(4));
assert!(!is_even(5));
assert!(is_even(0));
assert!(!is_even(-1));
println!("✅ Exercise 437 passed!");

// %% [markdown]
// ### Exercise 438: Test Vec Methods
//
// Write `sum_vec(v: &[i32]) -> i32` and test with empty, single, and multiple elements.

// %%
fn sum_vec(v: &[i32]) -> i32 {
    // YOUR CODE HERE
}
sum_vec(&[1, 2, 3])

// %%
assert_eq!(sum_vec(&[]), 0);
assert_eq!(sum_vec(&[1]), 1);
assert_eq!(sum_vec(&[1, 2, 3]), 6);
println!("✅ Exercise 438 passed!");

// %% [markdown]
// ### Exercise 439: Test with ? Operator
//
// Write a test that uses `?` to propagate errors. `fn safe_div(a: i32, b: i32) -> Result<i32, String>` and test with `unwrap()` or pattern match.

// %%
fn safe_div(a: i32, b: i32) -> Result<i32, String> {
    if b == 0 { Err("divide by zero".into()) } else { Ok(a / b) }
}
// YOUR CODE HERE
safe_div(10, 2)

// %%
assert_eq!(safe_div(10, 2).unwrap(), 5);
assert!(safe_div(10, 0).is_err());
println!("✅ Exercise 439 passed!");

// %% [markdown]
// ### Exercise 440: Test Module Visibility
//
// Define `mod math { pub fn add(a: i32, b: i32) -> i32 { a + b } }` and `#[cfg(test)] mod tests { use super::math; #[test] fn t() { assert_eq!(math::add(1,2), 3); } }`. Run assertion.

// %%
mod math { pub fn add(a: i32, b: i32) -> i32 { a + b } }
#[cfg(test)]
mod test_math {
    use super::math;
    #[test]
    fn test_add() { assert_eq!(math::add(1, 2), 3); }
}
math::add(1, 2)

// %%
assert_eq!(math::add(1, 2), 3);
println!("✅ Exercise 440 passed!");

// %% [markdown]
// ### Exercise 441: Doc Test - Basic
//
// Add a doc comment to `fn square(x: i32) -> i32` with an example that would run as a doctest: `/// Returns x squared.` and `/// # Example` with `assert_eq!(square(3), 9)`.

// %%
/// Returns x squared.
/// # Example
/// ```
/// assert_eq!(square(3), 9);
/// ```
fn square(x: i32) -> i32 {
    // YOUR CODE HERE
}
square(3)

// %%
assert_eq!(square(3), 9);
assert_eq!(square(0), 0);
assert_eq!(square(-2), 4);
println!("✅ Exercise 441 passed!");

// %% [markdown]
// ### Exercise 442: Doc Test with use
//
// Write a function with a doc example that uses `use` in the example block.

// %%
/// Doubles the input.
/// # Example
/// ```
/// let result = double_val(5);
/// assert_eq!(result, 10);
/// ```
fn double_val(x: i32) -> i32 { x * 2 }
// YOUR CODE HERE
double_val(5)

// %%
assert_eq!(double_val(5), 10);
println!("✅ Exercise 442 passed!");

// %% [markdown]
// ### Exercise 443: Doc Test ignore
//
// Add a doc example that is `/// ```ignore` so it doesn't run. The main function should still be tested in the test cell.

// %%
/// Returns 42.
/// # Example (ignored - would need external dep)
/// ```ignore
/// assert_eq!(answer(), 42);
/// ```
fn answer() -> i32 { 42 }
// Test in cell:
answer()

// %%
assert_eq!(answer(), 42);
println!("✅ Exercise 443 passed!");

// %% [markdown]
// ### Exercise 444: Test with Struct
//
// Define `struct User { name: String, age: u8 }` and `fn is_adult(u: &User) -> bool { u.age >= 18 }`. Test with different ages.

// %%
struct User { name: String, age: u8 }
fn is_adult(u: &User) -> bool {
    // YOUR CODE HERE
}
let u = User { name: String::from("Alice"), age: 25 };

// %%
assert!(is_adult(&User { name: String::from("A"), age: 25 }));
assert!(is_adult(&User { name: String::from("B"), age: 18 }));
assert!(!is_adult(&User { name: String::from("C"), age: 17 }));
println!("✅ Exercise 444 passed!");

// %% [markdown]
// ### Exercise 445: Test with Enum
//
// Define `enum Status { Active, Inactive }` and `fn is_active(s: Status) -> bool`. Test both variants.

// %%
enum Status { Active, Inactive }
fn is_active(s: Status) -> bool {
    // YOUR CODE HERE
}
is_active(Status::Active)

// %%
assert!(is_active(Status::Active));
assert!(!is_active(Status::Inactive));
println!("✅ Exercise 445 passed!");

// %% [markdown]
// ### Exercise 446: Parametrized Test Pattern
//
// Test `abs(n: i32) -> i32` with a list of (input, expected) pairs using a loop or multiple assertions.

// %%
fn abs(n: i32) -> i32 {
    if n < 0 { -n } else { n }
}
// YOUR CODE HERE - test multiple cases
let cases = [(0, 0), (5, 5), (-3, 3)];

// %%
let cases = [(0, 0), (5, 5), (-3, 3)];
for (input, expected) in cases {
    assert_eq!(abs(input), expected);
}
println!("✅ Exercise 446 passed!");

// %% [markdown]
// ### Exercise 447: Test Panic Message
//
// Use `catch_unwind` to verify that a function panics with a specific message (or any panic). `fn must_be_positive(n: i32)` panics if n <= 0.

// %%
fn must_be_positive(n: i32) {
    if n <= 0 { panic!("n must be positive"); }
}
// YOUR CODE HERE
must_be_positive(1)

// %%
must_be_positive(1);
let panicked = std::panic::catch_unwind(|| must_be_positive(0)).is_err();
assert!(panicked);
println!("✅ Exercise 447 passed!");

// %% [markdown]
// ### Exercise 448: Test with Float
//
// Write `approx_eq(a: f64, b: f64) -> bool` that returns true if `(a - b).abs() < 1e-10`. Test with floating point values.

// %%
fn approx_eq(a: f64, b: f64) -> bool {
    // YOUR CODE HERE
}
approx_eq(1.0, 1.0)

// %%
assert!(approx_eq(1.0, 1.0));
assert!(approx_eq(3.14159, 3.14159));
assert!(!approx_eq(1.0, 2.0));
println!("✅ Exercise 448 passed!");

// %% [markdown]
// ### Exercise 449: Test with HashMap
//
// Write `get_or_default<K, V>(map: &std::collections::HashMap<K, V>, k: K, default: V) -> V` where `K: Eq + Hash`. Test with a HashMap.

// %%
use std::collections::HashMap;
fn get_or_default<K: Eq + std::hash::Hash, V: Clone>(map: &HashMap<K, V>, k: K, default: V) -> V {
    map.get(&k).cloned().unwrap_or(default)
}
// YOUR CODE HERE - create map and test
let mut m: HashMap<i32, &str> = HashMap::new();
m.insert(1, "one");
// YOUR CODE HERE - m is used in test cell
m

// %%
assert_eq!(get_or_default(&m, 1, "default"), "one");
assert_eq!(get_or_default(&m, 2, "default"), "default");
println!("✅ Exercise 449 passed!");

// %% [markdown]
// ### Exercise 450: Full Test Suite
//
// Write `factorial(n: u32) -> u32` and add a comprehensive test: n=0, n=1, n=5, and verify factorial(5)==120.

// %%
fn factorial(n: u32) -> u32 {
    // YOUR CODE HERE
}
factorial(5)

// %%
assert_eq!(factorial(0), 1);
assert_eq!(factorial(1), 1);
assert_eq!(factorial(5), 120);
assert_eq!(factorial(6), 720);
println!("✅ Exercise 450 passed!");
