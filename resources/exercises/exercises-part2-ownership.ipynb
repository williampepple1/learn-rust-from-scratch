// %% [markdown]
// # 🦀 Rust Exercises — Part 2: Ownership & Borrowing (E51–E100)

// %% [markdown]
// ### Exercise 51: Move Semantics
//
// Create `s = String::from("hello")`, then move it to `t`. Do not use clone.

// %%
let s = String::from("hello");
let t = s;
// s is moved, t owns it
// YOUR CODE HERE
t.len()

// %%
let s = String::from("hello");
let t = s;
assert_eq!(t, "hello");
assert_eq!(t.len(), 5);
println!("✅ Exercise 51 passed!");

// %% [markdown]
// ### Exercise 52: Clone
//
// Create `a = String::from("rust")`, clone to `b`, so both are valid.

// %%
let a = String::from("rust");
let b = a.clone();
// YOUR CODE HERE
(a.len(), b.len())

// %%
let a = String::from("rust");
let b = a.clone();
assert_eq!(a, "rust");
assert_eq!(b, "rust");
println!("✅ Exercise 52 passed!");

// %% [markdown]
// ### Exercise 53: Copy Type
//
// Assign `x = 5` to `y`, then use both (i32 is Copy).

// %%
let x = 5;
let y = x;
// YOUR CODE HERE
(x + y)

// %%
assert_eq!(x, 5);
assert_eq!(y, 5);
assert_eq!(x + y, 10);
println!("✅ Exercise 53 passed!");

// %% [markdown]
// ### Exercise 54: Ownership in Function
//
// Write `take_ownership(s: String) -> usize` returning s.len().

// %%
fn take_ownership(s: String) -> usize {
    // YOUR CODE HERE
}
take_ownership(String::from("test"))

// %%
assert_eq!(take_ownership(String::from("test")), 4);
assert_eq!(take_ownership(String::from("hello")), 5);
println!("✅ Exercise 54 passed!");

// %% [markdown]
// ### Exercise 55: Return Ownership
//
// Write `give_string() -> String` returning String::from("owned").

// %%
fn give_string() -> String {
    // YOUR CODE HERE
}
give_string()

// %%
assert_eq!(give_string(), "owned");
println!("✅ Exercise 55 passed!");

// %% [markdown]
// ### Exercise 56: Move and Return
//
// Write `move_and_return(v: Vec<i32>) -> Vec<i32>` that pushes 4 and returns v.

// %%
fn move_and_return(mut v: Vec<i32>) -> Vec<i32> {
    // YOUR CODE HERE
}
move_and_return(vec![1, 2, 3])

// %%
let v = move_and_return(vec![1, 2, 3]);
assert_eq!(v, vec![1, 2, 3, 4]);
println!("✅ Exercise 56 passed!");

// %% [markdown]
// ### Exercise 57: Copy vs Clone
//
// Create a struct that implements Copy (e.g. use (i32, i32) as a point).

// %%
#[derive(Clone, Copy)]
struct Point { x: i32, y: i32 }
let p = Point { x: 1, y: 2 };
let q = p;
// YOUR CODE HERE
(p.x + q.x)

// %%
assert_eq!(p.x, 1);
assert_eq!(q.x, 1);
assert_eq!(p.x + q.x, 2);
println!("✅ Exercise 57 passed!");

// %% [markdown]
// ### Exercise 58: Ownership Chain
//
// Create String, pass to fn that returns it, then use it again.

// %%
fn identity(s: String) -> String { s }
let s = String::from("chain");
let s = identity(s);
// YOUR CODE HERE
s

// %%
assert_eq!(s, "chain");
println!("✅ Exercise 58 passed!");

// %% [markdown]
// ### Exercise 59: Vec Move
//
// Create `v = vec![1, 2, 3]`, move to function that returns it, then push 4.

// %%
fn take_vec(v: Vec<i32>) -> Vec<i32> { v }
let mut v = vec![1, 2, 3];
v = take_vec(v);
v.push(4);
// YOUR CODE HERE
v

// %%
assert_eq!(v, vec![1, 2, 3, 4]);
println!("✅ Exercise 59 passed!");

// %% [markdown]
// ### Exercise 60: Multiple Moves
//
// Create String, move to s1, then move s1 to s2. Only s2 is valid.

// %%
let s = String::from("moved");
let s1 = s;
let s2 = s1;
// YOUR CODE HERE
s2

// %%
assert_eq!(s2, "moved");
println!("✅ Exercise 60 passed!");

// %% [markdown]
// ### Exercise 61: Immutable Reference
//
// Write `len(s: &String) -> usize` returning s.len() without taking ownership.

// %%
fn len(s: &String) -> usize {
    // YOUR CODE HERE
}
let s = String::from("hello");
len(&s)

// %%
let s = String::from("hello");
assert_eq!(len(&s), 5);
assert_eq!(s, "hello");
println!("✅ Exercise 61 passed!");

// %% [markdown]
// ### Exercise 62: Mutable Reference
//
// Write `append_hi(s: &mut String)` that pushes "hi" to s.

// %%
fn append_hi(s: &mut String) {
    // YOUR CODE HERE
}
let mut s = String::from("hello");
append_hi(&mut s)

// %%
let mut s = String::from("hello");
append_hi(&mut s);
assert_eq!(s, "hellohi");
println!("✅ Exercise 62 passed!");

// %% [markdown]
// ### Exercise 63: Multiple Immutable Refs
//
// Create &s and &s again (multiple immutable refs allowed).

// %%
let s = String::from("shared");
let r1 = &s;
let r2 = &s;
// YOUR CODE HERE
(r1.len(), r2.len())

// %%
assert_eq!(r1.len(), 6);
assert_eq!(r2.len(), 6);
println!("✅ Exercise 63 passed!");

// %% [markdown]
// ### Exercise 64: No Mutable While Immutable
//
// Borrow &s, use it, then after it's done borrow &mut s. (Show scope.)

// %%
let mut s = String::from("test");
{
    let r = &s;
    let _ = r.len();
}
let r2 = &mut s;
r2.push_str("!");
// YOUR CODE HERE
r2

// %%
assert_eq!(r2, "test!");
println!("✅ Exercise 64 passed!");

// %% [markdown]
// ### Exercise 65: Reference in Function
//
// Write `first_char(s: &str) -> Option<char>` returning first char.

// %%
fn first_char(s: &str) -> Option<char> {
    // YOUR CODE HERE
}
first_char("hello")

// %%
assert_eq!(first_char("hello"), Some('h'));
assert_eq!(first_char(""), None);
println!("✅ Exercise 65 passed!");

// %% [markdown]
// ### Exercise 66: Borrow in Loop
//
// Iterate over &v with for x in &v, sum elements.

// %%
let v = vec![1, 2, 3, 4, 5];
let mut sum = 0;
for x in &v {
    sum += x;
}
// YOUR CODE HERE
(sum, v.len())

// %%
assert_eq!(sum, 15);
assert_eq!(v.len(), 5);
println!("✅ Exercise 66 passed!");

// %% [markdown]
// ### Exercise 67: Mutable Borrow
//
// Write `double(n: &mut i32)` that multiplies *n by 2.

// %%
fn double(n: &mut i32) {
    // YOUR CODE HERE
}
let mut x = 5;
double(&mut x)

// %%
let mut x = 5;
double(&mut x);
assert_eq!(x, 10);
println!("✅ Exercise 67 passed!");

// %% [markdown]
// ### Exercise 68: Return Reference
//
// Write `get_first(v: &[i32]) -> Option<&i32>` returning v.first().

// %%
fn get_first(v: &[i32]) -> Option<&i32> {
    // YOUR CODE HERE
}
get_first(&[1, 2, 3])

// %%
assert_eq!(get_first(&[1, 2, 3]), Some(&1));
assert_eq!(get_first(&[]), None);
println!("✅ Exercise 68 passed!");

// %% [markdown]
// ### Exercise 69: Dereference
//
// Write `add_one(n: &mut i32)` using *n += 1.

// %%
fn add_one(n: &mut i32) {
    // YOUR CODE HERE
}
let mut x = 41;
add_one(&mut x)

// %%
let mut x = 41;
add_one(&mut x);
assert_eq!(x, 42);
println!("✅ Exercise 69 passed!");

// %% [markdown]
// ### Exercise 70: Ref and Mut Ref
//
// Write `swap(a: &mut i32, b: &mut i32)` swapping values.

// %%
fn swap(a: &mut i32, b: &mut i32) {
    // YOUR CODE HERE
}
let mut x = 1;
let mut y = 2;
swap(&mut x, &mut y)

// %%
let mut x = 1;
let mut y = 2;
swap(&mut x, &mut y);
assert_eq!(x, 2);
assert_eq!(y, 1);
println!("✅ Exercise 70 passed!");

// %% [markdown]
// ### Exercise 71: String Slice
//
// Create `s = "hello world"`, slice `&s[0..5]` to get "hello".

// %%
let s = "hello world";
let hello: &str = &s[0..5];
// YOUR CODE HERE
hello

// %%
assert_eq!(hello, "hello");
println!("✅ Exercise 71 passed!");

// %% [markdown]
// ### Exercise 72: Array Slice
//
// Create `arr = [1, 2, 3, 4, 5]`, get slice `&arr[1..4]`.

// %%
let arr = [1, 2, 3, 4, 5];
let slice: &[i32] = &arr[1..4];
// YOUR CODE HERE
slice

// %%
assert_eq!(slice, &[2, 3, 4]);
println!("✅ Exercise 72 passed!");

// %% [markdown]
// ### Exercise 73: Slice Length
//
// Write `slice_len(s: &[i32]) -> usize` returning s.len().

// %%
fn slice_len(s: &[i32]) -> usize {
    // YOUR CODE HERE
}
slice_len(&[1, 2, 3])

// %%
assert_eq!(slice_len(&[1, 2, 3]), 3);
assert_eq!(slice_len(&[]), 0);
println!("✅ Exercise 73 passed!");

// %% [markdown]
// ### Exercise 74: First Element
//
// Write `first_elem(s: &[i32]) -> Option<&i32>`.

// %%
fn first_elem(s: &[i32]) -> Option<&i32> {
    // YOUR CODE HERE
}
first_elem(&[10, 20, 30])

// %%
assert_eq!(first_elem(&[10, 20, 30]), Some(&10));
assert_eq!(first_elem(&[]), None);
println!("✅ Exercise 74 passed!");

// %% [markdown]
// ### Exercise 75: String Slice Function
//
// Write `first_word(s: &str) -> &str` returning first word (up to first space).

// %%
fn first_word(s: &str) -> &str {
    // YOUR CODE HERE
}
first_word("hello world")

// %%
assert_eq!(first_word("hello world"), "hello");
assert_eq!(first_word("rust"), "rust");
println!("✅ Exercise 75 passed!");

// %% [markdown]
// ### Exercise 76: Full Slice
//
// Create `v = vec![1, 2, 3]`, get full slice `&v[..]`.

// %%
let v = vec![1, 2, 3];
let slice: &[i32] = &v[..];
// YOUR CODE HERE
slice

// %%
assert_eq!(slice, &[1, 2, 3]);
println!("✅ Exercise 76 passed!");

// %% [markdown]
// ### Exercise 77: Slice from Start
//
// Get slice of "rust" from start to index 2: "ru".

// %%
let s = "rust";
let slice = &s[..2];
// YOUR CODE HERE
slice

// %%
assert_eq!(slice, "ru");
println!("✅ Exercise 77 passed!");

// %% [markdown]
// ### Exercise 78: Slice to End
//
// Get slice of "hello" from index 2 to end: "llo".

// %%
let s = "hello";
let slice = &s[2..];
// YOUR CODE HERE
slice

// %%
assert_eq!(slice, "llo");
println!("✅ Exercise 78 passed!");

// %% [markdown]
// ### Exercise 79: Mutable Slice
//
// Write `zero_slice(s: &mut [i32])` setting all elements to 0.

// %%
fn zero_slice(s: &mut [i32]) {
    // YOUR CODE HERE
}
let mut arr = [1, 2, 3];
zero_slice(&mut arr)

// %%
let mut arr = [1, 2, 3];
zero_slice(&mut arr);
assert_eq!(arr, [0, 0, 0]);
println!("✅ Exercise 79 passed!");

// %% [markdown]
// ### Exercise 80: Slice in Function
//
// Write `sum_slice(s: &[i32]) -> i32` returning sum of elements.

// %%
fn sum_slice(s: &[i32]) -> i32 {
    // YOUR CODE HERE
}
sum_slice(&[1, 2, 3, 4, 5])

// %%
assert_eq!(sum_slice(&[1, 2, 3, 4, 5]), 15);
assert_eq!(sum_slice(&[]), 0);
println!("✅ Exercise 80 passed!");

// %% [markdown]
// ### Exercise 81: String from &str
//
// Create `s: String` from "hello" using .to_string() or String::from().

// %%
let s: String = "hello".to_string();
// YOUR CODE HERE
s

// %%
assert_eq!(s, "hello");
println!("✅ Exercise 81 passed!");

// %% [markdown]
// ### Exercise 82: &str from String
//
// Create `s = String::from("hi")`, get `&str` via `&s` or `s.as_str()`.

// %%
let s = String::from("hi");
let slice: &str = s.as_str();
// YOUR CODE HERE
slice

// %%
assert_eq!(slice, "hi");
println!("✅ Exercise 82 passed!");

// %% [markdown]
// ### Exercise 83: Push Str
//
// Create `s = String::from("hello")`, push " world" with push_str.

// %%
let mut s = String::from("hello");
s.push_str(" world");
// YOUR CODE HERE
s

// %%
assert_eq!(s, "hello world");
println!("✅ Exercise 83 passed!");

// %% [markdown]
// ### Exercise 84: Push Char
//
// Create `s = String::new()`, push 'a', 'b', 'c' with push.

// %%
let mut s = String::new();
s.push('a');
s.push('b');
s.push('c');
// YOUR CODE HERE
s

// %%
assert_eq!(s, "abc");
println!("✅ Exercise 84 passed!");

// %% [markdown]
// ### Exercise 85: Concatenate
//
// Concatenate "hello" and " world" using format! or +.

// %%
let s = format!("hello{}", " world");
// YOUR CODE HERE
s

// %%
assert_eq!(s, "hello world");
println!("✅ Exercise 85 passed!");

// %% [markdown]
// ### Exercise 86: String Length
//
// Write `string_len(s: &String) -> usize` returning s.len() (bytes).

// %%
fn string_len(s: &String) -> usize {
    // YOUR CODE HERE
}
string_len(&String::from("hello"))

// %%
assert_eq!(string_len(&String::from("hello")), 5);
println!("✅ Exercise 86 passed!");

// %% [markdown]
// ### Exercise 87: Is Empty
//
// Write `is_empty(s: &str) -> bool` returning s.is_empty().

// %%
fn is_empty_str(s: &str) -> bool {
    // YOUR CODE HERE
}
is_empty_str("")

// %%
assert!(is_empty_str(""));
assert!(!is_empty_str("x"));
println!("✅ Exercise 87 passed!");

// %% [markdown]
// ### Exercise 88: Trim
//
// Create `s = "  hello  "`, trim whitespace.

// %%
let s = "  hello  ";
let trimmed = s.trim();
// YOUR CODE HERE
trimmed

// %%
assert_eq!(trimmed, "hello");
println!("✅ Exercise 88 passed!");

// %% [markdown]
// ### Exercise 89: Split
//
// Split "a,b,c" by comma, collect to Vec<&str>.

// %%
let s = "a,b,c";
let parts: Vec<&str> = s.split(',').collect();
// YOUR CODE HERE
parts

// %%
assert_eq!(parts, vec!["a", "b", "c"]);
println!("✅ Exercise 89 passed!");

// %% [markdown]
// ### Exercise 90: Replace
//
// Replace "hello world" with "hello rust" using .replace().

// %%
let s = "hello world".replace("world", "rust");
// YOUR CODE HERE
s

// %%
assert_eq!(s, "hello rust");
println!("✅ Exercise 90 passed!");

// %% [markdown]
// ### Exercise 91: Borrow or Move
//
// Write `use_string(s: &String)` that prints s, doesn't take ownership.

// %%
fn use_string(s: &String) {
    let _ = s.len();
}
let s = String::from("test");
use_string(&s);
// YOUR CODE HERE
s

// %%
assert_eq!(s, "test");
println!("✅ Exercise 91 passed!");

// %% [markdown]
// ### Exercise 92: Return Borrowed
//
// Write `longer(a: &str, b: &str) -> &str` returning the longer slice.

// %%
fn longer<'a>(a: &'a str, b: &'a str) -> &'a str {
    // YOUR CODE HERE
}
longer("short", "longer")

// %%
assert_eq!(longer("short", "longer"), "longer");
assert_eq!(longer("same", "same"), "same");
println!("✅ Exercise 92 passed!");

// %% [markdown]
// ### Exercise 93: Mutable in Function
//
// Write `clear(v: &mut Vec<i32>)` that clears the vector.

// %%
fn clear(v: &mut Vec<i32>) {
    // YOUR CODE HERE
}
let mut v = vec![1, 2, 3];
clear(&mut v)

// %%
let mut v = vec![1, 2, 3];
clear(&mut v);
assert!(v.is_empty());
println!("✅ Exercise 93 passed!");

// %% [markdown]
// ### Exercise 94: Clone When Needed
//
// Write `duplicate(s: &String) -> String` returning s.clone().

// %%
fn duplicate(s: &String) -> String {
    // YOUR CODE HERE
}
duplicate(&String::from("copy"))

// %%
let s = String::from("copy");
let t = duplicate(&s);
assert_eq!(s, "copy");
assert_eq!(t, "copy");
println!("✅ Exercise 94 passed!");

// %% [markdown]
// ### Exercise 95: Into String
//
// Write `into_string(s: String) -> String` that returns s (identity).

// %%
fn into_string(s: String) -> String {
    // YOUR CODE HERE
}
into_string(String::from("owned"))

// %%
assert_eq!(into_string(String::from("owned")), "owned");
println!("✅ Exercise 95 passed!");

// %% [markdown]
// ### Exercise 96: Borrow in Struct
//
// Create struct `Wrapper` with `value: String`. Implement `new` and `get` returning &str.

// %%
struct Wrapper { value: String }
impl Wrapper {
    fn new(s: String) -> Self { Self { value: s } }
    fn get(&self) -> &str { &self.value }
}
let w = Wrapper::new(String::from("wrapped"));
// YOUR CODE HERE
w.get()

// %%
assert_eq!(w.get(), "wrapped");
println!("✅ Exercise 96 passed!");

// %% [markdown]
// ### Exercise 97: Slice Parameter
//
// Write `last(s: &[i32]) -> Option<&i32>` returning last element.

// %%
fn last(s: &[i32]) -> Option<&i32> {
    // YOUR CODE HERE
}
last(&[1, 2, 3])

// %%
assert_eq!(last(&[1, 2, 3]), Some(&3));
assert_eq!(last(&[]), None);
println!("✅ Exercise 97 passed!");

// %% [markdown]
// ### Exercise 98: Iter and Mut
//
// Write `increment_all(v: &mut [i32])` adding 1 to each element.

// %%
fn increment_all(v: &mut [i32]) {
    // YOUR CODE HERE
}
let mut arr = [1, 2, 3];
increment_all(&mut arr)

// %%
let mut arr = [1, 2, 3];
increment_all(&mut arr);
assert_eq!(arr, [2, 3, 4]);
println!("✅ Exercise 98 passed!");

// %% [markdown]
// ### Exercise 99: String Slices
//
// Write `first_two(s: &str) -> &str` returning first 2 chars (or less).

// %%
fn first_two(s: &str) -> &str {
    // YOUR CODE HERE
}
first_two("hello")

// %%
assert_eq!(first_two("hello"), "he");
assert_eq!(first_two("a"), "a");
println!("✅ Exercise 99 passed!");

// %% [markdown]
// ### Exercise 100: Ownership Summary
//
// Write `process(s: &str) -> String` returning s.to_uppercase().

// %%
fn process(s: &str) -> String {
    // YOUR CODE HERE
}
process("hello")

// %%
assert_eq!(process("hello"), "HELLO");
println!("✅ Exercise 100 passed!");
