// %% [markdown]
// # 🦀 Rust Interview MCQ — Part 1: Basics & Syntax (Q1–Q100)
//
// **500 Multiple-Choice Questions for Rust Interview Preparation**
//
// Each question has 4 options (A–D) with the correct answer and explanation immediately below.
//
// ---

// %% [markdown]
// ### Q1. What is Rust primarily designed for?
//
// - A) Web development only
// - B) Systems programming with safety and performance
// - C) Mobile app development
// - D) Data science
//
// <details>
// <summary>Show Answer</summary>
//
// **Q1. B)** Systems programming with safety and performance. Rust focuses on memory safety, zero-cost abstractions, and concurrency.
//
// </details>

// %% [markdown]
// ### Q2. Who originally created Rust?
//
// - A) Microsoft
// - B) Mozilla Research (Graydon Hoare)
// - C) Google
// - D) The Linux Foundation
//
// <details>
// <summary>Show Answer</summary>
//
// **Q2. B)** Mozilla Research (Graydon Hoare). Rust was started by Graydon Hoare at Mozilla around 2006.
//
// </details>

// %% [markdown]
// ### Q3. What year did Rust reach version 1.0?
//
// - A) 2012
// - B) 2013
// - C) 2014
// - D) 2015
//
// <details>
// <summary>Show Answer</summary>
//
// **Q3. D)** 2015. Rust 1.0 was released on May 15, 2015.
//
// </details>

// %% [markdown]
// ### Q4. Which of these is NOT one of Rust's core design goals?
//
// - A) Memory safety without garbage collection
// - B) Zero-cost abstractions
// - C) Automatic memory management via GC
// - D) Fearless concurrency
//
// <details>
// <summary>Show Answer</summary>
//
// **Q4. C)** Automatic memory management via GC. Rust uses ownership and borrowing instead of garbage collection.
//
// </details>

// %% [markdown]
// ### Q5. What does `rustc` do?
//
// - A) Manages Rust versions and toolchains
// - B) Compiles Rust source code to machine code
// - C) Runs Rust tests only
// - D) Formats Rust code
//
// <details>
// <summary>Show Answer</summary>
//
// **Q5. B)** Compiles Rust source code to machine code. `rustc` is the Rust compiler.
//
// </details>

// %% [markdown]
// ### Q6. What is Cargo?
//
// - A) Rust's compiler
// - B) Rust's package manager and build system
// - C) A Rust IDE
// - D) Rust's standard library
//
// <details>
// <summary>Show Answer</summary>
//
// **Q6. B)** Rust's package manager and build system. Cargo handles building, testing, and dependency management.
//
// </details>

// %% [markdown]
// ### Q7. What command creates a new Rust project?
//
// - A) `rust new my_project`
// - B) `cargo new my_project`
// - C) `rustup new my_project`
// - D) `cargo init my_project`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q7. B)** `cargo new my_project`. This creates a new binary project with the standard structure.
//
// </details>

// %% [markdown]
// ### Q8. What does `rustup` manage?
//
// - A) Dependencies in Cargo.toml
// - B) Rust toolchain versions and installations
// - C) Code formatting
// - D) Documentation generation
//
// <details>
// <summary>Show Answer</summary>
//
// **Q8. B)** Rust toolchain versions and installations. `rustup` manages multiple Rust versions and targets.
//
// </details>

// %% [markdown]
// ### Q9. What is the default entry point of a Rust program?
//
// - A) `main()`
// - B) `start()`
// - C) `rust_main()`
// - D) `entry()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q9. A)** `main()`. Every executable Rust program starts with the `main` function.
//
// </details>

// %% [markdown]
// ### Q10. Which file defines project metadata and dependencies?
//
// - A) `Cargo.lock`
// - B) `cargo.toml`
// - C) `Cargo.toml`
// - D) `rust.toml`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q10. C)** `Cargo.toml`. Project metadata and dependencies are defined in `Cargo.toml` (capital C).
//
// </details>

// %% [markdown]
// ### Q11. By default, Rust variables are:
//
// - A) Mutable
// - B) Immutable
// - C) Constant
// - D) Static
//
// <details>
// <summary>Show Answer</summary>
//
// **Q11. B)** Immutable. Variables are immutable by default; use `mut` to make them mutable.
//
// </details>

// %% [markdown]
// ### Q12. What keyword makes a variable mutable?
//
// - A) `var`
// - B) `mut`
// - C) `mutable`
// - D) `let mut`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q12. B)** `mut`. The full declaration is `let mut x = 5;`.
//
// </details>

// %% [markdown]
// ### Q13. What is the output of this code?
// ```rust
// let x = 5;
// x = 6;
// println!("{}", x);
// ```
//
// - A) 5
// - B) 6
// - C) Compilation error
// - D) Runtime error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q13. C)** Compilation error. `x` is immutable, so reassigning causes a compile error.
//
// </details>

// %% [markdown]
// ### Q14. How do you declare a compile-time constant?
//
// - A) `let const MAX = 100;`
// - B) `const MAX: i32 = 100;`
// - C) `constant MAX = 100;`
// - D) `static MAX = 100;`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q14. B)** `const MAX: i32 = 100;`. Constants require a type annotation and a compile-time evaluable expression.
//
// </details>

// %% [markdown]
// ### Q15. What is variable shadowing?
//
// - A) Declaring a variable with the same name in a different scope, hiding the previous one
// - B) Making a variable mutable
// - C) Copying a variable's value
// - D) Declaring a constant with the same name as a variable
//
// <details>
// <summary>Show Answer</summary>
//
// **Q15. A)** Declaring a variable with the same name in a different scope, hiding the previous one. Shadowing creates a new variable.
//
// </details>

// %% [markdown]
// ### Q16. What does this code output?
// ```rust
// let x = 5;
// let x = x + 1;
// let x = x * 2;
// println!("{}", x);
// ```
//
// - A) 5
// - B) 6
// - C) 12
// - D) Compilation error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q16. C)** 12. Each `let x` shadows the previous: 5→6→12.
//
// </details>

// %% [markdown]
// ### Q17. Which naming convention does Rust use for variables?
//
// - A) camelCase
// - B) snake_case
// - C) PascalCase
// - D) kebab-case
//
// <details>
// <summary>Show Answer</summary>
//
// **Q17. B)** snake_case. Rust uses snake_case for variables, functions, and modules.
//
// </details>

// %% [markdown]
// ### Q18. What is the difference between `const` and `let`?
//
// - A) `const` is mutable, `let` is immutable
// - B) `const` must have a type annotation and must be a compile-time constant expression
// - C) `let` can only be used in functions
// - D) There is no difference
//
// <details>
// <summary>Show Answer</summary>
//
// **Q18. B)** `const` must have a type annotation and must be a compile-time constant expression. `let` can hold runtime values.
//
// </details>

// %% [markdown]
// ### Q19. Can you shadow a variable with a different type?
//
// - A) No, shadowing requires the same type
// - B) Yes, shadowing allows reusing the name with a different type
// - C) Only with `mut`
// - D) Only for numeric types
//
// <details>
// <summary>Show Answer</summary>
//
// **Q19. B)** Yes, shadowing allows reusing the name with a different type. e.g., `let x = 5; let x = "hello";`
//
// </details>

// %% [markdown]
// ### Q20. What does `static` declare?
//
// - A) A compile-time constant
// - B) A variable with global lifetime that exists for the entire program
// - C) An immutable variable
// - D) A thread-local variable
//
// <details>
// <summary>Show Answer</summary>
//
// **Q20. B)** A variable with global lifetime that exists for the entire program. `static` items have a fixed memory address.
//
// </details>

// %% [markdown]
// ### Q21. What is the default integer type when you write `let x = 42;`?
//
// - A) `i8`
// - B) `i32`
// - C) `i64`
// - D) `u32`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q21. B)** `i32`. The default integer type for numeric literals is `i32`.
//
// </details>

// %% [markdown]
// ### Q22. What is the range of `i8`?
//
// - A) 0 to 255
// - B) -128 to 127
// - C) -256 to 255
// - D) 0 to 127
//
// <details>
// <summary>Show Answer</summary>
//
// **Q22. B)** -128 to 127. `i8` is an 8-bit signed integer.
//
// </details>

// %% [markdown]
// ### Q23. What is the default floating-point type?
//
// - A) `f32`
// - B) `f64`
// - C) `float`
// - D) `double`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q23. B)** `f64`. Rust defaults to 64-bit floats for type inference.
//
// </details>

// %% [markdown]
// ### Q24. In Rust, what type is `true`?
//
// - A) `bool`
// - B) `boolean`
// - C) `i1`
// - D) `u8`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q24. A)** `bool`. Rust has a dedicated boolean type.
//
// </details>

// %% [markdown]
// ### Q25. How many bytes does a `char` occupy in Rust?
//
// - A) 1 byte
// - B) 2 bytes
// - C) 4 bytes
// - D) Variable (1–4 bytes)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q25. C)** 4 bytes. A `char` in Rust is a Unicode scalar value (U+0000 to U+D7FF or U+E000 to U+10FFFF).
//
// </details>

// %% [markdown]
// ### Q26. What does this code output?
// ```rust
// let x: u8 = 256;
// println!("{}", x);
// ```
//
// - A) 256
// - B) 0
// - C) Compilation error (overflow in literal)
// - D) Runtime panic
//
// <details>
// <summary>Show Answer</summary>
//
// **Q26. C)** Compilation error (overflow in literal). 256 is out of range for `u8` (0–255).
//
// </details>

// %% [markdown]
// ### Q27. How do you perform explicit type conversion (casting)?
//
// - A) `x as i32`
// - B) `(i32) x`
// - C) `convert::<i32>(x)`
// - D) `i32::from(x)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q27. A)** `x as i32`. The `as` keyword performs primitive type casting.
//
// </details>

// %% [markdown]
// ### Q28. What is the result of `10 / 3` in Rust when both operands are integers?
//
// - A) 3.333...
// - B) 3
// - C) 3.0
// - D) Compilation error (type mismatch)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q28. B)** 3. Integer division truncates toward zero; no automatic float conversion.
//
// </details>

// %% [markdown]
// ### Q29. Which suffix specifies a `u64` literal?
//
// - A) `u`
// - B) `u64`
// - C) `ul`
// - D) `L`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q29. B)** `u64`. e.g., `42u64` or `42_u64`.
//
// </details>

// %% [markdown]
// ### Q30. What does `let x = 3.14;` infer as the type of `x`?
//
// - A) `f32`
// - B) `f64`
// - C) `float`
// - D) Compilation error (ambiguous)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q30. B)** `f64`. Floating-point literals without a suffix default to `f64`.
//
// </details>

// %% [markdown]
// ### Q31. What is `&str` in Rust?
//
// - A) A growable, owned string
// - B) A string slice (borrowed view into UTF-8 text)
// - C) A mutable string buffer
// - D) A C-style null-terminated string
//
// <details>
// <summary>Show Answer</summary>
//
// **Q31. B)** A string slice (borrowed view into UTF-8 text). `&str` is an immutable reference to string data.
//
// </details>

// %% [markdown]
// ### Q32. What is `String` in Rust?
//
// - A) A fixed-size array of characters
// - B) An owned, growable UTF-8 string
// - C) A string slice
// - D) A reference to a string
//
// <details>
// <summary>Show Answer</summary>
//
// **Q32. B)** An owned, growable UTF-8 string. `String` allocates on the heap and can grow.
//
// </details>

// %% [markdown]
// ### Q33. How do you create a `String` from a string literal?
//
// - A) `"hello".to_string()`
// - B) `String::from("hello")`
// - C) Both A and B
// - D) `new String("hello")`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q33. C)** Both A and B. `"hello".to_string()` and `String::from("hello")` are equivalent.
//
// </details>

// %% [markdown]
// ### Q34. Are Rust strings UTF-8 encoded?
//
// - A) No, they use ASCII
// - B) No, they use UTF-16
// - C) Yes, both `&str` and `String` are UTF-8
// - D) Only `String` is UTF-8
//
// <details>
// <summary>Show Answer</summary>
//
// **Q34. C)** Yes, both `&str` and `String` are UTF-8. Rust guarantees valid UTF-8 for all string types.
//
// </details>

// %% [markdown]
// ### Q35. What does `"hello".len()` return?
//
// - A) 5 (number of characters)
// - B) 5 (number of bytes for ASCII)
// - C) 6 (including null terminator)
// - D) Depends on encoding
//
// <details>
// <summary>Show Answer</summary>
//
// **Q35. B)** 5 (number of bytes for ASCII). `len()` returns byte count; for "hello" that equals character count.
//
// </details>

// %% [markdown]
// ### Q36. What macro is used for formatted output?
//
// - A) `print!`
// - B) `println!`
// - C) `format!`
// - D) All of the above use formatting
//
// <details>
// <summary>Show Answer</summary>
//
// **Q36. D)** All of the above use formatting. `print!`, `println!`, and `format!` all use the same format string syntax.
//
// </details>

// %% [markdown]
// ### Q37. What does `format!("{:.2}", 3.14159)` produce?
//
// - A) `"3.14"`
// - B) `"3.14159"`
// - C) `"3.15"` (rounded)
// - D) Compilation error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q37. A)** `"3.14"`. `:.2` formats with 2 decimal places.
//
// </details>

// %% [markdown]
// ### Q38. How do you concatenate two `String` values?
//
// - A) `s1 + s2` (both must be `String`)
// - B) `format!("{}{}", s1, s2)`
// - C) `s1.push_str(&s2)`
// - D) All of the above (with appropriate types)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q38. D)** All of the above (with appropriate types). `+` requires `&str` on the right; `push_str` mutates; `format!` creates new.
//
// </details>

// %% [markdown]
// ### Q39. What does `"hello".chars()` return?
//
// - A) A `Vec<char>`
// - B) An iterator over Unicode scalar values
// - C) A slice of bytes
// - D) The string unchanged
//
// <details>
// <summary>Show Answer</summary>
//
// **Q39. B)** An iterator over Unicode scalar values. `chars()` yields `char` values, not bytes.
//
// </details>

// %% [markdown]
// ### Q40. What is the type of `"hello"`?
//
// - A) `String`
// - B) `&str`
// - C) `&[u8]`
// - D) `str`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q40. B)** `&str`. String literals have type `&'static str`.
//
// </details>

// %% [markdown]
// ### Q41. What is a tuple in Rust?
//
// - A) A fixed-size collection of heterogeneous elements
// - B) A growable list of same-type elements
// - C) A key-value mapping
// - D) A single value
//
// <details>
// <summary>Show Answer</summary>
//
// **Q41. A)** A fixed-size collection of heterogeneous elements. Tuples can hold different types.
//
// </details>

// %% [markdown]
// ### Q42. How do you access the first element of tuple `t`?
//
// - A) `t[0]`
// - B) `t.0`
// - C) `t.first`
// - D) `t.get(0)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q42. B)** `t.0`. Tuple elements are accessed by index with dot notation (`.0`, `.1`, etc.).
//
// </details>

// %% [markdown]
// ### Q43. What is the type of `[1, 2, 3]` in Rust?
//
// - A) `Vec<i32>`
// - B) `[i32; 3]` (array of 3 i32)
// - C) `&[i32]`
// - D) `(i32, i32, i32)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q43. B)** `[i32; 3]`. Square brackets with a semicolon denote a fixed-size array.
//
// </details>

// %% [markdown]
// ### Q44. Arrays in Rust have a fixed size that must be known at:
//
// - A) Runtime
// - B) Compile time
// - C) Either
// - D) Never (arrays are dynamic)
//
// <details>
// <summary>Show Answer</summary>
//
// **Q44. B)** Compile time. Array length is part of the type.
//
// </details>

// %% [markdown]
// ### Q45. What is a slice?
//
// - A) An owned contiguous sequence
// - B) A borrowed view into a contiguous sequence (array or Vec)
// - C) A copy of an array
// - D) A reference to a single element
//
// <details>
// <summary>Show Answer</summary>
//
// **Q45. B)** A borrowed view into a contiguous sequence. Slices are `&[T]` or `&mut [T]`.
//
// </details>

// %% [markdown]
// ### Q46. What is the type of `&arr[1..3]` when `arr` is `[i32; 5]`?
//
// - A) `[i32; 2]`
// - B) `&[i32]`
// - C) `Vec<i32>`
// - D) `(i32, i32)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q46. B)** `&[i32]`. A slice of the array from index 1 to 3 (exclusive).
//
// </details>

// %% [markdown]
// ### Q47. How do you create an empty `Vec<i32>`?
//
// - A) `Vec::new()`
// - B) `vec![]`
// - C) Both A and B (with type annotation for A)
// - D) `Vec::empty()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q47. C)** Both A and B. `Vec::new()` needs a type (e.g., `Vec::<i32>::new()` or `let v: Vec<i32> = Vec::new()`); `vec![]` may need context.
//
// </details>

// %% [markdown]
// ### Q48. What does `vec![1, 2, 3]` create?
//
// - A) An array `[1, 2, 3]`
// - B) A `Vec<i32>` with elements 1, 2, 3
// - C) A slice
// - D) A tuple
//
// <details>
// <summary>Show Answer</summary>
//
// **Q48. B)** A `Vec<i32>` with elements 1, 2, 3. The `vec!` macro creates a vector.
//
// </details>

// %% [markdown]
// ### Q49. How do you push an element onto a `Vec`?
//
// - A) `vec.add(4)`
// - B) `vec.push(4)`
// - C) `vec.append(4)`
// - D) `vec.insert(4)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q49. B)** `vec.push(4)`. `push` adds an element to the end.
//
// </details>

// %% [markdown]
// ### Q50. What does `&v[..]` produce when `v` is a `Vec<i32>`?
//
// - A) The first element
// - B) A slice of the entire Vec
// - C) A copy of the Vec
// - D) Compilation error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q50. B)** A slice of the entire Vec. `..` means full range; `&v` also coerces to `&[i32]`.
//
// </details>

// %% [markdown]
// ### Q51. What is the return type of a function that doesn't specify one?
//
// - A) `void`
// - B) `()` (unit type)
// - C) `null`
// - D) Compilation error
//
// <details>
// <summary>Show Answer</summary>
//
// **Q51. B)** `()` (unit type). Functions without an explicit return type return `()`.
//
// </details>

// %% [markdown]
// ### Q52. In Rust, what is the difference between a statement and an expression?
//
// - A) There is no difference
// - B) Statements do not return a value; expressions do
// - C) Expressions cannot contain statements
// - D) Statements are only in `fn` bodies
//
// <details>
// <summary>Show Answer</summary>
//
// **Q52. B)** Statements do not return a value; expressions do. The last expression in a block is its value.
//
// </details>

// %% [markdown]
// ### Q53. What does this function return?
// ```rust
// fn foo() -> i32 {
//     5
// }
// ```
//
// - A) Nothing (error: missing return)
// - B) 5 (the trailing expression)
// - C) Compilation error (need `return 5`)
// - D) Undefined
//
// <details>
// <summary>Show Answer</summary>
//
// **Q53. B)** 5 (the trailing expression). In Rust, the last expression (no semicolon) is the return value.
//
// </details>

// %% [markdown]
// ### Q54. How do you pass a value by reference to a function?
//
// - A) `fn f(x: &i32)`
// - B) `fn f(x: ref i32)`
// - C) `fn f(x: *i32)`
// - D) `fn f(x: ref &i32)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q54. A)** `fn f(x: &i32)`. The `&` denotes a reference (borrow).
//
// </details>

// %% [markdown]
// ### Q55. What does `fn add(x: i32, y: i32) -> i32 { x + y }` demonstrate?
//
// - A) Multiple return values
// - B) Parameters and return value
// - C) Closure syntax
// - D) Generic function
//
// <details>
// <summary>Show Answer</summary>
//
// **Q55. B)** Parameters and return value. The function takes two `i32`s and returns their sum.
//
// </details>

// %% [markdown]
// ### Q56. What is a closure in Rust?
//
// - A) A function that can only be called once
// - B) An anonymous function that can capture its environment
// - C) A function with no parameters
// - D) A recursive function
//
// <details>
// <summary>Show Answer</summary>
//
// **Q56. B)** An anonymous function that can capture its environment. Closures can use variables from the enclosing scope.
//
// </details>

// %% [markdown]
// ### Q57. Which syntax defines a closure that adds two numbers?
//
// - A) `fn |a, b| a + b`
// - B) `|a, b| a + b`
// - C) `closure(a, b) { a + b }`
// - D) `lambda a, b: a + b`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q57. B)** `|a, b| a + b`. Closures use `|params| body` syntax.
//
// </details>

// %% [markdown]
// ### Q58. Can a closure capture variables from its enclosing scope?
//
// - A) No, never
// - B) Yes, by default it borrows immutably
// - C) Only with explicit `capture` keyword
// - D) Only for `Copy` types
//
// <details>
// <summary>Show Answer</summary>
//
// **Q58. B)** Yes, by default it borrows immutably. Closures can also borrow mutably or take ownership with `move`.
//
// </details>

// %% [markdown]
// ### Q59. What does `return` do in a Rust function?
//
// - A) Exits the function and returns the unit value `()`
// - B) Exits the function and returns the specified value
// - C) Only exits loops
// - D) Is required for all functions
//
// <details>
// <summary>Show Answer</summary>
//
// **Q59. B)** Exits the function and returns the specified value. `return x;` is equivalent to `x` as the last expression, but can appear anywhere.
//
// </details>

// %% [markdown]
// ### Q60. What is the type of `|| 42`?
//
// - A) `fn() -> i32`
// - B) A closure type (e.g., `impl Fn() -> i32`)
// - C) `i32`
// - D) Invalid syntax
//
// <details>
// <summary>Show Answer</summary>
//
// **Q60. B)** A closure type. Each closure has a unique, anonymous type implementing `Fn`, `FnMut`, or `FnOnce`.
//
// </details>

// %% [markdown]
// ### Q61. In Rust, is `if` an expression or a statement?
//
// - A) Statement only
// - B) Expression (can produce a value)
// - C) Neither
// - D) Both, depending on context
//
// <details>
// <summary>Show Answer</summary>
//
// **Q61. B)** Expression (can produce a value). `let x = if cond { 1 } else { 2 };` is valid.
//
// </details>

// %% [markdown]
// ### Q62. What must all arms of an `if` expression return?
//
// - A) The same type
// - B) Any type
// - C) Only numeric types
// - D) The unit type `()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q62. A)** The same type. All branches must evaluate to the same type for the `if` to be used as an expression.
//
// </details>

// %% [markdown]
// ### Q63. What does `match` require?
//
// - A) At least one arm
// - B) Exhaustive pattern matching (all cases covered)
// - C) A default arm
// - D) Only one arm
//
// <details>
// <summary>Show Answer</summary>
//
// **Q63. B)** Exhaustive pattern matching (all cases covered). Every possible value must be handled or `_` used.
//
// </details>

// %% [markdown]
// ### Q64. What does `loop` do?
//
// - A) Runs exactly once
// - B) Runs while a condition is true
// - C) Runs indefinitely until `break`
// - D) Runs a fixed number of times
//
// <details>
// <summary>Show Answer</summary>
//
// **Q64. C)** Runs indefinitely until `break`. `loop` is an infinite loop by default.
//
// </details>

// %% [markdown]
// ### Q65. What does `break` return from a `loop`?
//
// - A) Nothing
// - B) The value passed to `break` (e.g., `break 42`)
// - C) Always `()`
// - D) The loop's last expression
//
// <details>
// <summary>Show Answer</summary>
//
// **Q65. B)** The value passed to `break` (e.g., `break 42`). `loop` can be an expression: `let x = loop { break 42; };`
//
// </details>

// %% [markdown]
// ### Q66. How do you label a loop for use with `break`/`continue`?
//
// - A) `loop "outer" { }`
// - B) `'outer: loop { }`
// - C) `loop @outer { }`
// - D) `#outer loop { }`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q66. B)** `'outer: loop { }`. Loop labels use a lifetime-like syntax with a leading quote.
//
// </details>

// %% [markdown]
// ### Q67. What does `for i in 0..5` iterate over?
//
// - A) 0, 1, 2, 3, 4
// - B) 0, 1, 2, 3, 4, 5
// - C) 1, 2, 3, 4, 5
// - D) An infinite range
//
// <details>
// <summary>Show Answer</summary>
//
// **Q67. A)** 0, 1, 2, 3, 4. `0..5` is a range exclusive of the end.
//
// </details>

// %% [markdown]
// ### Q68. What is `0..=5`?
//
// - A) Range 0 to 5 exclusive
// - B) Range 0 to 5 inclusive
// - C) Invalid syntax
// - D) Same as `0..5`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q68. B)** Range 0 to 5 inclusive. `..=` includes the end value.
//
// </details>

// %% [markdown]
// ### Q69. When is a `while` loop's condition evaluated?
//
// - A) Only at the start
// - B) Before each iteration
// - C) Only at the end
// - D) Once, before the first run
//
// <details>
// <summary>Show Answer</summary>
//
// **Q69. B)** Before each iteration. The condition is checked at the start of every loop iteration.
//
// </details>

// %% [markdown]
// ### Q70. What does `continue` do?
//
// - A) Exits the loop entirely
// - B) Skips the rest of the current iteration and continues to the next
// - C) Returns a value from the loop
// - D) Pauses the loop
//
// <details>
// <summary>Show Answer</summary>
//
// **Q70. B)** Skips the rest of the current iteration and continues to the next. With a label, it continues the labeled loop.
//
// </details>

// %% [markdown]
// ### Q71. What are the three kinds of structs in Rust?
//
// - A) Public, private, protected
// - B) Struct, class, interface
// - C) Named-field, tuple, unit
// - D) Mutable, immutable, constant
//
// <details>
// <summary>Show Answer</summary>
//
// **Q71. C)** Named-field, tuple, unit. Structs can have named fields, tuple-like fields, or no fields.
//
// </details>

// %% [markdown]
// ### Q72. What is a unit struct?
//
// - A) A struct with no fields
// - B) A struct with one field
// - C) A struct that implements `Unit`
// - D) A struct with unit type fields only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q72. A)** A struct with no fields. e.g., `struct Unit;` — useful for type-level markers.
//
// </details>

// %% [markdown]
// ### Q73. How do you define a method on a struct?
//
// - A) Inside the struct definition
// - B) In an `impl` block
// - C) Using the `method` keyword
// - D) With `fn struct_name::method`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q73. B)** In an `impl` block. `impl StructName { fn method(&self) { } }`
//
// </details>

// %% [markdown]
// ### Q74. What is `self` in a method?
//
// - A) A keyword for the current module
// - B) A reference to the instance the method is called on
// - C) The return value
// - D) A type parameter
//
// <details>
// <summary>Show Answer</summary>
//
// **Q74. B)** A reference to the instance the method is called on. `self` can be `self`, `&self`, or `&mut self`.
//
// </details>

// %% [markdown]
// ### Q75. What is the difference between `&self` and `self` in a method?
//
// - A) No difference
// - B) `&self` borrows the instance; `self` takes ownership
// - C) `self` is used for static methods
// - D) `&self` is mutable, `self` is immutable
//
// <details>
// <summary>Show Answer</summary>
//
// **Q75. B)** `&self` borrows the instance; `self` takes ownership. Use `&self` for read-only, `&mut self` for mutation.
//
// </details>

// %% [markdown]
// ### Q76. What is an associated function?
//
// - A) A function that takes `&self`
// - B) A function in an `impl` block that doesn't take `self` (like a constructor)
// - C) A function in another module
// - D) A closure associated with a struct
//
// <details>
// <summary>Show Answer</summary>
//
// **Q76. B)** A function in an `impl` block that doesn't take `self`. Often used as constructors, e.g., `String::new()`.
//
// </details>

// %% [markdown]
// ### Q77. How do you call an associated function?
//
// - A) `instance.method()`
// - B) `Struct::function()`
// - C) `function(Struct)`
// - D) `Struct.method()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q77. B)** `Struct::function()`. Associated functions are called with `::`; methods use `.`.
//
// </details>

// %% [markdown]
// ### Q78. What is a tuple struct?
//
// ```rust
// struct Point(i32, i32);
// ```
//
// - A) Invalid syntax
// - B) A struct with unnamed fields accessed by index
// - C) A type alias for a tuple
// - D) A struct with one field
//
// <details>
// <summary>Show Answer</summary>
//
// **Q78. B)** A struct with unnamed fields accessed by index. `Point(1, 2)` has fields `.0` and `.1`.
//
// </details>

// %% [markdown]
// ### Q79. Can you have multiple `impl` blocks for the same struct?
//
// - A) No, only one
// - B) Yes, you can split them
// - C) Only for generic structs
// - D) Only in different modules
//
// <details>
// <summary>Show Answer</summary>
//
// **Q79. B)** Yes, you can split them. Multiple `impl` blocks for the same type are allowed.
//
// </details>

// %% [markdown]
// ### Q80. What does `#[derive(Debug)]` do?
//
// - A) Enables debug mode
// - B) Automatically implements the `Debug` trait for formatting
// - C) Adds debug logging
// - D) Makes the struct public
//
// <details>
// <summary>Show Answer</summary>
//
// **Q80. B)** Automatically implements the `Debug` trait for formatting. Enables `{:?}` and `{:#?}` in `println!`.
//
// </details>

// %% [markdown]
// ### Q81. What is an enum in Rust?
//
// - A) A collection of constants
// - B) A type that can be one of several variants, each optionally holding data
// - C) A set of flags
// - D) A namespace for functions
//
// <details>
// <summary>Show Answer</summary>
//
// **Q81. B)** A type that can be one of several variants, each optionally holding data. Enums are algebraic data types.
//
// </details>

// %% [markdown]
// ### Q82. What is `Option<T>`?
//
// - A) A type that must hold a value
// - B) A type representing an optional value: `Some(T)` or `None`
// - C) A generic array
// - D) A result type
//
// <details>
// <summary>Show Answer</summary>
//
// **Q82. B)** A type representing an optional value: `Some(T)` or `None`. Replaces null from other languages.
//
// </details>

// %% [markdown]
// ### Q83. What is `Result<T, E>`?
//
// - A) A type that can only succeed
// - B) A type representing success `Ok(T)` or failure `Err(E)`
// - C) A tuple of two values
// - D) An optional with error info
//
// <details>
// <summary>Show Answer</summary>
//
// **Q83. B)** A type representing success `Ok(T)` or failure `Err(E)`. Used for fallible operations.
//
// </details>

// %% [markdown]
// ### Q84. How do you unwrap an `Option<T>` to get the inner value (panicking if `None`)?
//
// - A) `.get()`
// - B) `.unwrap()`
// - C) `.value()`
// - D) `.extract()`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q84. B)** `.unwrap()`. Returns the value or panics. Prefer `?`, `unwrap_or`, or `match` in production.
//
// </details>

// %% [markdown]
// ### Q85. What does `Option::unwrap_or(default)` do?
//
// - A) Panics if `None`
// - B) Returns the inner value, or `default` if `None`
// - C) Converts to `Result`
// - D) Returns `None`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q85. B)** Returns the inner value, or `default` if `None`. Safe way to provide a fallback.
//
// </details>

// %% [markdown]
// ### Q86. Can enum variants hold different types of data?
//
// - A) No, all variants must hold the same type
// - B) Yes, each variant can have different associated data
// - C) Only tuple variants
// - D) Only unit variants
//
// <details>
// <summary>Show Answer</summary>
//
// **Q86. B)** Yes, each variant can have different associated data. Variants can be unit, tuple, or struct-like.
//
// </details>

// %% [markdown]
// ### Q87. What is this enum?
// ```rust
// enum Message {
//     Quit,
//     Write(String),
//     Move { x: i32, y: i32 },
// }
// ```
//
// - A) Invalid (mixed variant styles)
// - B) Valid: unit, tuple, and struct variants
// - C) Only unit variants allowed
// - D) Must use one style only
//
// <details>
// <summary>Show Answer</summary>
//
// **Q87. B)** Valid: unit, tuple, and struct variants. Rust allows mixing variant styles in one enum.
//
// </details>

// %% [markdown]
// ### Q88. How do you construct `Some(5)`?
//
// - A) `Option::Some(5)` or `Some(5)`
// - B) `Option(5)`
// - C) `Optional::some(5)`
// - D) `Some::new(5)`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q88. A)** `Option::Some(5)` or `Some(5)`. `Some` is a variant constructor.
//
// </details>

// %% [markdown]
// ### Q89. What does `?` do when used on a `Result`?
//
// - A) Negates the value
// - B) Returns early with `Err` if the `Result` is `Err`, otherwise unwraps `Ok`
// - C) Converts to `Option`
// - D) Unwraps and panics on `Err`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q89. B)** Returns early with `Err` if the `Result` is `Err`, otherwise unwraps `Ok`. Used for error propagation.
//
// </details>

// %% [markdown]
// ### Q90. Is `Option<T>` in the prelude?
//
// - A) No, you must import it
// - B) Yes, `Some` and `None` are in the prelude
// - C) Only `Option` is, not `Some`/`None`
// - D) Only in `std`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q90. B)** Yes, `Some` and `None` are in the prelude. No need to import for basic use.
//
// </details>

// %% [markdown]
// ### Q91. What does `match` do?
//
// - A) Compares two values for equality
// - B) Pattern matches on a value and executes the matching arm
// - C) Loops until a condition is met
// - D) Declares a variable
//
// <details>
// <summary>Show Answer</summary>
//
// **Q91. B)** Pattern matches on a value and executes the matching arm. `match` is exhaustive and must cover all cases.
//
// </details>

// %% [markdown]
// ### Q92. What is `if let` used for?
//
// - A) Replacing `if` with `let`
// - B) Concise pattern matching when you care about one variant only
// - C) Declaring a variable conditionally
// - D) Looping with a condition
//
// <details>
// <summary>Show Answer</summary>
//
// **Q92. B)** Concise pattern matching when you care about one variant. e.g., `if let Some(x) = opt { }` instead of `match opt { Some(x) => {}, _ => {} }`
//
// </details>

// %% [markdown]
// ### Q93. What does `while let` do?
//
// - A) Loops while a condition is true
// - B) Loops while a pattern matches, binding the matched value
// - C) Same as `for` loop
// - D) Invalid syntax
//
// <details>
// <summary>Show Answer</summary>
//
// **Q93. B)** Loops while a pattern matches, binding the matched value. Useful for iterators: `while let Some(item) = iter.next()`
//
// </details>

// %% [markdown]
// ### Q94. What is destructuring?
//
// - A) Deleting a variable
// - B) Extracting values from a compound type (tuple, struct, enum) into variables
// - C) Converting types
// - D) Breaking a string
//
// <details>
// <summary>Show Answer</summary>
//
// **Q94. B)** Extracting values from a compound type into variables. e.g., `let (a, b) = (1, 2);` or `let Point { x, y } = p;`
//
// </details>

// %% [markdown]
// ### Q95. What is a match guard?
//
// - A) A `match` that must be exhaustive
// - B) An extra `if` condition on a match arm
// - C) A default arm
// - D) A pattern that matches everything
//
// <details>
// <summary>Show Answer</summary>
//
// **Q95. B)** An extra `if` condition on a match arm. e.g., `Some(n) if n > 0 =>` — refines the match.
//
// </details>

// %% [markdown]
// ### Q96. What does `_` mean in a pattern?
//
// - A) A variable named underscore
// - B) A wildcard that matches any value and doesn't bind
// - C) Ignore the rest of the pattern
// - D) Default value
//
// <details>
// <summary>Show Answer</summary>
//
// **Q96. B)** A wildcard that matches any value and doesn't bind. Used when you don't need the value.
//
// </details>

// %% [markdown]
// ### Q97. What does `..` mean in a pattern?
//
// - A) Range
// - B) Ignore remaining fields in a struct/tuple
// - C) Splat operator
// - D) Spread
//
// <details>
// <summary>Show Answer</summary>
//
// **Q97. B)** Ignore remaining fields in a struct/tuple. e.g., `Point { x, .. }` ignores `y` and other fields.
//
// </details>

// %% [markdown]
// ### Q98. Can you use `if let` with `else`?
//
// - A) No
// - B) Yes, `if let ... else { }`
// - C) Only with `match`
// - D) Only for `Option`
//
// <details>
// <summary>Show Answer</summary>
//
// **Q98. B)** Yes, `if let ... else { }`. The `else` block runs when the pattern doesn't match.
//
// </details>

// %% [markdown]
// ### Q99. What does this match?
// ```rust
// match x {
//     Some(n) if n > 0 => { },
//     _ => { },
// }
// ```
//
// - A) Only `Some` with positive value
// - B) `Some(n)` where n > 0 (first arm)
// - C) Invalid syntax
// - D) All `Some` values
//
// <details>
// <summary>Show Answer</summary>
//
// **Q99. B)** `Some(n)` where n > 0 (first arm). The `if n > 0` is a match guard; `_` catches everything else.
//
// </details>

// %% [markdown]
// ### Q100. What is `@` used for in patterns?
//
// - A) Reference to a variable
// - B) Binding a value to a variable while also matching a pattern (e.g., `p @ 1..=5`)
// - C) Dereference
// - D) Address-of
//
// <details>
// <summary>Show Answer</summary>
//
// **Q100. B)** Binding a value to a variable while also matching a pattern. e.g., `p @ 1..=5` binds the matched value to `p`.
//
// </details>
